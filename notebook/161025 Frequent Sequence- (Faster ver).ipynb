# %% [markdown]
# ### Frequent Sequence 를 찾은 후 Feature로 이용하는 모듈 (faster ver)
#
# 달라진 점: 기존 161024 version에서는 pymining package로 support가 일정 이상인, frequent sequence를 찾은 후 information gain 계산을 위해 data frame 전체에 검색해서 TP, TN, FP, FN를 계산했는데 이 방법으로는 한 사이클에 30분 이상이 걸렸었다.
#
# 이 version에서는 frequent sequence를 찾으면서, 해당 sequence의 revisit intention을 동시에 기록해 놓아 information gain 계산을 하는데 걸렸던 검색 시간을 없애서 한 사이클에 20초 내외로 끝낼 수 있었다.
#
# To-Do: Scikit-learn에서 10-fold cross validation을 제공해 주는데, 보통 feature들을 다 뽑은 후,  frequent sequence가 test data까지 모두 합한 데이터를 기반해서 찾아짐.

# %%
import pandas as pd
from pymining import seqmining
import numpy as np
from scipy.special import entr
from collections import defaultdict

# %%
trajs_combined_balanced = pd.read_pickle("../data/786/786_trajs_combined_balanced.p")

# %%
trajs_combined_balanced['revisit_intention'] = trajs_combined_balanced['revisit_intention'].astype(int)
seqs = trajs_combined_balanced.apply(lambda x: (x['traj'], x['revisit_intention']), axis=1)

# %%
seqs.shape[0]
# Out:
# 8886

# %%
freq_seqs = freq_seq_enum(seqs, 200)

# %%
freq_seqs
# Out:
# {(('1f',), 6509, 3359),
#  (('1f', '1f'), 617, 431),
#  (('1f', '1f', '1f-inner'), 201, 141),
#  (('1f', '1f', '1f-left'), 225, 163),
#  (('1f', '1f', '1f-right'), 341, 236),
#  (('1f', '1f-inner'), 1827, 1005),
#  (('1f', '1f-inner', '1f'), 207, 143),
#  (('1f', '1f-inner', '1f-left'), 610, 372),
#  (('1f', '1f-inner', '1f-left', '1f-right'), 229, 142),
#  (('1f', '1f-inner', '1f-right'), 657, 390),
#  (('1f', '1f-inner', '1f-right', '1f-left'), 203, 130),
#  (('1f', '1f-inner', '2f'), 432, 265),
#  (('1f', '1f-inner', '2f-right'), 211, 122),
#  (('1f', '1f-inner', 'out'), 407, 210),
#  (('1f', '1f-left'), 1823, 1069),
#  (('1f', '1f-left', '1f-inner'), 729, 429),
#  (('1f', '1f-left', '1f-inner', '1f-right'), 206, 132),
#  (('1f', '1f-left', '1f-right'), 717, 423),
#  (('1f', '1f-left', '1f-right', '1f-inner'), 217, 134),
#  (('1f', '1f-left', '2f'), 453, 282),
#  (('1f', '1f-left', '2f-right'), 218, 124),
#  (('1f', '1f-left', 'out'), 405, 237),
#  (('1f', '1f-right'), 2608, 1486),
#  (('1f', '1f-right', '1f'), 301, 218),
#  (('1f', '1f-right', '1f-inner'), 805, 477),
#  (('1f', '1f-right', '1f-inner', '1f-left'), 259, 159),
#  (('1f', '1f-right', '1f-inner', '2f'), 201, 127),
#  (('1f', '1f-right', '1f-left'), 898, 556),
#  (('1f', '1f-right', '1f-left', '1f-inner'), 321, 200),
#  (('1f', '1f-right', '1f-left', '2f'), 206, 135),
#  (('1f', '1f-right', '1f-left', 'out'), 202, 131),
#  (('1f', '1f-right', '1f-right'), 285, 192),
#  (('1f', '1f-right', '2f'), 681, 397),
#  (('1f', '1f-right', '2f', '2f-inner'), 218, 124),
#  (('1f', '1f-right', '2f', '2f-left'), 290, 165),
#  (('1f', '1f-right', '2f', '2f-right'), 308, 174),
#  (('1f', '1f-right', '2f-inner'), 304, 174),
#  (('1f', '1f-right', '2f-left'), 336, 190),
#  (('1f', '1f-right', '2f-right'), 372, 211),
#  (('1f', '1f-right', '3f'), 205, 116),
#  (('1f', '1f-right', 'out'), 567, 315),
#  (('1f', '2f'), 1612, 883),
#  (('1f', '2f', '1f'), 349, 251),
#  (('1f', '2f', '1f', '1f-right'), 229, 169),
#  (('1f', '2f', '1f-inner'), 339, 235),
#  (('1f', '2f', '1f-left'), 398, 277),
#  (('1f', '2f', '1f-right'), 506, 350),
#  (('1f', '2f', '2f-inner'), 456, 261),
#  (('1f', '2f', '2f-left'), 602, 338),
#  (('1f', '2f', '2f-left', '1f-right'), 232, 161),
#  (('1f', '2f', '2f-left', '2f-right'), 214, 118),
#  (('1f', '2f', '2f-right'), 624, 333),
#  (('1f', '2f', '2f-right', '1f-right'), 224, 156),
#  (('1f', '2f', '2f-right', '2f-left'), 202, 114),
#  (('1f', '2f', '3f'), 273, 149),
#  (('1f', '2f', 'out'), 370, 206),
#  (('1f', '2f-inner'), 666, 368),
#  (('1f', '2f-inner', '1f-left'), 207, 140),
#  (('1f', '2f-inner', '1f-right'), 272, 183),
#  (('1f', '2f-inner', '2f-left'), 274, 160),
#  (('1f', '2f-inner', '2f-right'), 276, 151),
#  (('1f', '2f-left'), 744, 412),
#  (('1f', '2f-left', '1f-left'), 220, 153),
#  (('1f', '2f-left', '1f-right'), 278, 193),
#  (('1f', '2f-left', '2f-inner'), 213, 121),
#  (('1f', '2f-left', '2f-right'), 279, 154),
#  (('1f', '2f-right'), 806, 437),
#  (('1f', '2f-right', '1f-left'), 233, 162),
#  (('1f', '2f-right', '1f-right'), 287, 203),
#  (('1f', '2f-right', '2f-left'), 277, 162),
#  (('1f', '3f'), 453, 248),
#  (('1f', 'in'), 421, 293),
#  (('1f', 'in', '1f'), 369, 260),
#  (('1f', 'in', '1f-right'), 230, 159),
#  (('1f', 'out'), 1543, 833),
#  (('1f', 'out', '1f'), 266, 183),
#  (('1f', 'out', 'in'), 301, 207),
#  (('1f', 'out', 'in', '1f'), 266, 183),
#  (('1f', 'out', 'out'), 357, 220),
#  (('1f-inner',), 2000, 1095),
#  (('1f-inner', '1f'), 391, 240),
#  (('1f-inner', '1f', '1f-right'), 235, 148),
#  (('1f-inner', '1f-left'), 683, 420),
#  (('1f-inner', '1f-left', '1f-right'), 271, 167),
#  (('1f-inner', '1f-right'), 754, 449),
#  (('1f-inner', '1f-right', '1f-left'), 236, 156),
#  (('1f-inner', '2f'), 478, 294),
#  (('1f-inner', '2f-right'), 223, 129),
#  (('1f-inner', 'out'), 451, 233),
#  (('1f-left',), 2015, 1167),
#  (('1f-left', '1f'), 400, 240),
#  (('1f-left', '1f', '1f-right'), 284, 171),
#  (('1f-left', '1f-inner'), 838, 485),
#  (('1f-left', '1f-inner', '1f-right'), 249, 151),
#  (('1f-left', '1f-right'), 872, 508),
#  (('1f-left', '1f-right', '1f-inner'), 280, 171),
#  (('1f-left', '1f-right', '2f'), 211, 126),
#  (('1f-left', '2f'), 506, 311),
#  (('1f-left', '2f-inner'), 200, 115),
#  (('1f-left', '2f-left'), 221, 133),
#  (('1f-left', '2f-right'), 247, 141),
#  (('1f-left', 'out'), 448, 256),
#  (('1f-right',), 3145, 1778),
#  (('1f-right', '1f'), 885, 546),
#  (('1f-right', '1f', '1f-inner'), 312, 193),
#  (('1f-right', '1f', '1f-left'), 379, 247),
#  (('1f-right', '1f', '1f-right'), 207, 146),
#  (('1f-right', '1f', '2f'), 213, 129),
#  (('1f-right', '1f-inner'), 1002, 589),
#  (('1f-right', '1f-inner', '1f-left'), 332, 208),
#  (('1f-right', '1f-inner', '2f'), 247, 155),
#  (('1f-right', '1f-inner', 'out'), 238, 135),
#  (('1f-right', '1f-left'), 1136, 700),
#  (('1f-right', '1f-left', '1f-inner'), 414, 250),
#  (('1f-right', '1f-left', '2f'), 265, 172),
#  (('1f-right', '1f-left', 'out'), 254, 158),
#  (('1f-right', '1f-right'), 336, 232),
#  (('1f-right', '2f'), 836, 486),
#  (('1f-right', '2f', '1f-left'), 221, 152),
#  (('1f-right', '2f', '1f-right'), 204, 150),
#  (('1f-right', '2f', '2f-inner'), 255, 151),
#  (('1f-right', '2f', '2f-left'), 334, 193),
#  (('1f-right', '2f', '2f-right'), 365, 198),
#  (('1f-right', '2f-inner'), 357, 209),
#  (('1f-right', '2f-left'), 395, 228),
#  (('1f-right', '2f-right'), 445, 248),
#  (('1f-right', '3f'), 251, 146),
#  (('1f-right', 'in'), 205, 148),
#  (('1f-right', 'out'), 666, 375),
#  (('2f',), 3189, 1664),
#  (('2f', '1f'), 1095, 666),
#  (('2f', '1f', '1f-inner'), 279, 197),
#  (('2f', '1f', '1f-left'), 360, 249),
#  (('2f', '1f', '1f-right'), 554, 381),
#  (('2f', '1f', '1f-right', '1f-left'), 208, 150),
#  (('2f', '1f-inner'), 503, 345),
#  (('2f', '1f-left'), 611, 414),
#  (('2f', '1f-left', '1f-right'), 206, 138),
#  (('2f', '1f-right'), 915, 609),
#  (('2f', '1f-right', '1f'), 204, 135),
#  (('2f', '1f-right', '1f-inner'), 233, 164),
#  (('2f', '1f-right', '1f-left'), 335, 233),
#  (('2f', '2f'), 219, 162),
#  (('2f', '2f-inner'), 702, 394),
#  (('2f', '2f-inner', '1f'), 262, 168),
#  (('2f', '2f-inner', '1f-left'), 219, 145),
#  (('2f', '2f-inner', '1f-right'), 316, 211),
#  (('2f', '2f-inner', '2f-left'), 221, 139),
#  (('2f', '2f-inner', '2f-right'), 235, 137),
#  (('2f', '2f-left'), 996, 548),
#  (('2f', '2f-left', '1f'), 374, 233),
#  (('2f', '2f-left', '1f', '1f-right'), 217, 146),
#  (('2f', '2f-left', '1f-left'), 266, 184),
#  (('2f', '2f-left', '1f-right'), 381, 260),
#  (('2f', '2f-left', '2f-inner'), 245, 131),
#  (('2f', '2f-left', '2f-right'), 329, 183),
#  (('2f', '2f-left', 'out'), 218, 119),
#  (('2f', '2f-right'), 1032, 564),
#  (('2f', '2f-right', '1f'), 367, 243),
#  (('2f', '2f-right', '1f', '1f-right'), 206, 152),
#  (('2f', '2f-right', '1f-inner'), 210, 146),
#  (('2f', '2f-right', '1f-left'), 278, 195),
#  (('2f', '2f-right', '1f-right'), 378, 270),
#  (('2f', '2f-right', '2f-inner'), 205, 117),
#  (('2f', '2f-right', '2f-left'), 303, 175),
#  (('2f', '2f-right', 'out'), 225, 130),
#  (('2f', '3f'), 418, 221),
#  (('2f', 'in'), 251, 174),
#  (('2f', 'in', '1f'), 209, 145),
#  (('2f', 'out'), 677, 363),
#  (('2f-inner',), 917, 505),
#  (('2f-inner', '1f'), 332, 215),
#  (('2f-inner', '1f', '1f-right'), 203, 138),
#  (('2f-inner', '1f-left'), 265, 182),
#  (('2f-inner', '1f-right'), 382, 257),
#  (('2f-inner', '2f'), 280, 155),
#  (('2f-inner', '2f-left'), 350, 206),
#  (('2f-inner', '2f-right'), 350, 196),
#  (('2f-inner', 'out'), 204, 114),
#  (('2f-left',), 1198, 657),
#  (('2f-left', '1f'), 451, 279),
#  (('2f-left', '1f', '1f-right'), 247, 166),
#  (('2f-left', '1f-inner'), 224, 156),
#  (('2f-left', '1f-left'), 308, 212),
#  (('2f-left', '1f-right'), 432, 295),
#  (('2f-left', '2f'), 273, 156),
#  (('2f-left', '2f-inner'), 313, 172),
#  (('2f-left', '2f-right'), 429, 239),
#  (('2f-left', 'out'), 253, 138),
#  (('2f-right',), 1304, 700),
#  (('2f-right', '1f'), 477, 303),
#  (('2f-right', '1f', '1f-right'), 263, 185),
#  (('2f-right', '1f-inner'), 249, 170),
#  (('2f-right', '1f-left'), 326, 225),
#  (('2f-right', '1f-right'), 462, 321),
#  (('2f-right', '2f'), 359, 201),
#  (('2f-right', '2f-inner'), 253, 141),
#  (('2f-right', '2f-left'), 411, 237),
#  (('2f-right', 'out'), 290, 163),
#  (('3f',), 756, 418),
#  (('3f', '1f'), 262, 172),
#  (('3f', '1f-right'), 233, 161),
#  (('3f', '2f'), 220, 127),
#  (('3f', '2f-right'), 213, 111),
#  (('in',), 8886, 4443),
#  (('in', '1f'), 6509, 3359),
#  (('in', '1f', '1f'), 616, 431),
#  (('in', '1f', '1f', '1f-inner'), 201, 141),
#  (('in', '1f', '1f', '1f-left'), 225, 163),
#  (('in', '1f', '1f', '1f-right'), 341, 236),
#  (('in', '1f', '1f-inner'), 1827, 1005),
#  (('in', '1f', '1f-inner', '1f'), 207, 143),
#  (('in', '1f', '1f-inner', '1f-left'), 610, 372),
#  (('in', '1f', '1f-inner', '1f-left', '1f-right'), 229, 142),
#  (('in', '1f', '1f-inner', '1f-right'), 657, 390),
#  (('in', '1f', '1f-inner', '1f-right', '1f-left'), 203, 130),
#  (('in', '1f', '1f-inner', '2f'), 432, 265),
#  (('in', '1f', '1f-inner', '2f-right'), 211, 122),
#  (('in', '1f', '1f-inner', 'out'), 407, 210),
#  (('in', '1f', '1f-left'), 1823, 1069),
#  (('in', '1f', '1f-left', '1f-inner'), 729, 429),
#  (('in', '1f', '1f-left', '1f-inner', '1f-right'), 206, 132),
#  (('in', '1f', '1f-left', '1f-right'), 717, 423),
#  (('in', '1f', '1f-left', '1f-right', '1f-inner'), 217, 134),
#  (('in', '1f', '1f-left', '2f'), 453, 282),
#  (('in', '1f', '1f-left', '2f-right'), 218, 124),
#  (('in', '1f', '1f-left', 'out'), 405, 237),
#  (('in', '1f', '1f-right'), 2607, 1486),
#  (('in', '1f', '1f-right', '1f'), 300, 218),
#  (('in', '1f', '1f-right', '1f-inner'), 805, 477),
#  (('in', '1f', '1f-right', '1f-inner', '1f-left'), 259, 159),
#  (('in', '1f', '1f-right', '1f-inner', '2f'), 201, 127),
#  (('in', '1f', '1f-right', '1f-left'), 898, 556),
#  (('in', '1f', '1f-right', '1f-left', '1f-inner'), 321, 200),
#  (('in', '1f', '1f-right', '1f-left', '2f'), 206, 135),
#  (('in', '1f', '1f-right', '1f-left', 'out'), 202, 131),
#  (('in', '1f', '1f-right', '1f-right'), 285, 192),
#  (('in', '1f', '1f-right', '2f'), 681, 397),
#  (('in', '1f', '1f-right', '2f', '2f-inner'), 218, 124),
#  (('in', '1f', '1f-right', '2f', '2f-left'), 290, 165),
#  (('in', '1f', '1f-right', '2f', '2f-right'), 308, 174),
#  (('in', '1f', '1f-right', '2f-inner'), 304, 174),
#  (('in', '1f', '1f-right', '2f-left'), 336, 190),
#  (('in', '1f', '1f-right', '2f-right'), 372, 211),
#  (('in', '1f', '1f-right', '3f'), 205, 116),
#  (('in', '1f', '1f-right', 'out'), 566, 315),
#  (('in', '1f', '2f'), 1612, 883),
#  (('in', '1f', '2f', '1f'), 349, 251),
#  (('in', '1f', '2f', '1f', '1f-right'), 229, 169),
#  (('in', '1f', '2f', '1f-inner'), 339, 235),
#  (('in', '1f', '2f', '1f-left'), 398, 277),
#  (('in', '1f', '2f', '1f-right'), 506, 350),
#  (('in', '1f', '2f', '2f-inner'), 456, 261),
#  (('in', '1f', '2f', '2f-left'), 602, 338),
#  (('in', '1f', '2f', '2f-left', '1f-right'), 232, 161),
#  (('in', '1f', '2f', '2f-left', '2f-right'), 214, 118),
#  (('in', '1f', '2f', '2f-right'), 624, 333),
#  (('in', '1f', '2f', '2f-right', '1f-right'), 224, 156),
#  (('in', '1f', '2f', '2f-right', '2f-left'), 202, 114),
#  (('in', '1f', '2f', '3f'), 273, 149),
#  (('in', '1f', '2f', 'out'), 370, 206),
#  (('in', '1f', '2f-inner'), 666, 368),
#  (('in', '1f', '2f-inner', '1f-left'), 207, 140),
#  (('in', '1f', '2f-inner', '1f-right'), 272, 183),
#  (('in', '1f', '2f-inner', '2f-left'), 274, 160),
#  (('in', '1f', '2f-inner', '2f-right'), 276, 151),
#  (('in', '1f', '2f-left'), 744, 412),
#  (('in', '1f', '2f-left', '1f-left'), 220, 153),
#  (('in', '1f', '2f-left', '1f-right'), 278, 193),
#  (('in', '1f', '2f-left', '2f-inner'), 213, 121),
#  (('in', '1f', '2f-left', '2f-right'), 279, 154),
#  (('in', '1f', '2f-right'), 806, 437),
#  (('in', '1f', '2f-right', '1f-left'), 233, 162),
#  (('in', '1f', '2f-right', '1f-right'), 287, 203),
#  (('in', '1f', '2f-right', '2f-left'), 277, 162),
#  (('in', '1f', '3f'), 453, 248),
#  (('in', '1f', 'in'), 420, 293),
#  (('in', '1f', 'in', '1f'), 368, 260),
#  (('in', '1f', 'in', '1f-right'), 230, 159),
#  (('in', '1f', 'out'), 1542, 833),
#  (('in', '1f', 'out', '1f'), 265, 183),
#  (('in', '1f', 'out', 'in'), 300, 207),
#  (('in', '1f', 'out', 'in', '1f'), 265, 183),
#  (('in', '1f', 'out', 'out'), 357, 220),
#  (('in', '1f-inner'), 2000, 1095),
#  (('in', '1f-inner', '1f'), 391, 240),
#  (('in', '1f-inner', '1f', '1f-right'), 235, 148),
#  (('in', '1f-inner', '1f-left'), 683, 420),
#  (('in', '1f-inner', '1f-left', '1f-right'), 271, 167),
#  (('in', '1f-inner', '1f-right'), 754, 449),
#  (('in', '1f-inner', '1f-right', '1f-left'), 236, 156),
#  (('in', '1f-inner', '2f'), 478, 294),
#  (('in', '1f-inner', '2f-right'), 223, 129),
#  (('in', '1f-inner', 'out'), 451, 233),
#  (('in', '1f-left'), 2015, 1167),
#  (('in', '1f-left', '1f'), 400, 240),
#  (('in', '1f-left', '1f', '1f-right'), 284, 171),
#  (('in', '1f-left', '1f-inner'), 838, 485),
#  (('in', '1f-left', '1f-inner', '1f-right'), 249, 151),
#  (('in', '1f-left', '1f-right'), 872, 508),
#  (('in', '1f-left', '1f-right', '1f-inner'), 280, 171),
#  (('in', '1f-left', '1f-right', '2f'), 211, 126),
#  (('in', '1f-left', '2f'), 506, 311),
#  (('in', '1f-left', '2f-inner'), 200, 115),
#  (('in', '1f-left', '2f-left'), 221, 133),
#  (('in', '1f-left', '2f-right'), 247, 141),
#  (('in', '1f-left', 'out'), 448, 256),
#  (('in', '1f-right'), 3144, 1778),
#  (('in', '1f-right', '1f'), 884, 546),
#  (('in', '1f-right', '1f', '1f-inner'), 312, 193),
#  (('in', '1f-right', '1f', '1f-left'), 379, 247),
#  (('in', '1f-right', '1f', '1f-right'), 207, 146),
#  (('in', '1f-right', '1f', '2f'), 213, 129),
#  (('in', '1f-right', '1f-inner'), 1002, 589),
#  (('in', '1f-right', '1f-inner', '1f-left'), 332, 208),
#  (('in', '1f-right', '1f-inner', '2f'), 247, 155),
#  (('in', '1f-right', '1f-inner', 'out'), 238, 135),
#  (('in', '1f-right', '1f-left'), 1136, 700),
#  (('in', '1f-right', '1f-left', '1f-inner'), 414, 250),
#  (('in', '1f-right', '1f-left', '2f'), 265, 172),
#  (('in', '1f-right', '1f-left', 'out'), 254, 158),
#  (('in', '1f-right', '1f-right'), 336, 232),
#  (('in', '1f-right', '2f'), 836, 486),
#  (('in', '1f-right', '2f', '1f-left'), 221, 152),
#  (('in', '1f-right', '2f', '1f-right'), 204, 150),
#  (('in', '1f-right', '2f', '2f-inner'), 255, 151),
#  (('in', '1f-right', '2f', '2f-left'), 334, 193),
#  (('in', '1f-right', '2f', '2f-right'), 365, 198),
#  (('in', '1f-right', '2f-inner'), 357, 209),
#  (('in', '1f-right', '2f-left'), 395, 228),
#  (('in', '1f-right', '2f-right'), 445, 248),
#  (('in', '1f-right', '3f'), 251, 146),
#  (('in', '1f-right', 'in'), 204, 148),
#  (('in', '1f-right', 'out'), 665, 375),
#  (('in', '2f'), 3188, 1664),
#  (('in', '2f', '1f'), 1094, 666),
#  (('in', '2f', '1f', '1f-inner'), 279, 197),
#  (('in', '2f', '1f', '1f-left'), 360, 249),
#  (('in', '2f', '1f', '1f-right'), 553, 381),
#  (('in', '2f', '1f', '1f-right', '1f-left'), 208, 150),
#  (('in', '2f', '1f-inner'), 503, 345),
#  (('in', '2f', '1f-left'), 611, 414),
#  (('in', '2f', '1f-left', '1f-right'), 206, 138),
#  (('in', '2f', '1f-right'), 914, 609),
#  (('in', '2f', '1f-right', '1f'), 203, 135),
#  (('in', '2f', '1f-right', '1f-inner'), 233, 164),
#  (('in', '2f', '1f-right', '1f-left'), 335, 233),
#  (('in', '2f', '2f'), 219, 162),
#  (('in', '2f', '2f-inner'), 702, 394),
#  (('in', '2f', '2f-inner', '1f'), 262, 168),
#  (('in', '2f', '2f-inner', '1f-left'), 219, 145),
#  (('in', '2f', '2f-inner', '1f-right'), 316, 211),
#  (('in', '2f', '2f-inner', '2f-left'), 221, 139),
#  (('in', '2f', '2f-inner', '2f-right'), 235, 137),
#  (('in', '2f', '2f-left'), 995, 548),
#  (('in', '2f', '2f-left', '1f'), 373, 233),
#  (('in', '2f', '2f-left', '1f', '1f-right'), 216, 146),
#  (('in', '2f', '2f-left', '1f-left'), 266, 184),
#  (('in', '2f', '2f-left', '1f-right'), 380, 260),
#  (('in', '2f', '2f-left', '2f-inner'), 245, 131),
#  (('in', '2f', '2f-left', '2f-right'), 329, 183),
#  (('in', '2f', '2f-left', 'out'), 217, 119),
#  (('in', '2f', '2f-right'), 1032, 564),
#  (('in', '2f', '2f-right', '1f'), 367, 243),
#  (('in', '2f', '2f-right', '1f', '1f-right'), 206, 152),
#  (('in', '2f', '2f-right', '1f-inner'), 210, 146),
#  (('in', '2f', '2f-right', '1f-left'), 278, 195),
#  (('in', '2f', '2f-right', '1f-right'), 378, 270),
#  (('in', '2f', '2f-right', '2f-inner'), 205, 117),
#  (('in', '2f', '2f-right', '2f-left'), 303, 175),
#  (('in', '2f', '2f-right', 'out'), 225, 130),
#  (('in', '2f', '3f'), 418, 221),
#  (('in', '2f', 'in'), 250, 174),
#  (('in', '2f', 'in', '1f'), 208, 145),
#  (('in', '2f', 'out'), 676, 363),
#  (('in', '2f-inner'), 917, 505),
#  (('in', '2f-inner', '1f'), 332, 215),
#  (('in', '2f-inner', '1f', '1f-right'), 203, 138),
#  (('in', '2f-inner', '1f-left'), 265, 182),
#  (('in', '2f-inner', '1f-right'), 382, 257),
#  (('in', '2f-inner', '2f'), 280, 155),
#  (('in', '2f-inner', '2f-left'), 350, 206),
#  (('in', '2f-inner', '2f-right'), 350, 196),
#  (('in', '2f-inner', 'out'), 204, 114),
#  (('in', '2f-left'), 1197, 657),
#  (('in', '2f-left', '1f'), 450, 279),
#  (('in', '2f-left', '1f', '1f-right'), 246, 166),
#  (('in', '2f-left', '1f-inner'), 224, 156),
#  (('in', '2f-left', '1f-left'), 308, 212),
#  (('in', '2f-left', '1f-right'), 431, 295),
#  (('in', '2f-left', '2f'), 273, 156),
#  (('in', '2f-left', '2f-inner'), 313, 172),
#  (('in', '2f-left', '2f-right'), 429, 239),
#  (('in', '2f-left', 'out'), 252, 138),
#  (('in', '2f-right'), 1304, 700),
#  (('in', '2f-right', '1f'), 477, 303),
#  (('in', '2f-right', '1f', '1f-right'), 263, 185),
#  (('in', '2f-right', '1f-inner'), 249, 170),
#  (('in', '2f-right', '1f-left'), 326, 225),
#  (('in', '2f-right', '1f-right'), 462, 321),
#  (('in', '2f-right', '2f'), 359, 201),
#  (('in', '2f-right', '2f-inner'), 253, 141),
#  (('in', '2f-right', '2f-left'), 411, 237),
#  (('in', '2f-right', 'out'), 290, 163),
#  (('in', '3f'), 756, 418),
#  (('in', '3f', '1f'), 262, 172),
#  (('in', '3f', '1f-right'), 233, 161),
#  (('in', '3f', '2f'), 220, 127),
#  (('in', '3f', '2f-right'), 213, 111),
#  (('in', 'in'), 603, 425),
#  (('in', 'in', '1f'), 491, 347),
#  (('in', 'in', '1f', '1f-right'), 234, 164),
#  (('in', 'in', '1f-right'), 295, 211),
#  (('in', 'out'), 2139, 1144),
#  (('in', 'out', '1f'), 338, 231),
#  (('in', 'out', '1f-right'), 202, 140),
#  (('in', 'out', 'in'), 410, 283),
#  (('in', 'out', 'in', '1f'), 338, 231),
#  (('in', 'out', 'in', '1f-right'), 202, 140),
#  (('in', 'out', 'out'), 513, 321),
#  (('out',), 8885, 4442),
#  (('out', '1f'), 6507, 3357),
#  (('out', '1f', '1f'), 616, 431),
#  (('out', '1f', '1f', '1f-inner'), 201, 141),
#  (('out', '1f', '1f', '1f-left'), 225, 163),
#  (('out', '1f', '1f', '1f-right'), 341, 236),
#  (('out', '1f', '1f-inner'), 1827, 1005),
#  (('out', '1f', '1f-inner', '1f'), 207, 143),
#  (('out', '1f', '1f-inner', '1f-left'), 610, 372),
#  (('out', '1f', '1f-inner', '1f-left', '1f-right'), 229, 142),
#  (('out', '1f', '1f-inner', '1f-right'), 657, 390),
#  (('out', '1f', '1f-inner', '1f-right', '1f-left'), 203, 130),
#  (('out', '1f', '1f-inner', '2f'), 432, 265),
#  (('out', '1f', '1f-inner', '2f-right'), 211, 122),
#  (('out', '1f', '1f-inner', 'out'), 407, 210),
#  (('out', '1f', '1f-left'), 1823, 1069),
#  (('out', '1f', '1f-left', '1f-inner'), 729, 429),
#  (('out', '1f', '1f-left', '1f-inner', '1f-right'), 206, 132),
#  (('out', '1f', '1f-left', '1f-right'), 717, 423),
#  (('out', '1f', '1f-left', '1f-right', '1f-inner'), 217, 134),
#  (('out', '1f', '1f-left', '2f'), 453, 282),
#  (('out', '1f', '1f-left', '2f-right'), 218, 124),
#  (('out', '1f', '1f-left', 'out'), 405, 237),
#  (('out', '1f', '1f-right'), 2607, 1486),
#  (('out', '1f', '1f-right', '1f'), 300, 218),
#  (('out', '1f', '1f-right', '1f-inner'), 805, 477),
#  (('out', '1f', '1f-right', '1f-inner', '1f-left'), 259, 159),
#  (('out', '1f', '1f-right', '1f-inner', '2f'), 201, 127),
#  (('out', '1f', '1f-right', '1f-left'), 898, 556),
#  (('out', '1f', '1f-right', '1f-left', '1f-inner'), 321, 200),
#  (('out', '1f', '1f-right', '1f-left', '2f'), 206, 135),
#  (('out', '1f', '1f-right', '1f-left', 'out'), 202, 131),
#  (('out', '1f', '1f-right', '1f-right'), 285, 192),
#  (('out', '1f', '1f-right', '2f'), 681, 397),
#  (('out', '1f', '1f-right', '2f', '2f-inner'), 218, 124),
#  (('out', '1f', '1f-right', '2f', '2f-left'), 290, 165),
#  (('out', '1f', '1f-right', '2f', '2f-right'), 308, 174),
#  (('out', '1f', '1f-right', '2f-inner'), 304, 174),
#  (('out', '1f', '1f-right', '2f-left'), 336, 190),
#  (('out', '1f', '1f-right', '2f-right'), 372, 211),
#  (('out', '1f', '1f-right', '3f'), 205, 116),
#  (('out', '1f', '1f-right', 'out'), 566, 315),
#  (('out', '1f', '2f'), 1612, 883),
#  (('out', '1f', '2f', '1f'), 349, 251),
#  (('out', '1f', '2f', '1f', '1f-right'), 229, 169),
#  (('out', '1f', '2f', '1f-inner'), 339, 235),
#  (('out', '1f', '2f', '1f-left'), 398, 277),
#  (('out', '1f', '2f', '1f-right'), 506, 350),
#  (('out', '1f', '2f', '2f-inner'), 456, 261),
#  (('out', '1f', '2f', '2f-left'), 602, 338),
#  (('out', '1f', '2f', '2f-left', '1f-right'), 232, 161),
#  (('out', '1f', '2f', '2f-left', '2f-right'), 214, 118),
#  (('out', '1f', '2f', '2f-right'), 624, 333),
#  (('out', '1f', '2f', '2f-right', '1f-right'), 224, 156),
#  (('out', '1f', '2f', '2f-right', '2f-left'), 202, 114),
#  (('out', '1f', '2f', '3f'), 273, 149),
#  (('out', '1f', '2f', 'out'), 370, 206),
#  (('out', '1f', '2f-inner'), 666, 368),
#  (('out', '1f', '2f-inner', '1f-left'), 207, 140),
#  (('out', '1f', '2f-inner', '1f-right'), 272, 183),
#  (('out', '1f', '2f-inner', '2f-left'), 274, 160),
#  (('out', '1f', '2f-inner', '2f-right'), 276, 151),
#  (('out', '1f', '2f-left'), 744, 412),
#  (('out', '1f', '2f-left', '1f-left'), 220, 153),
#  (('out', '1f', '2f-left', '1f-right'), 278, 193),
#  (('out', '1f', '2f-left', '2f-inner'), 213, 121),
#  (('out', '1f', '2f-left', '2f-right'), 279, 154),
#  (('out', '1f', '2f-right'), 806, 437),
#  (('out', '1f', '2f-right', '1f-left'), 233, 162),
#  (('out', '1f', '2f-right', '1f-right'), 287, 203),
#  (('out', '1f', '2f-right', '2f-left'), 277, 162),
#  (('out', '1f', '3f'), 453, 248),
#  (('out', '1f', 'in'), 420, 293),
#  (('out', '1f', 'in', '1f'), 368, 260),
#  (('out', '1f', 'in', '1f-right'), 230, 159),
#  (('out', '1f', 'out'), 1541, 832),
#  (('out', '1f', 'out', '1f'), 265, 183),
#  (('out', '1f', 'out', 'in'), 300, 207),
#  (('out', '1f', 'out', 'in', '1f'), 265, 183),
#  (('out', '1f', 'out', 'out'), 356, 219),
#  (('out', '1f-inner'), 2000, 1095),
#  (('out', '1f-inner', '1f'), 391, 240),
#  (('out', '1f-inner', '1f', '1f-right'), 235, 148),
#  (('out', '1f-inner', '1f-left'), 683, 420),
#  (('out', '1f-inner', '1f-left', '1f-right'), 271, 167),
#  (('out', '1f-inner', '1f-right'), 754, 449),
#  (('out', '1f-inner', '1f-right', '1f-left'), 236, 156),
#  (('out', '1f-inner', '2f'), 478, 294),
#  (('out', '1f-inner', '2f-right'), 223, 129),
#  (('out', '1f-inner', 'out'), 451, 233),
#  (('out', '1f-left'), 2015, 1167),
#  (('out', '1f-left', '1f'), 400, 240),
#  (('out', '1f-left', '1f', '1f-right'), 284, 171),
#  (('out', '1f-left', '1f-inner'), 838, 485),
#  (('out', '1f-left', '1f-inner', '1f-right'), 249, 151),
#  (('out', '1f-left', '1f-right'), 872, 508),
#  (('out', '1f-left', '1f-right', '1f-inner'), 280, 171),
#  (('out', '1f-left', '1f-right', '2f'), 211, 126),
#  (('out', '1f-left', '2f'), 506, 311),
#  (('out', '1f-left', '2f-inner'), 200, 115),
#  (('out', '1f-left', '2f-left'), 221, 133),
#  (('out', '1f-left', '2f-right'), 247, 141),
#  (('out', '1f-left', 'out'), 448, 256),
#  (('out', '1f-right'), 3144, 1778),
#  (('out', '1f-right', '1f'), 884, 546),
#  (('out', '1f-right', '1f', '1f-inner'), 312, 193),
#  (('out', '1f-right', '1f', '1f-left'), 379, 247),
#  (('out', '1f-right', '1f', '1f-right'), 207, 146),
#  (('out', '1f-right', '1f', '2f'), 213, 129),
#  (('out', '1f-right', '1f-inner'), 1002, 589),
#  (('out', '1f-right', '1f-inner', '1f-left'), 332, 208),
#  (('out', '1f-right', '1f-inner', '2f'), 247, 155),
#  (('out', '1f-right', '1f-inner', 'out'), 238, 135),
#  (('out', '1f-right', '1f-left'), 1136, 700),
#  (('out', '1f-right', '1f-left', '1f-inner'), 414, 250),
#  (('out', '1f-right', '1f-left', '2f'), 265, 172),
#  (('out', '1f-right', '1f-left', 'out'), 254, 158),
#  (('out', '1f-right', '1f-right'), 336, 232),
#  (('out', '1f-right', '2f'), 836, 486),
#  (('out', '1f-right', '2f', '1f-left'), 221, 152),
#  (('out', '1f-right', '2f', '1f-right'), 204, 150),
#  (('out', '1f-right', '2f', '2f-inner'), 255, 151),
#  (('out', '1f-right', '2f', '2f-left'), 334, 193),
#  (('out', '1f-right', '2f', '2f-right'), 365, 198),
#  (('out', '1f-right', '2f-inner'), 357, 209),
#  (('out', '1f-right', '2f-left'), 395, 228),
#  (('out', '1f-right', '2f-right'), 445, 248),
#  (('out', '1f-right', '3f'), 251, 146),
#  (('out', '1f-right', 'in'), 204, 148),
#  (('out', '1f-right', 'out'), 665, 375),
#  (('out', '2f'), 3188, 1664),
#  (('out', '2f', '1f'), 1094, 666),
#  (('out', '2f', '1f', '1f-inner'), 279, 197),
#  (('out', '2f', '1f', '1f-left'), 360, 249),
#  (('out', '2f', '1f', '1f-right'), 553, 381),
#  (('out', '2f', '1f', '1f-right', '1f-left'), 208, 150),
#  (('out', '2f', '1f-inner'), 503, 345),
#  (('out', '2f', '1f-left'), 611, 414),
#  (('out', '2f', '1f-left', '1f-right'), 206, 138),
#  (('out', '2f', '1f-right'), 914, 609),
#  (('out', '2f', '1f-right', '1f'), 203, 135),
#  (('out', '2f', '1f-right', '1f-inner'), 233, 164),
#  (('out', '2f', '1f-right', '1f-left'), 335, 233),
#  (('out', '2f', '2f'), 219, 162),
#  (('out', '2f', '2f-inner'), 702, 394),
#  (('out', '2f', '2f-inner', '1f'), 262, 168),
#  (('out', '2f', '2f-inner', '1f-left'), 219, 145),
#  (('out', '2f', '2f-inner', '1f-right'), 316, 211),
#  (('out', '2f', '2f-inner', '2f-left'), 221, 139),
#  (('out', '2f', '2f-inner', '2f-right'), 235, 137),
#  (('out', '2f', '2f-left'), 995, 548),
#  (('out', '2f', '2f-left', '1f'), 373, 233),
#  (('out', '2f', '2f-left', '1f', '1f-right'), 216, 146),
#  (('out', '2f', '2f-left', '1f-left'), 266, 184),
#  (('out', '2f', '2f-left', '1f-right'), 380, 260),
#  (('out', '2f', '2f-left', '2f-inner'), 245, 131),
#  (('out', '2f', '2f-left', '2f-right'), 329, 183),
#  (('out', '2f', '2f-left', 'out'), 217, 119),
#  (('out', '2f', '2f-right'), 1032, 564),
#  (('out', '2f', '2f-right', '1f'), 367, 243),
#  (('out', '2f', '2f-right', '1f', '1f-right'), 206, 152),
#  (('out', '2f', '2f-right', '1f-inner'), 210, 146),
#  (('out', '2f', '2f-right', '1f-left'), 278, 195),
#  (('out', '2f', '2f-right', '1f-right'), 378, 270),
#  (('out', '2f', '2f-right', '2f-inner'), 205, 117),
#  (('out', '2f', '2f-right', '2f-left'), 303, 175),
#  (('out', '2f', '2f-right', 'out'), 225, 130),
#  (('out', '2f', '3f'), 418, 221),
#  (('out', '2f', 'in'), 250, 174),
#  (('out', '2f', 'in', '1f'), 208, 145),
#  (('out', '2f', 'out'), 676, 363),
#  (('out', '2f-inner'), 917, 505),
#  (('out', '2f-inner', '1f'), 332, 215),
#  (('out', '2f-inner', '1f', '1f-right'), 203, 138),
#  (('out', '2f-inner', '1f-left'), 265, 182),
#  (('out', '2f-inner', '1f-right'), 382, 257),
#  (('out', '2f-inner', '2f'), 280, 155),
#  (('out', '2f-inner', '2f-left'), 350, 206),
#  (('out', '2f-inner', '2f-right'), 350, 196),
#  (('out', '2f-inner', 'out'), 204, 114),
#  (('out', '2f-left'), 1197, 657),
#  (('out', '2f-left', '1f'), 450, 279),
#  (('out', '2f-left', '1f', '1f-right'), 246, 166),
#  (('out', '2f-left', '1f-inner'), 224, 156),
#  (('out', '2f-left', '1f-left'), 308, 212),
#  (('out', '2f-left', '1f-right'), 431, 295),
#  (('out', '2f-left', '2f'), 273, 156),
#  (('out', '2f-left', '2f-inner'), 313, 172),
#  (('out', '2f-left', '2f-right'), 429, 239),
#  (('out', '2f-left', 'out'), 252, 138),
#  (('out', '2f-right'), 1304, 700),
#  (('out', '2f-right', '1f'), 477, 303),
#  (('out', '2f-right', '1f', '1f-right'), 263, 185),
#  (('out', '2f-right', '1f-inner'), 249, 170),
#  (('out', '2f-right', '1f-left'), 326, 225),
#  (('out', '2f-right', '1f-right'), 462, 321),
#  (('out', '2f-right', '2f'), 359, 201),
#  (('out', '2f-right', '2f-inner'), 253, 141),
#  (('out', '2f-right', '2f-left'), 411, 237),
#  (('out', '2f-right', 'out'), 290, 163),
#  (('out', '3f'), 756, 418),
#  (('out', '3f', '1f'), 262, 172),
#  (('out', '3f', '1f-right'), 233, 161),
#  (('out', '3f', '2f'), 220, 127),
#  (('out', '3f', '2f-right'), 213, 111),
#  (('out', 'in'), 8882, 4439),
#  (('out', 'in', '1f'), 6507, 3357),
#  (('out', 'in', '1f', '1f'), 616, 431),
#  (('out', 'in', '1f', '1f', '1f-inner'), 201, 141),
#  (('out', 'in', '1f', '1f', '1f-left'), 225, 163),
#  (('out', 'in', '1f', '1f', '1f-right'), 341, 236),
#  (('out', 'in', '1f', '1f-inner'), 1827, 1005),
#  (('out', 'in', '1f', '1f-inner', '1f'), 207, 143),
#  (('out', 'in', '1f', '1f-inner', '1f-left'), 610, 372),
#  (('out', 'in', '1f', '1f-inner', '1f-left', '1f-right'), 229, 142),
#  (('out', 'in', '1f', '1f-inner', '1f-right'), 657, 390),
#  (('out', 'in', '1f', '1f-inner', '1f-right', '1f-left'), 203, 130),
#  (('out', 'in', '1f', '1f-inner', '2f'), 432, 265),
#  (('out', 'in', '1f', '1f-inner', '2f-right'), 211, 122),
#  (('out', 'in', '1f', '1f-inner', 'out'), 407, 210),
#  (('out', 'in', '1f', '1f-left'), 1823, 1069),
#  (('out', 'in', '1f', '1f-left', '1f-inner'), 729, 429),
#  (('out', 'in', '1f', '1f-left', '1f-inner', '1f-right'), 206, 132),
#  (('out', 'in', '1f', '1f-left', '1f-right'), 717, 423),
#  (('out', 'in', '1f', '1f-left', '1f-right', '1f-inner'), 217, 134),
#  (('out', 'in', '1f', '1f-left', '2f'), 453, 282),
#  (('out', 'in', '1f', '1f-left', '2f-right'), 218, 124),
#  (('out', 'in', '1f', '1f-left', 'out'), 405, 237),
#  (('out', 'in', '1f', '1f-right'), 2607, 1486),
#  (('out', 'in', '1f', '1f-right', '1f'), 300, 218),
#  (('out', 'in', '1f', '1f-right', '1f-inner'), 805, 477),
#  (('out', 'in', '1f', '1f-right', '1f-inner', '1f-left'), 259, 159),
#  (('out', 'in', '1f', '1f-right', '1f-inner', '2f'), 201, 127),
#  (('out', 'in', '1f', '1f-right', '1f-left'), 898, 556),
#  (('out', 'in', '1f', '1f-right', '1f-left', '1f-inner'), 321, 200),
#  (('out', 'in', '1f', '1f-right', '1f-left', '2f'), 206, 135),
#  (('out', 'in', '1f', '1f-right', '1f-left', 'out'), 202, 131),
#  (('out', 'in', '1f', '1f-right', '1f-right'), 285, 192),
#  (('out', 'in', '1f', '1f-right', '2f'), 681, 397),
#  (('out', 'in', '1f', '1f-right', '2f', '2f-inner'), 218, 124),
#  (('out', 'in', '1f', '1f-right', '2f', '2f-left'), 290, 165),
#  (('out', 'in', '1f', '1f-right', '2f', '2f-right'), 308, 174),
#  (('out', 'in', '1f', '1f-right', '2f-inner'), 304, 174),
#  (('out', 'in', '1f', '1f-right', '2f-left'), 336, 190),
#  (('out', 'in', '1f', '1f-right', '2f-right'), 372, 211),
#  (('out', 'in', '1f', '1f-right', '3f'), 205, 116),
#  (('out', 'in', '1f', '1f-right', 'out'), 566, 315),
#  (('out', 'in', '1f', '2f'), 1612, 883),
#  (('out', 'in', '1f', '2f', '1f'), 349, 251),
#  (('out', 'in', '1f', '2f', '1f', '1f-right'), 229, 169),
#  (('out', 'in', '1f', '2f', '1f-inner'), 339, 235),
#  (('out', 'in', '1f', '2f', '1f-left'), 398, 277),
#  (('out', 'in', '1f', '2f', '1f-right'), 506, 350),
#  (('out', 'in', '1f', '2f', '2f-inner'), 456, 261),
#  (('out', 'in', '1f', '2f', '2f-left'), 602, 338),
#  (('out', 'in', '1f', '2f', '2f-left', '1f-right'), 232, 161),
#  (('out', 'in', '1f', '2f', '2f-left', '2f-right'), 214, 118),
#  (('out', 'in', '1f', '2f', '2f-right'), 624, 333),
#  (('out', 'in', '1f', '2f', '2f-right', '1f-right'), 224, 156),
#  (('out', 'in', '1f', '2f', '2f-right', '2f-left'), 202, 114),
#  (('out', 'in', '1f', '2f', '3f'), 273, 149),
#  (('out', 'in', '1f', '2f', 'out'), 370, 206),
#  (('out', 'in', '1f', '2f-inner'), 666, 368),
#  (('out', 'in', '1f', '2f-inner', '1f-left'), 207, 140),
#  (('out', 'in', '1f', '2f-inner', '1f-right'), 272, 183),
#  (('out', 'in', '1f', '2f-inner', '2f-left'), 274, 160),
#  (('out', 'in', '1f', '2f-inner', '2f-right'), 276, 151),
#  (('out', 'in', '1f', '2f-left'), 744, 412),
#  (('out', 'in', '1f', '2f-left', '1f-left'), 220, 153),
#  (('out', 'in', '1f', '2f-left', '1f-right'), 278, 193),
#  (('out', 'in', '1f', '2f-left', '2f-inner'), 213, 121),
#  (('out', 'in', '1f', '2f-left', '2f-right'), 279, 154),
#  (('out', 'in', '1f', '2f-right'), 806, 437),
#  (('out', 'in', '1f', '2f-right', '1f-left'), 233, 162),
#  (('out', 'in', '1f', '2f-right', '1f-right'), 287, 203),
#  (('out', 'in', '1f', '2f-right', '2f-left'), 277, 162),
#  (('out', 'in', '1f', '3f'), 453, 248),
#  (('out', 'in', '1f', 'in'), 420, 293),
#  (('out', 'in', '1f', 'in', '1f'), 368, 260),
#  (('out', 'in', '1f', 'in', '1f-right'), 230, 159),
#  (('out', 'in', '1f', 'out'), 1541, 832),
#  (('out', 'in', '1f', 'out', '1f'), 265, 183),
#  (('out', 'in', '1f', 'out', 'in'), 300, 207),
#  (('out', 'in', '1f', 'out', 'in', '1f'), 265, 183),
#  (('out', 'in', '1f', 'out', 'out'), 356, 219),
#  (('out', 'in', '1f-inner'), 2000, 1095),
#  (('out', 'in', '1f-inner', '1f'), 391, 240),
#  (('out', 'in', '1f-inner', '1f', '1f-right'), 235, 148),
#  (('out', 'in', '1f-inner', '1f-left'), 683, 420),
#  (('out', 'in', '1f-inner', '1f-left', '1f-right'), 271, 167),
#  (('out', 'in', '1f-inner', '1f-right'), 754, 449),
#  (('out', 'in', '1f-inner', '1f-right', '1f-left'), 236, 156),
#  (('out', 'in', '1f-inner', '2f'), 478, 294),
#  (('out', 'in', '1f-inner', '2f-right'), 223, 129),
#  (('out', 'in', '1f-inner', 'out'), 451, 233),
#  (('out', 'in', '1f-left'), 2015, 1167),
#  (('out', 'in', '1f-left', '1f'), 400, 240),
#  (('out', 'in', '1f-left', '1f', '1f-right'), 284, 171),
#  (('out', 'in', '1f-left', '1f-inner'), 838, 485),
#  (('out', 'in', '1f-left', '1f-inner', '1f-right'), 249, 151),
#  (('out', 'in', '1f-left', '1f-right'), 872, 508),
#  (('out', 'in', '1f-left', '1f-right', '1f-inner'), 280, 171),
#  (('out', 'in', '1f-left', '1f-right', '2f'), 211, 126),
#  (('out', 'in', '1f-left', '2f'), 506, 311),
#  (('out', 'in', '1f-left', '2f-inner'), 200, 115),
#  (('out', 'in', '1f-left', '2f-left'), 221, 133),
#  (('out', 'in', '1f-left', '2f-right'), 247, 141),
#  (('out', 'in', '1f-left', 'out'), 448, 256),
#  (('out', 'in', '1f-right'), 3144, 1778),
#  (('out', 'in', '1f-right', '1f'), 884, 546),
#  (('out', 'in', '1f-right', '1f', '1f-inner'), 312, 193),
#  (('out', 'in', '1f-right', '1f', '1f-left'), 379, 247),
#  (('out', 'in', '1f-right', '1f', '1f-right'), 207, 146),
#  (('out', 'in', '1f-right', '1f', '2f'), 213, 129),
#  (('out', 'in', '1f-right', '1f-inner'), 1002, 589),
#  (('out', 'in', '1f-right', '1f-inner', '1f-left'), 332, 208),
#  (('out', 'in', '1f-right', '1f-inner', '2f'), 247, 155),
#  (('out', 'in', '1f-right', '1f-inner', 'out'), 238, 135),
#  (('out', 'in', '1f-right', '1f-left'), 1136, 700),
#  (('out', 'in', '1f-right', '1f-left', '1f-inner'), 414, 250),
#  (('out', 'in', '1f-right', '1f-left', '2f'), 265, 172),
#  (('out', 'in', '1f-right', '1f-left', 'out'), 254, 158),
#  (('out', 'in', '1f-right', '1f-right'), 336, 232),
#  (('out', 'in', '1f-right', '2f'), 836, 486),
#  (('out', 'in', '1f-right', '2f', '1f-left'), 221, 152),
#  (('out', 'in', '1f-right', '2f', '1f-right'), 204, 150),
#  (('out', 'in', '1f-right', '2f', '2f-inner'), 255, 151),
#  (('out', 'in', '1f-right', '2f', '2f-left'), 334, 193),
#  (('out', 'in', '1f-right', '2f', '2f-right'), 365, 198),
#  (('out', 'in', '1f-right', '2f-inner'), 357, 209),
#  (('out', 'in', '1f-right', '2f-left'), 395, 228),
#  (('out', 'in', '1f-right', '2f-right'), 445, 248),
#  (('out', 'in', '1f-right', '3f'), 251, 146),
#  (('out', 'in', '1f-right', 'in'), 204, 148),
#  (('out', 'in', '1f-right', 'out'), 665, 375),
#  (('out', 'in', '2f'), 3188, 1664),
#  (('out', 'in', '2f', '1f'), 1094, 666),
#  (('out', 'in', '2f', '1f', '1f-inner'), 279, 197),
#  (('out', 'in', '2f', '1f', '1f-left'), 360, 249),
#  (('out', 'in', '2f', '1f', '1f-right'), 553, 381),
#  (('out', 'in', '2f', '1f', '1f-right', '1f-left'), 208, 150),
#  (('out', 'in', '2f', '1f-inner'), 503, 345),
#  (('out', 'in', '2f', '1f-left'), 611, 414),
#  (('out', 'in', '2f', '1f-left', '1f-right'), 206, 138),
#  (('out', 'in', '2f', '1f-right'), 914, 609),
#  (('out', 'in', '2f', '1f-right', '1f'), 203, 135),
#  (('out', 'in', '2f', '1f-right', '1f-inner'), 233, 164),
#  (('out', 'in', '2f', '1f-right', '1f-left'), 335, 233),
#  (('out', 'in', '2f', '2f'), 219, 162),
#  (('out', 'in', '2f', '2f-inner'), 702, 394),
#  (('out', 'in', '2f', '2f-inner', '1f'), 262, 168),
#  (('out', 'in', '2f', '2f-inner', '1f-left'), 219, 145),
#  (('out', 'in', '2f', '2f-inner', '1f-right'), 316, 211),
#  (('out', 'in', '2f', '2f-inner', '2f-left'), 221, 139),
#  (('out', 'in', '2f', '2f-inner', '2f-right'), 235, 137),
#  (('out', 'in', '2f', '2f-left'), 995, 548),
#  (('out', 'in', '2f', '2f-left', '1f'), 373, 233),
#  (('out', 'in', '2f', '2f-left', '1f', '1f-right'), 216, 146),
#  (('out', 'in', '2f', '2f-left', '1f-left'), 266, 184),
#  (('out', 'in', '2f', '2f-left', '1f-right'), 380, 260),
#  (('out', 'in', '2f', '2f-left', '2f-inner'), 245, 131),
#  (('out', 'in', '2f', '2f-left', '2f-right'), 329, 183),
#  (('out', 'in', '2f', '2f-left', 'out'), 217, 119),
#  (('out', 'in', '2f', '2f-right'), 1032, 564),
#  (('out', 'in', '2f', '2f-right', '1f'), 367, 243),
#  (('out', 'in', '2f', '2f-right', '1f', '1f-right'), 206, 152),
#  (('out', 'in', '2f', '2f-right', '1f-inner'), 210, 146),
#  (('out', 'in', '2f', '2f-right', '1f-left'), 278, 195),
#  (('out', 'in', '2f', '2f-right', '1f-right'), 378, 270),
#  (('out', 'in', '2f', '2f-right', '2f-inner'), 205, 117),
#  (('out', 'in', '2f', '2f-right', '2f-left'), 303, 175),
#  (('out', 'in', '2f', '2f-right', 'out'), 225, 130),
#  (('out', 'in', '2f', '3f'), 418, 221),
#  (('out', 'in', '2f', 'in'), 250, 174),
#  (('out', 'in', '2f', 'in', '1f'), 208, 145),
#  (('out', 'in', '2f', 'out'), 676, 363),
#  (('out', 'in', '2f-inner'), 917, 505),
#  (('out', 'in', '2f-inner', '1f'), 332, 215),
#  (('out', 'in', '2f-inner', '1f', '1f-right'), 203, 138),
#  (('out', 'in', '2f-inner', '1f-left'), 265, 182),
#  (('out', 'in', '2f-inner', '1f-right'), 382, 257),
#  (('out', 'in', '2f-inner', '2f'), 280, 155),
#  (('out', 'in', '2f-inner', '2f-left'), 350, 206),
#  (('out', 'in', '2f-inner', '2f-right'), 350, 196),
#  (('out', 'in', '2f-inner', 'out'), 204, 114),
#  (('out', 'in', '2f-left'), 1197, 657),
#  (('out', 'in', '2f-left', '1f'), 450, 279),
#  (('out', 'in', '2f-left', '1f', '1f-right'), 246, 166),
#  (('out', 'in', '2f-left', '1f-inner'), 224, 156),
#  (('out', 'in', '2f-left', '1f-left'), 308, 212),
#  (('out', 'in', '2f-left', '1f-right'), 431, 295),
#  (('out', 'in', '2f-left', '2f'), 273, 156),
#  (('out', 'in', '2f-left', '2f-inner'), 313, 172),
#  (('out', 'in', '2f-left', '2f-right'), 429, 239),
#  (('out', 'in', '2f-left', 'out'), 252, 138),
#  (('out', 'in', '2f-right'), 1304, 700),
#  (('out', 'in', '2f-right', '1f'), 477, 303),
#  (('out', 'in', '2f-right', '1f', '1f-right'), 263, 185),
#  (('out', 'in', '2f-right', '1f-inner'), 249, 170),
#  (('out', 'in', '2f-right', '1f-left'), 326, 225),
#  (('out', 'in', '2f-right', '1f-right'), 462, 321),
#  (('out', 'in', '2f-right', '2f'), 359, 201),
#  (('out', 'in', '2f-right', '2f-inner'), 253, 141),
#  (('out', 'in', '2f-right', '2f-left'), 411, 237),
#  (('out', 'in', '2f-right', 'out'), 290, 163),
#  (('out', 'in', '3f'), 756, 418),
#  (('out', 'in', '3f', '1f'), 262, 172),
#  (('out', 'in', '3f', '1f-right'), 233, 161),
#  (('out', 'in', '3f', '2f'), 220, 127),
#  (('out', 'in', '3f', '2f-right'), 213, 111),
#  (('out', 'in', 'in'), 603, 425),
#  (('out', 'in', 'in', '1f'), 491, 347),
#  (('out', 'in', 'in', '1f', '1f-right'), 234, 164),
#  (('out', 'in', 'in', '1f-right'), 295, 211),
#  (('out', 'in', 'out'), 2136, 1141),
#  (('out', 'in', 'out', '1f'), 338, 231),
#  (('out', 'in', 'out', '1f-right'), 202, 140),
#  (('out', 'in', 'out', 'in'), 410, 283),
#  (('out', 'in', 'out', 'in', '1f'), 338, 231),
#  (('out', 'in', 'out', 'in', '1f-right'), 202, 140),
#  (('out', 'in', 'out', 'out'), 511, 319),
#  (('out', 'out'), 3301, 1698),
#  (('out', 'out', '1f'), 1390, 771),
#  (('out', 'out', '1f', '1f-inner'), 348, 194),
#  (('out', 'out', '1f', '1f-left'), 325, 207),
#  (('out', 'out', '1f', '1f-right'), 499, 298),
#  (('out', 'out', '1f', '2f'), 305, 174),
#  (('out', 'out', '1f', 'out'), 332, 205),
#  (('out', 'out', '1f-inner'), 384, 215),
#  (('out', 'out', '1f-left'), 370, 229),
#  (('out', 'out', '1f-right'), 603, 358),
#  (('out', 'out', '2f'), 578, 309),
#  (('out', 'out', '2f-right'), 229, 126),
#  (('out', 'out', 'in'), 1937, 1048),
#  (('out', 'out', 'in', '1f'), 1390, 771),
#  (('out', 'out', 'in', '1f', '1f-inner'), 348, 194),
#  (('out', 'out', 'in', '1f', '1f-left'), 325, 207),
#  (('out', 'out', 'in', '1f', '1f-right'), 499, 298),
#  (('out', 'out', 'in', '1f', '2f'), 305, 174),
#  (('out', 'out', 'in', '1f', 'out'), 332, 205),
#  (('out', 'out', 'in', '1f-inner'), 384, 215),
#  (('out', 'out', 'in', '1f-left'), 370, 229),
#  (('out', 'out', 'in', '1f-right'), 603, 358),
#  (('out', 'out', 'in', '2f'), 578, 309),
#  (('out', 'out', 'in', '2f-right'), 229, 126),
#  (('out', 'out', 'in', 'out'), 482, 300),
#  (('out', 'out', 'out'), 994, 594),
#  (('out', 'out', 'out', '1f'), 302, 204),
#  (('out', 'out', 'out', 'in'), 442, 301),
#  (('out', 'out', 'out', 'in', '1f'), 302, 204),
#  (('out', 'out', 'out', 'out'), 365, 259)}

# %%
freq_seqs_sorted = sorted(freq_seqs, key=lambda tup: tup[1], reverse=True)

# %%
for x in freq_seqs_sorted:
    if (len(x[0]) >= 4):
#         if (x[0][0] != 'out') & (x[0][0] != 'in'):
        print(x)
# Out:
# (('out', 'in', '1f', '1f-right'), 2607, 1486)
# (('out', 'in', '1f', '1f-inner'), 1827, 1005)
# (('out', 'in', '1f', '1f-left'), 1823, 1069)
# (('out', 'in', '1f', '2f'), 1612, 883)
# (('out', 'in', '1f', 'out'), 1541, 832)
# (('out', 'out', 'in', '1f'), 1390, 771)
# (('out', 'in', '1f-right', '1f-left'), 1136, 700)
# (('out', 'in', '2f', '1f'), 1094, 666)
# (('out', 'in', '2f', '2f-right'), 1032, 564)
# (('out', 'in', '1f-right', '1f-inner'), 1002, 589)
# (('out', 'in', '2f', '2f-left'), 995, 548)
# (('out', 'in', '2f', '1f-right'), 914, 609)
# (('out', 'in', '1f', '1f-right', '1f-left'), 898, 556)
# (('out', '1f', '1f-right', '1f-left'), 898, 556)
# (('in', '1f', '1f-right', '1f-left'), 898, 556)
# (('out', 'in', '1f-right', '1f'), 884, 546)
# (('out', 'in', '1f-left', '1f-right'), 872, 508)
# (('out', 'in', '1f-left', '1f-inner'), 838, 485)
# (('out', 'in', '1f-right', '2f'), 836, 486)
# (('out', 'in', '1f', '2f-right'), 806, 437)
# (('in', '1f', '1f-right', '1f-inner'), 805, 477)
# (('out', '1f', '1f-right', '1f-inner'), 805, 477)
# (('out', 'in', '1f', '1f-right', '1f-inner'), 805, 477)
# (('out', 'in', '1f-inner', '1f-right'), 754, 449)
# (('out', 'in', '1f', '2f-left'), 744, 412)
# (('out', 'in', '1f', '1f-left', '1f-inner'), 729, 429)
# (('out', '1f', '1f-left', '1f-inner'), 729, 429)
# (('in', '1f', '1f-left', '1f-inner'), 729, 429)
# (('in', '1f', '1f-left', '1f-right'), 717, 423)
# (('out', '1f', '1f-left', '1f-right'), 717, 423)
# (('out', 'in', '1f', '1f-left', '1f-right'), 717, 423)
# (('out', 'in', '2f', '2f-inner'), 702, 394)
# (('out', 'in', '1f-inner', '1f-left'), 683, 420)
# (('out', '1f', '1f-right', '2f'), 681, 397)
# (('in', '1f', '1f-right', '2f'), 681, 397)
# (('out', 'in', '1f', '1f-right', '2f'), 681, 397)
# (('out', 'in', '2f', 'out'), 676, 363)
# (('out', 'in', '1f', '2f-inner'), 666, 368)
# (('out', 'in', '1f-right', 'out'), 665, 375)
# (('out', '1f', '1f-inner', '1f-right'), 657, 390)
# (('out', 'in', '1f', '1f-inner', '1f-right'), 657, 390)
# (('in', '1f', '1f-inner', '1f-right'), 657, 390)
# (('out', 'in', '1f', '2f', '2f-right'), 624, 333)
# (('in', '1f', '2f', '2f-right'), 624, 333)
# (('out', '1f', '2f', '2f-right'), 624, 333)
# (('out', 'in', '1f', '1f'), 616, 431)
# (('out', 'in', '2f', '1f-left'), 611, 414)
# (('in', '1f', '1f-inner', '1f-left'), 610, 372)
# (('out', '1f', '1f-inner', '1f-left'), 610, 372)
# (('out', 'in', '1f', '1f-inner', '1f-left'), 610, 372)
# (('out', 'out', 'in', '1f-right'), 603, 358)
# (('in', '1f', '2f', '2f-left'), 602, 338)
# (('out', 'in', '1f', '2f', '2f-left'), 602, 338)
# (('out', '1f', '2f', '2f-left'), 602, 338)
# (('out', 'out', 'in', '2f'), 578, 309)
# (('out', '1f', '1f-right', 'out'), 566, 315)
# (('in', '1f', '1f-right', 'out'), 566, 315)
# (('out', 'in', '1f', '1f-right', 'out'), 566, 315)
# (('in', '2f', '1f', '1f-right'), 553, 381)
# (('out', 'in', '2f', '1f', '1f-right'), 553, 381)
# (('out', '2f', '1f', '1f-right'), 553, 381)
# (('out', 'in', 'out', 'out'), 511, 319)
# (('out', 'in', '1f-left', '2f'), 506, 311)
# (('out', 'in', '1f', '2f', '1f-right'), 506, 350)
# (('out', '1f', '2f', '1f-right'), 506, 350)
# (('in', '1f', '2f', '1f-right'), 506, 350)
# (('out', 'in', '2f', '1f-inner'), 503, 345)
# (('out', 'out', '1f', '1f-right'), 499, 298)
# (('out', 'out', 'in', '1f', '1f-right'), 499, 298)
# (('out', 'in', 'in', '1f'), 491, 347)
# (('out', 'out', 'in', 'out'), 482, 300)
# (('out', 'in', '1f-inner', '2f'), 478, 294)
# (('out', 'in', '2f-right', '1f'), 477, 303)
# (('out', 'in', '2f-right', '1f-right'), 462, 321)
# (('in', '1f', '2f', '2f-inner'), 456, 261)
# (('out', '1f', '2f', '2f-inner'), 456, 261)
# (('out', 'in', '1f', '2f', '2f-inner'), 456, 261)
# (('out', '1f', '1f-left', '2f'), 453, 282)
# (('in', '1f', '1f-left', '2f'), 453, 282)
# (('out', 'in', '1f', '1f-left', '2f'), 453, 282)
# (('out', 'in', '1f', '3f'), 453, 248)
# (('out', 'in', '1f-inner', 'out'), 451, 233)
# (('out', 'in', '2f-left', '1f'), 450, 279)
# (('out', 'in', '1f-left', 'out'), 448, 256)
# (('out', 'in', '1f-right', '2f-right'), 445, 248)
# (('out', 'out', 'out', 'in'), 442, 301)
# (('out', 'in', '1f', '1f-inner', '2f'), 432, 265)
# (('in', '1f', '1f-inner', '2f'), 432, 265)
# (('out', '1f', '1f-inner', '2f'), 432, 265)
# (('out', 'in', '2f-left', '1f-right'), 431, 295)
# (('out', 'in', '2f-left', '2f-right'), 429, 239)
# (('out', 'in', '1f', 'in'), 420, 293)
# (('out', 'in', '2f', '3f'), 418, 221)
# (('out', '1f-right', '1f-left', '1f-inner'), 414, 250)
# (('out', 'in', '1f-right', '1f-left', '1f-inner'), 414, 250)
# (('in', '1f-right', '1f-left', '1f-inner'), 414, 250)
# (('out', 'in', '2f-right', '2f-left'), 411, 237)
# (('out', 'in', 'out', 'in'), 410, 283)
# (('in', '1f', '1f-inner', 'out'), 407, 210)
# (('out', '1f', '1f-inner', 'out'), 407, 210)
# (('out', 'in', '1f', '1f-inner', 'out'), 407, 210)
# (('out', 'in', '1f', '1f-left', 'out'), 405, 237)
# (('in', '1f', '1f-left', 'out'), 405, 237)
# (('out', '1f', '1f-left', 'out'), 405, 237)
# (('out', 'in', '1f-left', '1f'), 400, 240)
# (('out', 'in', '1f', '2f', '1f-left'), 398, 277)
# (('out', '1f', '2f', '1f-left'), 398, 277)
# (('in', '1f', '2f', '1f-left'), 398, 277)
# (('out', 'in', '1f-right', '2f-left'), 395, 228)
# (('out', 'in', '1f-inner', '1f'), 391, 240)
# (('out', 'out', 'in', '1f-inner'), 384, 215)
# (('out', 'in', '2f-inner', '1f-right'), 382, 257)
# (('in', '2f', '2f-left', '1f-right'), 380, 260)
# (('out', '2f', '2f-left', '1f-right'), 380, 260)
# (('out', 'in', '2f', '2f-left', '1f-right'), 380, 260)
# (('out', 'in', '1f-right', '1f', '1f-left'), 379, 247)
# (('in', '1f-right', '1f', '1f-left'), 379, 247)
# (('out', '1f-right', '1f', '1f-left'), 379, 247)
# (('out', '2f', '2f-right', '1f-right'), 378, 270)
# (('out', 'in', '2f', '2f-right', '1f-right'), 378, 270)
# (('in', '2f', '2f-right', '1f-right'), 378, 270)
# (('in', '2f', '2f-left', '1f'), 373, 233)
# (('out', '2f', '2f-left', '1f'), 373, 233)
# (('out', 'in', '2f', '2f-left', '1f'), 373, 233)
# (('out', 'in', '1f', '1f-right', '2f-right'), 372, 211)
# (('out', '1f', '1f-right', '2f-right'), 372, 211)
# (('in', '1f', '1f-right', '2f-right'), 372, 211)
# (('out', 'in', '1f', '2f', 'out'), 370, 206)
# (('out', '1f', '2f', 'out'), 370, 206)
# (('out', 'out', 'in', '1f-left'), 370, 229)
# (('in', '1f', '2f', 'out'), 370, 206)
# (('out', 'in', '1f', 'in', '1f'), 368, 260)
# (('out', '1f', 'in', '1f'), 368, 260)
# (('in', '1f', 'in', '1f'), 368, 260)
# (('in', '2f', '2f-right', '1f'), 367, 243)
# (('out', 'in', '2f', '2f-right', '1f'), 367, 243)
# (('out', '2f', '2f-right', '1f'), 367, 243)
# (('out', '1f-right', '2f', '2f-right'), 365, 198)
# (('in', '1f-right', '2f', '2f-right'), 365, 198)
# (('out', 'in', '1f-right', '2f', '2f-right'), 365, 198)
# (('out', 'out', 'out', 'out'), 365, 259)
# (('out', '2f', '1f', '1f-left'), 360, 249)
# (('in', '2f', '1f', '1f-left'), 360, 249)
# (('out', 'in', '2f', '1f', '1f-left'), 360, 249)
# (('out', 'in', '2f-right', '2f'), 359, 201)
# (('out', 'in', '1f-right', '2f-inner'), 357, 209)
# (('in', '1f', 'out', 'out'), 357, 220)
# (('out', 'in', '1f', 'out', 'out'), 356, 219)
# (('out', '1f', 'out', 'out'), 356, 219)
# (('out', 'in', '2f-inner', '2f-right'), 350, 196)
# (('out', 'in', '2f-inner', '2f-left'), 350, 206)
# (('out', '1f', '2f', '1f'), 349, 251)
# (('out', 'in', '1f', '2f', '1f'), 349, 251)
# (('in', '1f', '2f', '1f'), 349, 251)
# (('out', 'out', 'in', '1f', '1f-inner'), 348, 194)
# (('out', 'out', '1f', '1f-inner'), 348, 194)
# (('out', '1f', '1f', '1f-right'), 341, 236)
# (('out', 'in', '1f', '1f', '1f-right'), 341, 236)
# (('in', '1f', '1f', '1f-right'), 341, 236)
# (('in', '1f', '2f', '1f-inner'), 339, 235)
# (('out', 'in', '1f', '2f', '1f-inner'), 339, 235)
# (('out', '1f', '2f', '1f-inner'), 339, 235)
# (('in', 'out', 'in', '1f'), 338, 231)
# (('out', 'in', 'out', 'in', '1f'), 338, 231)
# (('out', 'in', 'out', '1f'), 338, 231)
# (('out', '1f', '1f-right', '2f-left'), 336, 190)
# (('out', 'in', '1f-right', '1f-right'), 336, 232)
# (('in', '1f', '1f-right', '2f-left'), 336, 190)
# (('out', 'in', '1f', '1f-right', '2f-left'), 336, 190)
# (('out', '2f', '1f-right', '1f-left'), 335, 233)
# (('out', 'in', '2f', '1f-right', '1f-left'), 335, 233)
# (('in', '2f', '1f-right', '1f-left'), 335, 233)
# (('out', '1f-right', '2f', '2f-left'), 334, 193)
# (('in', '1f-right', '2f', '2f-left'), 334, 193)
# (('out', 'in', '1f-right', '2f', '2f-left'), 334, 193)
# (('out', 'out', 'in', '1f', 'out'), 332, 205)
# (('out', '1f-right', '1f-inner', '1f-left'), 332, 208)
# (('out', 'in', '2f-inner', '1f'), 332, 215)
# (('out', 'in', '1f-right', '1f-inner', '1f-left'), 332, 208)
# (('out', 'out', '1f', 'out'), 332, 205)
# (('in', '1f-right', '1f-inner', '1f-left'), 332, 208)
# (('in', '2f', '2f-left', '2f-right'), 329, 183)
# (('out', '2f', '2f-left', '2f-right'), 329, 183)
# (('out', 'in', '2f', '2f-left', '2f-right'), 329, 183)
# (('out', 'in', '2f-right', '1f-left'), 326, 225)
# (('out', 'out', 'in', '1f', '1f-left'), 325, 207)
# (('out', 'out', '1f', '1f-left'), 325, 207)
# (('1f', '1f-right', '1f-left', '1f-inner'), 321, 200)
# (('in', '1f', '1f-right', '1f-left', '1f-inner'), 321, 200)
# (('out', '1f', '1f-right', '1f-left', '1f-inner'), 321, 200)
# (('out', 'in', '1f', '1f-right', '1f-left', '1f-inner'), 321, 200)
# (('out', 'in', '2f', '2f-inner', '1f-right'), 316, 211)
# (('out', '2f', '2f-inner', '1f-right'), 316, 211)
# (('in', '2f', '2f-inner', '1f-right'), 316, 211)
# (('out', 'in', '2f-left', '2f-inner'), 313, 172)
# (('out', 'in', '1f-right', '1f', '1f-inner'), 312, 193)
# (('out', '1f-right', '1f', '1f-inner'), 312, 193)
# (('in', '1f-right', '1f', '1f-inner'), 312, 193)
# (('out', 'in', '1f', '1f-right', '2f', '2f-right'), 308, 174)
# (('out', '1f', '1f-right', '2f', '2f-right'), 308, 174)
# (('out', 'in', '2f-left', '1f-left'), 308, 212)
# (('1f', '1f-right', '2f', '2f-right'), 308, 174)
# (('in', '1f', '1f-right', '2f', '2f-right'), 308, 174)
# (('out', 'out', 'in', '1f', '2f'), 305, 174)
# (('out', 'out', '1f', '2f'), 305, 174)
# (('out', 'in', '1f', '1f-right', '2f-inner'), 304, 174)
# (('in', '1f', '1f-right', '2f-inner'), 304, 174)
# (('out', '1f', '1f-right', '2f-inner'), 304, 174)
# (('out', '2f', '2f-right', '2f-left'), 303, 175)
# (('out', 'in', '2f', '2f-right', '2f-left'), 303, 175)
# (('in', '2f', '2f-right', '2f-left'), 303, 175)
# (('out', 'out', 'out', '1f'), 302, 204)
# (('out', 'out', 'out', 'in', '1f'), 302, 204)
# (('out', 'in', '1f', 'out', 'in'), 300, 207)
# (('out', '1f', '1f-right', '1f'), 300, 218)
# (('out', 'in', '1f', '1f-right', '1f'), 300, 218)
# (('in', '1f', 'out', 'in'), 300, 207)
# (('out', '1f', 'out', 'in'), 300, 207)
# (('in', '1f', '1f-right', '1f'), 300, 218)
# (('out', 'in', 'in', '1f-right'), 295, 211)
# (('out', '1f', '1f-right', '2f', '2f-left'), 290, 165)
# (('out', 'in', '1f', '1f-right', '2f', '2f-left'), 290, 165)
# (('1f', '1f-right', '2f', '2f-left'), 290, 165)
# (('in', '1f', '1f-right', '2f', '2f-left'), 290, 165)
# (('out', 'in', '2f-right', 'out'), 290, 163)
# (('in', '1f', '2f-right', '1f-right'), 287, 203)
# (('out', 'in', '1f', '2f-right', '1f-right'), 287, 203)
# (('out', '1f', '2f-right', '1f-right'), 287, 203)
# (('out', '1f', '1f-right', '1f-right'), 285, 192)
# (('out', 'in', '1f', '1f-right', '1f-right'), 285, 192)
# (('in', '1f', '1f-right', '1f-right'), 285, 192)
# (('out', 'in', '1f-left', '1f', '1f-right'), 284, 171)
# (('out', '1f-left', '1f', '1f-right'), 284, 171)
# (('in', '1f-left', '1f', '1f-right'), 284, 171)
# (('out', 'in', '2f-inner', '2f'), 280, 155)
# (('out', '1f-left', '1f-right', '1f-inner'), 280, 171)
# (('in', '1f-left', '1f-right', '1f-inner'), 280, 171)
# (('out', 'in', '1f-left', '1f-right', '1f-inner'), 280, 171)
# (('out', '1f', '2f-left', '2f-right'), 279, 154)
# (('in', '1f', '2f-left', '2f-right'), 279, 154)
# (('out', 'in', '2f', '1f', '1f-inner'), 279, 197)
# (('out', 'in', '1f', '2f-left', '2f-right'), 279, 154)
# (('out', '2f', '1f', '1f-inner'), 279, 197)
# (('in', '2f', '1f', '1f-inner'), 279, 197)
# (('in', '2f', '2f-right', '1f-left'), 278, 195)
# (('out', 'in', '2f', '2f-right', '1f-left'), 278, 195)
# (('out', 'in', '1f', '2f-left', '1f-right'), 278, 193)
# (('out', '1f', '2f-left', '1f-right'), 278, 193)
# (('out', '2f', '2f-right', '1f-left'), 278, 195)
# (('in', '1f', '2f-left', '1f-right'), 278, 193)
# (('out', '1f', '2f-right', '2f-left'), 277, 162)
# (('out', 'in', '1f', '2f-right', '2f-left'), 277, 162)
# (('in', '1f', '2f-right', '2f-left'), 277, 162)
# (('out', '1f', '2f-inner', '2f-right'), 276, 151)
# (('in', '1f', '2f-inner', '2f-right'), 276, 151)
# (('out', 'in', '1f', '2f-inner', '2f-right'), 276, 151)
# (('in', '1f', '2f-inner', '2f-left'), 274, 160)
# (('out', '1f', '2f-inner', '2f-left'), 274, 160)
# (('out', 'in', '1f', '2f-inner', '2f-left'), 274, 160)
# (('out', '1f', '2f', '3f'), 273, 149)
# (('in', '1f', '2f', '3f'), 273, 149)
# (('out', 'in', '2f-left', '2f'), 273, 156)
# (('out', 'in', '1f', '2f', '3f'), 273, 149)
# (('out', '1f', '2f-inner', '1f-right'), 272, 183)
# (('out', 'in', '1f', '2f-inner', '1f-right'), 272, 183)
# (('in', '1f', '2f-inner', '1f-right'), 272, 183)
# (('out', '1f-inner', '1f-left', '1f-right'), 271, 167)
# (('in', '1f-inner', '1f-left', '1f-right'), 271, 167)
# (('out', 'in', '1f-inner', '1f-left', '1f-right'), 271, 167)
# (('out', '2f', '2f-left', '1f-left'), 266, 184)
# (('in', '2f', '2f-left', '1f-left'), 266, 184)
# (('1f', 'out', 'in', '1f'), 266, 183)
# (('out', 'in', '2f', '2f-left', '1f-left'), 266, 184)
# (('out', '1f', 'out', '1f'), 265, 183)
# (('in', '1f-right', '1f-left', '2f'), 265, 172)
# (('out', 'in', '2f-inner', '1f-left'), 265, 182)
# (('in', '1f', 'out', 'in', '1f'), 265, 183)
# (('out', '1f-right', '1f-left', '2f'), 265, 172)
# (('out', 'in', '1f', 'out', '1f'), 265, 183)
# (('out', 'in', '1f-right', '1f-left', '2f'), 265, 172)
# (('in', '1f', 'out', '1f'), 265, 183)
# (('out', '1f', 'out', 'in', '1f'), 265, 183)
# (('out', 'in', '1f', 'out', 'in', '1f'), 265, 183)
# (('in', '2f-right', '1f', '1f-right'), 263, 185)
# (('out', '2f-right', '1f', '1f-right'), 263, 185)
# (('out', 'in', '2f-right', '1f', '1f-right'), 263, 185)
# (('in', '2f', '2f-inner', '1f'), 262, 168)
# (('out', 'in', '3f', '1f'), 262, 172)
# (('out', '2f', '2f-inner', '1f'), 262, 168)
# (('out', 'in', '2f', '2f-inner', '1f'), 262, 168)
# (('1f', '1f-right', '1f-inner', '1f-left'), 259, 159)
# (('out', 'in', '1f', '1f-right', '1f-inner', '1f-left'), 259, 159)
# (('in', '1f', '1f-right', '1f-inner', '1f-left'), 259, 159)
# (('out', '1f', '1f-right', '1f-inner', '1f-left'), 259, 159)
# (('out', 'in', '1f-right', '2f', '2f-inner'), 255, 151)
# (('in', '1f-right', '2f', '2f-inner'), 255, 151)
# (('out', '1f-right', '2f', '2f-inner'), 255, 151)
# (('in', '1f-right', '1f-left', 'out'), 254, 158)
# (('out', '1f-right', '1f-left', 'out'), 254, 158)
# (('out', 'in', '1f-right', '1f-left', 'out'), 254, 158)
# (('out', 'in', '2f-right', '2f-inner'), 253, 141)
# (('out', 'in', '2f-left', 'out'), 252, 138)
# (('out', 'in', '1f-right', '3f'), 251, 146)
# (('out', 'in', '2f', 'in'), 250, 174)
# (('in', '1f-left', '1f-inner', '1f-right'), 249, 151)
# (('out', 'in', '2f-right', '1f-inner'), 249, 170)
# (('out', 'in', '1f-left', '1f-inner', '1f-right'), 249, 151)
# (('out', '1f-left', '1f-inner', '1f-right'), 249, 151)
# (('in', '1f-right', '1f-inner', '2f'), 247, 155)
# (('out', 'in', '1f-right', '1f-inner', '2f'), 247, 155)
# (('out', '1f-right', '1f-inner', '2f'), 247, 155)
# (('out', 'in', '1f-left', '2f-right'), 247, 141)
# (('out', '2f-left', '1f', '1f-right'), 246, 166)
# (('in', '2f-left', '1f', '1f-right'), 246, 166)
# (('out', 'in', '2f-left', '1f', '1f-right'), 246, 166)
# (('out', 'in', '2f', '2f-left', '2f-inner'), 245, 131)
# (('in', '2f', '2f-left', '2f-inner'), 245, 131)
# (('out', '2f', '2f-left', '2f-inner'), 245, 131)
# (('out', '1f-right', '1f-inner', 'out'), 238, 135)
# (('out', 'in', '1f-right', '1f-inner', 'out'), 238, 135)
# (('in', '1f-right', '1f-inner', 'out'), 238, 135)
# (('in', '1f-inner', '1f-right', '1f-left'), 236, 156)
# (('out', '1f-inner', '1f-right', '1f-left'), 236, 156)
# (('out', 'in', '1f-inner', '1f-right', '1f-left'), 236, 156)
# (('out', 'in', '2f', '2f-inner', '2f-right'), 235, 137)
# (('out', 'in', '1f-inner', '1f', '1f-right'), 235, 148)
# (('in', '2f', '2f-inner', '2f-right'), 235, 137)
# (('in', '1f-inner', '1f', '1f-right'), 235, 148)
# (('out', '2f', '2f-inner', '2f-right'), 235, 137)
# (('out', '1f-inner', '1f', '1f-right'), 235, 148)
# (('out', 'in', 'in', '1f', '1f-right'), 234, 164)
# (('in', 'in', '1f', '1f-right'), 234, 164)
# (('out', 'in', '2f', '1f-right', '1f-inner'), 233, 164)
# (('out', '1f', '2f-right', '1f-left'), 233, 162)
# (('out', 'in', '1f', '2f-right', '1f-left'), 233, 162)
# (('out', 'in', '3f', '1f-right'), 233, 161)
# (('in', '2f', '1f-right', '1f-inner'), 233, 164)
# (('in', '1f', '2f-right', '1f-left'), 233, 162)
# (('out', '2f', '1f-right', '1f-inner'), 233, 164)
# (('out', 'in', '1f', '2f', '2f-left', '1f-right'), 232, 161)
# (('out', '1f', '2f', '2f-left', '1f-right'), 232, 161)
# (('in', '1f', '2f', '2f-left', '1f-right'), 232, 161)
# (('1f', '2f', '2f-left', '1f-right'), 232, 161)
# (('in', '1f', 'in', '1f-right'), 230, 159)
# (('out', '1f', 'in', '1f-right'), 230, 159)
# (('out', 'in', '1f', 'in', '1f-right'), 230, 159)
# (('out', 'out', 'in', '2f-right'), 229, 126)
# (('1f', '2f', '1f', '1f-right'), 229, 169)
# (('out', 'in', '1f', '2f', '1f', '1f-right'), 229, 169)
# (('out', '1f', '1f-inner', '1f-left', '1f-right'), 229, 142)
# (('out', '1f', '2f', '1f', '1f-right'), 229, 169)
# (('1f', '1f-inner', '1f-left', '1f-right'), 229, 142)
# (('out', 'in', '1f', '1f-inner', '1f-left', '1f-right'), 229, 142)
# (('in', '1f', '2f', '1f', '1f-right'), 229, 169)
# (('in', '1f', '1f-inner', '1f-left', '1f-right'), 229, 142)
# (('in', '2f', '2f-right', 'out'), 225, 130)
# (('out', '1f', '1f', '1f-left'), 225, 163)
# (('in', '1f', '1f', '1f-left'), 225, 163)
# (('out', '2f', '2f-right', 'out'), 225, 130)
# (('out', 'in', '1f', '1f', '1f-left'), 225, 163)
# (('out', 'in', '2f', '2f-right', 'out'), 225, 130)
# (('out', '1f', '2f', '2f-right', '1f-right'), 224, 156)
# (('out', 'in', '2f-left', '1f-inner'), 224, 156)
# (('in', '1f', '2f', '2f-right', '1f-right'), 224, 156)
# (('1f', '2f', '2f-right', '1f-right'), 224, 156)
# (('out', 'in', '1f', '2f', '2f-right', '1f-right'), 224, 156)
# (('out', 'in', '1f-inner', '2f-right'), 223, 129)
# (('out', '2f', '2f-inner', '2f-left'), 221, 139)
# (('out', 'in', '1f-right', '2f', '1f-left'), 221, 152)
# (('out', 'in', '1f-left', '2f-left'), 221, 133)
# (('out', 'in', '2f', '2f-inner', '2f-left'), 221, 139)
# (('in', '1f-right', '2f', '1f-left'), 221, 152)
# (('in', '2f', '2f-inner', '2f-left'), 221, 139)
# (('out', '1f-right', '2f', '1f-left'), 221, 152)
# (('out', '1f', '2f-left', '1f-left'), 220, 153)
# (('out', 'in', '3f', '2f'), 220, 127)
# (('out', 'in', '1f', '2f-left', '1f-left'), 220, 153)
# (('in', '1f', '2f-left', '1f-left'), 220, 153)
# (('out', 'in', '2f', '2f'), 219, 162)
# (('in', '2f', '2f-inner', '1f-left'), 219, 145)
# (('out', '2f', '2f-inner', '1f-left'), 219, 145)
# (('out', 'in', '2f', '2f-inner', '1f-left'), 219, 145)
# (('in', '1f', '1f-right', '2f', '2f-inner'), 218, 124)
# (('1f', '1f-right', '2f', '2f-inner'), 218, 124)
# (('out', '1f', '1f-right', '2f', '2f-inner'), 218, 124)
# (('out', 'in', '1f', '1f-left', '2f-right'), 218, 124)
# (('out', '1f', '1f-left', '2f-right'), 218, 124)
# (('out', 'in', '1f', '1f-right', '2f', '2f-inner'), 218, 124)
# (('in', '1f', '1f-left', '2f-right'), 218, 124)
# (('out', 'in', '1f', '1f-left', '1f-right', '1f-inner'), 217, 134)
# (('in', '1f', '1f-left', '1f-right', '1f-inner'), 217, 134)
# (('in', '2f', '2f-left', 'out'), 217, 119)
# (('1f', '1f-left', '1f-right', '1f-inner'), 217, 134)
# (('out', 'in', '2f', '2f-left', 'out'), 217, 119)
# (('out', '1f', '1f-left', '1f-right', '1f-inner'), 217, 134)
# (('2f', '2f-left', '1f', '1f-right'), 217, 146)
# (('out', '2f', '2f-left', 'out'), 217, 119)
# (('out', 'in', '2f', '2f-left', '1f', '1f-right'), 216, 146)
# (('in', '2f', '2f-left', '1f', '1f-right'), 216, 146)
# (('out', '2f', '2f-left', '1f', '1f-right'), 216, 146)
# (('1f', '2f', '2f-left', '2f-right'), 214, 118)
# (('out', '1f', '2f', '2f-left', '2f-right'), 214, 118)
# (('out', 'in', '1f', '2f', '2f-left', '2f-right'), 214, 118)
# (('in', '1f', '2f', '2f-left', '2f-right'), 214, 118)
# (('out', 'in', '1f', '2f-left', '2f-inner'), 213, 121)
# (('out', 'in', '3f', '2f-right'), 213, 111)
# (('out', '1f-right', '1f', '2f'), 213, 129)
# (('out', 'in', '1f-right', '1f', '2f'), 213, 129)
# (('in', '1f-right', '1f', '2f'), 213, 129)
# (('out', '1f', '2f-left', '2f-inner'), 213, 121)
# (('in', '1f', '2f-left', '2f-inner'), 213, 121)
# (('out', 'in', '1f-left', '1f-right', '2f'), 211, 126)
# (('out', 'in', '1f', '1f-inner', '2f-right'), 211, 122)
# (('out', '1f-left', '1f-right', '2f'), 211, 126)
# (('out', '1f', '1f-inner', '2f-right'), 211, 122)
# (('in', '1f', '1f-inner', '2f-right'), 211, 122)
# (('in', '1f-left', '1f-right', '2f'), 211, 126)
# (('in', '2f', '2f-right', '1f-inner'), 210, 146)
# (('out', 'in', '2f', '2f-right', '1f-inner'), 210, 146)
# (('out', '2f', '2f-right', '1f-inner'), 210, 146)
# (('out', 'in', '2f', '1f', '1f-right', '1f-left'), 208, 150)
# (('out', '2f', 'in', '1f'), 208, 145)
# (('out', '2f', '1f', '1f-right', '1f-left'), 208, 150)
# (('out', 'in', '2f', 'in', '1f'), 208, 145)
# (('in', '2f', '1f', '1f-right', '1f-left'), 208, 150)
# (('in', '2f', 'in', '1f'), 208, 145)
# (('2f', '1f', '1f-right', '1f-left'), 208, 150)
# (('out', '1f', '2f-inner', '1f-left'), 207, 140)
# (('in', '1f', '1f-inner', '1f'), 207, 143)
# (('out', '1f', '1f-inner', '1f'), 207, 143)
# (('in', '1f', '2f-inner', '1f-left'), 207, 140)
# (('out', 'in', '1f-right', '1f', '1f-right'), 207, 146)
# (('out', 'in', '1f', '2f-inner', '1f-left'), 207, 140)
# (('out', '1f-right', '1f', '1f-right'), 207, 146)
# (('out', 'in', '1f', '1f-inner', '1f'), 207, 143)
# (('in', '1f-right', '1f', '1f-right'), 207, 146)
# (('out', 'in', '1f', '1f-left', '1f-inner', '1f-right'), 206, 132)
# (('1f', '1f-right', '1f-left', '2f'), 206, 135)
# (('out', 'in', '1f', '1f-right', '1f-left', '2f'), 206, 135)
# (('1f', '1f-left', '1f-inner', '1f-right'), 206, 132)
# (('out', 'in', '2f', '1f-left', '1f-right'), 206, 138)
# (('in', '1f', '1f-left', '1f-inner', '1f-right'), 206, 132)
# (('in', '2f', '2f-right', '1f', '1f-right'), 206, 152)
# (('out', '1f', '1f-left', '1f-inner', '1f-right'), 206, 132)
# (('out', '2f', '1f-left', '1f-right'), 206, 138)
# (('in', '2f', '1f-left', '1f-right'), 206, 138)
# (('out', '2f', '2f-right', '1f', '1f-right'), 206, 152)
# (('out', 'in', '2f', '2f-right', '1f', '1f-right'), 206, 152)
# (('out', '1f', '1f-right', '1f-left', '2f'), 206, 135)
# (('in', '1f', '1f-right', '1f-left', '2f'), 206, 135)
# (('2f', '2f-right', '1f', '1f-right'), 206, 152)
# (('out', '2f', '2f-right', '2f-inner'), 205, 117)
# (('in', '1f', '1f-right', '3f'), 205, 116)
# (('out', 'in', '2f', '2f-right', '2f-inner'), 205, 117)
# (('out', 'in', '1f', '1f-right', '3f'), 205, 116)
# (('in', '2f', '2f-right', '2f-inner'), 205, 117)
# (('out', '1f', '1f-right', '3f'), 205, 116)
# (('out', '1f-right', '2f', '1f-right'), 204, 150)
# (('out', 'in', '2f-inner', 'out'), 204, 114)
# (('out', 'in', '1f-right', '2f', '1f-right'), 204, 150)
# (('out', 'in', '1f-right', 'in'), 204, 148)
# (('in', '1f-right', '2f', '1f-right'), 204, 150)
# (('in', '2f-inner', '1f', '1f-right'), 203, 138)
# (('1f', '1f-inner', '1f-right', '1f-left'), 203, 130)
# (('out', '1f', '1f-inner', '1f-right', '1f-left'), 203, 130)
# (('in', '1f', '1f-inner', '1f-right', '1f-left'), 203, 130)
# (('out', 'in', '2f', '1f-right', '1f'), 203, 135)
# (('out', '2f-inner', '1f', '1f-right'), 203, 138)
# (('out', '2f', '1f-right', '1f'), 203, 135)
# (('in', '2f', '1f-right', '1f'), 203, 135)
# (('out', 'in', '2f-inner', '1f', '1f-right'), 203, 138)
# (('out', 'in', '1f', '1f-inner', '1f-right', '1f-left'), 203, 130)
# (('out', 'in', '1f', '1f-right', '1f-left', 'out'), 202, 131)
# (('out', 'in', '1f', '2f', '2f-right', '2f-left'), 202, 114)
# (('out', 'in', 'out', 'in', '1f-right'), 202, 140)
# (('in', '1f', '1f-right', '1f-left', 'out'), 202, 131)
# (('out', '1f', '2f', '2f-right', '2f-left'), 202, 114)
# (('out', '1f', '1f-right', '1f-left', 'out'), 202, 131)
# (('1f', '2f', '2f-right', '2f-left'), 202, 114)
# (('out', 'in', 'out', '1f-right'), 202, 140)
# (('1f', '1f-right', '1f-left', 'out'), 202, 131)
# (('in', '1f', '2f', '2f-right', '2f-left'), 202, 114)
# (('in', 'out', 'in', '1f-right'), 202, 140)
# (('out', 'in', '1f', '1f-right', '1f-inner', '2f'), 201, 127)
# (('out', '1f', '1f', '1f-inner'), 201, 141)
# (('1f', '1f-right', '1f-inner', '2f'), 201, 127)
# (('in', '1f', '1f', '1f-inner'), 201, 141)
# (('in', '1f', '1f-right', '1f-inner', '2f'), 201, 127)
# (('out', '1f', '1f-right', '1f-inner', '2f'), 201, 127)
# (('out', 'in', '1f', '1f', '1f-inner'), 201, 141)
# (('out', 'in', '1f-left', '2f-inner'), 200, 115)

# %%
freq_seqs_sample = []
for x in freq_seqs_sorted:
    if (len(x[0]) >= 4):
#         if (x[0][0] != 'out') & (x[0][0] != 'in'):
        freq_seqs_sample.append(x)
print(len(freq_seqs_sample))
# Out:
# 491

# %%
freq_seqs_sample2 = {}
for kv in freq_seqs_sample:
    freq_seqs_sample2.setdefault((kv[1], kv[2]), []).append(kv[0])
freq_seqs_sample2
# Out:
# {(200, 115): [('out', 'in', '1f-left', '2f-inner')],
#  (201, 127): [('out', 'in', '1f', '1f-right', '1f-inner', '2f'),
#   ('1f', '1f-right', '1f-inner', '2f'),
#   ('in', '1f', '1f-right', '1f-inner', '2f'),
#   ('out', '1f', '1f-right', '1f-inner', '2f')],
#  (201, 141): [('out', '1f', '1f', '1f-inner'),
#   ('in', '1f', '1f', '1f-inner'),
#   ('out', 'in', '1f', '1f', '1f-inner')],
#  (202, 114): [('out', 'in', '1f', '2f', '2f-right', '2f-left'),
#   ('out', '1f', '2f', '2f-right', '2f-left'),
#   ('1f', '2f', '2f-right', '2f-left'),
#   ('in', '1f', '2f', '2f-right', '2f-left')],
#  (202, 131): [('out', 'in', '1f', '1f-right', '1f-left', 'out'),
#   ('in', '1f', '1f-right', '1f-left', 'out'),
#   ('out', '1f', '1f-right', '1f-left', 'out'),
#   ('1f', '1f-right', '1f-left', 'out')],
#  (202, 140): [('out', 'in', 'out', 'in', '1f-right'),
#   ('out', 'in', 'out', '1f-right'),
#   ('in', 'out', 'in', '1f-right')],
#  (203, 130): [('1f', '1f-inner', '1f-right', '1f-left'),
#   ('out', '1f', '1f-inner', '1f-right', '1f-left'),
#   ('in', '1f', '1f-inner', '1f-right', '1f-left'),
#   ('out', 'in', '1f', '1f-inner', '1f-right', '1f-left')],
#  (203, 135): [('out', 'in', '2f', '1f-right', '1f'),
#   ('out', '2f', '1f-right', '1f'),
#   ('in', '2f', '1f-right', '1f')],
#  (203, 138): [('in', '2f-inner', '1f', '1f-right'),
#   ('out', '2f-inner', '1f', '1f-right'),
#   ('out', 'in', '2f-inner', '1f', '1f-right')],
#  (204, 114): [('out', 'in', '2f-inner', 'out')],
#  (204, 148): [('out', 'in', '1f-right', 'in')],
#  (204, 150): [('out', '1f-right', '2f', '1f-right'),
#   ('out', 'in', '1f-right', '2f', '1f-right'),
#   ('in', '1f-right', '2f', '1f-right')],
#  (205, 116): [('in', '1f', '1f-right', '3f'),
#   ('out', 'in', '1f', '1f-right', '3f'),
#   ('out', '1f', '1f-right', '3f')],
#  (205, 117): [('out', '2f', '2f-right', '2f-inner'),
#   ('out', 'in', '2f', '2f-right', '2f-inner'),
#   ('in', '2f', '2f-right', '2f-inner')],
#  (206, 132): [('out', 'in', '1f', '1f-left', '1f-inner', '1f-right'),
#   ('1f', '1f-left', '1f-inner', '1f-right'),
#   ('in', '1f', '1f-left', '1f-inner', '1f-right'),
#   ('out', '1f', '1f-left', '1f-inner', '1f-right')],
#  (206, 135): [('1f', '1f-right', '1f-left', '2f'),
#   ('out', 'in', '1f', '1f-right', '1f-left', '2f'),
#   ('out', '1f', '1f-right', '1f-left', '2f'),
#   ('in', '1f', '1f-right', '1f-left', '2f')],
#  (206, 138): [('out', 'in', '2f', '1f-left', '1f-right'),
#   ('out', '2f', '1f-left', '1f-right'),
#   ('in', '2f', '1f-left', '1f-right')],
#  (206, 152): [('in', '2f', '2f-right', '1f', '1f-right'),
#   ('out', '2f', '2f-right', '1f', '1f-right'),
#   ('out', 'in', '2f', '2f-right', '1f', '1f-right'),
#   ('2f', '2f-right', '1f', '1f-right')],
#  (207, 140): [('out', '1f', '2f-inner', '1f-left'),
#   ('in', '1f', '2f-inner', '1f-left'),
#   ('out', 'in', '1f', '2f-inner', '1f-left')],
#  (207, 143): [('in', '1f', '1f-inner', '1f'),
#   ('out', '1f', '1f-inner', '1f'),
#   ('out', 'in', '1f', '1f-inner', '1f')],
#  (207, 146): [('out', 'in', '1f-right', '1f', '1f-right'),
#   ('out', '1f-right', '1f', '1f-right'),
#   ('in', '1f-right', '1f', '1f-right')],
#  (208, 145): [('out', '2f', 'in', '1f'),
#   ('out', 'in', '2f', 'in', '1f'),
#   ('in', '2f', 'in', '1f')],
#  (208, 150): [('out', 'in', '2f', '1f', '1f-right', '1f-left'),
#   ('out', '2f', '1f', '1f-right', '1f-left'),
#   ('in', '2f', '1f', '1f-right', '1f-left'),
#   ('2f', '1f', '1f-right', '1f-left')],
#  (210, 146): [('in', '2f', '2f-right', '1f-inner'),
#   ('out', 'in', '2f', '2f-right', '1f-inner'),
#   ('out', '2f', '2f-right', '1f-inner')],
#  (211, 122): [('out', 'in', '1f', '1f-inner', '2f-right'),
#   ('out', '1f', '1f-inner', '2f-right'),
#   ('in', '1f', '1f-inner', '2f-right')],
#  (211, 126): [('out', 'in', '1f-left', '1f-right', '2f'),
#   ('out', '1f-left', '1f-right', '2f'),
#   ('in', '1f-left', '1f-right', '2f')],
#  (213, 111): [('out', 'in', '3f', '2f-right')],
#  (213, 121): [('out', 'in', '1f', '2f-left', '2f-inner'),
#   ('out', '1f', '2f-left', '2f-inner'),
#   ('in', '1f', '2f-left', '2f-inner')],
#  (213, 129): [('out', '1f-right', '1f', '2f'),
#   ('out', 'in', '1f-right', '1f', '2f'),
#   ('in', '1f-right', '1f', '2f')],
#  (214, 118): [('1f', '2f', '2f-left', '2f-right'),
#   ('out', '1f', '2f', '2f-left', '2f-right'),
#   ('out', 'in', '1f', '2f', '2f-left', '2f-right'),
#   ('in', '1f', '2f', '2f-left', '2f-right')],
#  (216, 146): [('out', 'in', '2f', '2f-left', '1f', '1f-right'),
#   ('in', '2f', '2f-left', '1f', '1f-right'),
#   ('out', '2f', '2f-left', '1f', '1f-right')],
#  (217, 119): [('in', '2f', '2f-left', 'out'),
#   ('out', 'in', '2f', '2f-left', 'out'),
#   ('out', '2f', '2f-left', 'out')],
#  (217, 134): [('out', 'in', '1f', '1f-left', '1f-right', '1f-inner'),
#   ('in', '1f', '1f-left', '1f-right', '1f-inner'),
#   ('1f', '1f-left', '1f-right', '1f-inner'),
#   ('out', '1f', '1f-left', '1f-right', '1f-inner')],
#  (217, 146): [('2f', '2f-left', '1f', '1f-right')],
#  (218, 124): [('in', '1f', '1f-right', '2f', '2f-inner'),
#   ('1f', '1f-right', '2f', '2f-inner'),
#   ('out', '1f', '1f-right', '2f', '2f-inner'),
#   ('out', 'in', '1f', '1f-left', '2f-right'),
#   ('out', '1f', '1f-left', '2f-right'),
#   ('out', 'in', '1f', '1f-right', '2f', '2f-inner'),
#   ('in', '1f', '1f-left', '2f-right')],
#  (219, 145): [('in', '2f', '2f-inner', '1f-left'),
#   ('out', '2f', '2f-inner', '1f-left'),
#   ('out', 'in', '2f', '2f-inner', '1f-left')],
#  (219, 162): [('out', 'in', '2f', '2f')],
#  (220, 127): [('out', 'in', '3f', '2f')],
#  (220, 153): [('out', '1f', '2f-left', '1f-left'),
#   ('out', 'in', '1f', '2f-left', '1f-left'),
#   ('in', '1f', '2f-left', '1f-left')],
#  (221, 133): [('out', 'in', '1f-left', '2f-left')],
#  (221, 139): [('out', '2f', '2f-inner', '2f-left'),
#   ('out', 'in', '2f', '2f-inner', '2f-left'),
#   ('in', '2f', '2f-inner', '2f-left')],
#  (221, 152): [('out', 'in', '1f-right', '2f', '1f-left'),
#   ('in', '1f-right', '2f', '1f-left'),
#   ('out', '1f-right', '2f', '1f-left')],
#  (223, 129): [('out', 'in', '1f-inner', '2f-right')],
#  (224, 156): [('out', '1f', '2f', '2f-right', '1f-right'),
#   ('out', 'in', '2f-left', '1f-inner'),
#   ('in', '1f', '2f', '2f-right', '1f-right'),
#   ('1f', '2f', '2f-right', '1f-right'),
#   ('out', 'in', '1f', '2f', '2f-right', '1f-right')],
#  (225, 130): [('in', '2f', '2f-right', 'out'),
#   ('out', '2f', '2f-right', 'out'),
#   ('out', 'in', '2f', '2f-right', 'out')],
#  (225, 163): [('out', '1f', '1f', '1f-left'),
#   ('in', '1f', '1f', '1f-left'),
#   ('out', 'in', '1f', '1f', '1f-left')],
#  (229, 126): [('out', 'out', 'in', '2f-right')],
#  (229, 142): [('out', '1f', '1f-inner', '1f-left', '1f-right'),
#   ('1f', '1f-inner', '1f-left', '1f-right'),
#   ('out', 'in', '1f', '1f-inner', '1f-left', '1f-right'),
#   ('in', '1f', '1f-inner', '1f-left', '1f-right')],
#  (229, 169): [('1f', '2f', '1f', '1f-right'),
#   ('out', 'in', '1f', '2f', '1f', '1f-right'),
#   ('out', '1f', '2f', '1f', '1f-right'),
#   ('in', '1f', '2f', '1f', '1f-right')],
#  (230, 159): [('in', '1f', 'in', '1f-right'),
#   ('out', '1f', 'in', '1f-right'),
#   ('out', 'in', '1f', 'in', '1f-right')],
#  (232, 161): [('out', 'in', '1f', '2f', '2f-left', '1f-right'),
#   ('out', '1f', '2f', '2f-left', '1f-right'),
#   ('in', '1f', '2f', '2f-left', '1f-right'),
#   ('1f', '2f', '2f-left', '1f-right')],
#  (233, 161): [('out', 'in', '3f', '1f-right')],
#  (233, 162): [('out', '1f', '2f-right', '1f-left'),
#   ('out', 'in', '1f', '2f-right', '1f-left'),
#   ('in', '1f', '2f-right', '1f-left')],
#  (233, 164): [('out', 'in', '2f', '1f-right', '1f-inner'),
#   ('in', '2f', '1f-right', '1f-inner'),
#   ('out', '2f', '1f-right', '1f-inner')],
#  (234, 164): [('out', 'in', 'in', '1f', '1f-right'),
#   ('in', 'in', '1f', '1f-right')],
#  (235, 137): [('out', 'in', '2f', '2f-inner', '2f-right'),
#   ('in', '2f', '2f-inner', '2f-right'),
#   ('out', '2f', '2f-inner', '2f-right')],
#  (235, 148): [('out', 'in', '1f-inner', '1f', '1f-right'),
#   ('in', '1f-inner', '1f', '1f-right'),
#   ('out', '1f-inner', '1f', '1f-right')],
#  (236, 156): [('in', '1f-inner', '1f-right', '1f-left'),
#   ('out', '1f-inner', '1f-right', '1f-left'),
#   ('out', 'in', '1f-inner', '1f-right', '1f-left')],
#  (238, 135): [('out', '1f-right', '1f-inner', 'out'),
#   ('out', 'in', '1f-right', '1f-inner', 'out'),
#   ('in', '1f-right', '1f-inner', 'out')],
#  (245, 131): [('out', 'in', '2f', '2f-left', '2f-inner'),
#   ('in', '2f', '2f-left', '2f-inner'),
#   ('out', '2f', '2f-left', '2f-inner')],
#  (246, 166): [('out', '2f-left', '1f', '1f-right'),
#   ('in', '2f-left', '1f', '1f-right'),
#   ('out', 'in', '2f-left', '1f', '1f-right')],
#  (247, 141): [('out', 'in', '1f-left', '2f-right')],
#  (247, 155): [('in', '1f-right', '1f-inner', '2f'),
#   ('out', 'in', '1f-right', '1f-inner', '2f'),
#   ('out', '1f-right', '1f-inner', '2f')],
#  (249, 151): [('in', '1f-left', '1f-inner', '1f-right'),
#   ('out', 'in', '1f-left', '1f-inner', '1f-right'),
#   ('out', '1f-left', '1f-inner', '1f-right')],
#  (249, 170): [('out', 'in', '2f-right', '1f-inner')],
#  (250, 174): [('out', 'in', '2f', 'in')],
#  (251, 146): [('out', 'in', '1f-right', '3f')],
#  (252, 138): [('out', 'in', '2f-left', 'out')],
#  (253, 141): [('out', 'in', '2f-right', '2f-inner')],
#  (254, 158): [('in', '1f-right', '1f-left', 'out'),
#   ('out', '1f-right', '1f-left', 'out'),
#   ('out', 'in', '1f-right', '1f-left', 'out')],
#  (255, 151): [('out', 'in', '1f-right', '2f', '2f-inner'),
#   ('in', '1f-right', '2f', '2f-inner'),
#   ('out', '1f-right', '2f', '2f-inner')],
#  (259, 159): [('1f', '1f-right', '1f-inner', '1f-left'),
#   ('out', 'in', '1f', '1f-right', '1f-inner', '1f-left'),
#   ('in', '1f', '1f-right', '1f-inner', '1f-left'),
#   ('out', '1f', '1f-right', '1f-inner', '1f-left')],
#  (262, 168): [('in', '2f', '2f-inner', '1f'),
#   ('out', '2f', '2f-inner', '1f'),
#   ('out', 'in', '2f', '2f-inner', '1f')],
#  (262, 172): [('out', 'in', '3f', '1f')],
#  (263, 185): [('in', '2f-right', '1f', '1f-right'),
#   ('out', '2f-right', '1f', '1f-right'),
#   ('out', 'in', '2f-right', '1f', '1f-right')],
#  (265, 172): [('in', '1f-right', '1f-left', '2f'),
#   ('out', '1f-right', '1f-left', '2f'),
#   ('out', 'in', '1f-right', '1f-left', '2f')],
#  (265, 182): [('out', 'in', '2f-inner', '1f-left')],
#  (265, 183): [('out', '1f', 'out', '1f'),
#   ('in', '1f', 'out', 'in', '1f'),
#   ('out', 'in', '1f', 'out', '1f'),
#   ('in', '1f', 'out', '1f'),
#   ('out', '1f', 'out', 'in', '1f'),
#   ('out', 'in', '1f', 'out', 'in', '1f')],
#  (266, 183): [('1f', 'out', 'in', '1f')],
#  (266, 184): [('out', '2f', '2f-left', '1f-left'),
#   ('in', '2f', '2f-left', '1f-left'),
#   ('out', 'in', '2f', '2f-left', '1f-left')],
#  (271, 167): [('out', '1f-inner', '1f-left', '1f-right'),
#   ('in', '1f-inner', '1f-left', '1f-right'),
#   ('out', 'in', '1f-inner', '1f-left', '1f-right')],
#  (272, 183): [('out', '1f', '2f-inner', '1f-right'),
#   ('out', 'in', '1f', '2f-inner', '1f-right'),
#   ('in', '1f', '2f-inner', '1f-right')],
#  (273, 149): [('out', '1f', '2f', '3f'),
#   ('in', '1f', '2f', '3f'),
#   ('out', 'in', '1f', '2f', '3f')],
#  (273, 156): [('out', 'in', '2f-left', '2f')],
#  (274, 160): [('in', '1f', '2f-inner', '2f-left'),
#   ('out', '1f', '2f-inner', '2f-left'),
#   ('out', 'in', '1f', '2f-inner', '2f-left')],
#  (276, 151): [('out', '1f', '2f-inner', '2f-right'),
#   ('in', '1f', '2f-inner', '2f-right'),
#   ('out', 'in', '1f', '2f-inner', '2f-right')],
#  (277, 162): [('out', '1f', '2f-right', '2f-left'),
#   ('out', 'in', '1f', '2f-right', '2f-left'),
#   ('in', '1f', '2f-right', '2f-left')],
#  (278, 193): [('out', 'in', '1f', '2f-left', '1f-right'),
#   ('out', '1f', '2f-left', '1f-right'),
#   ('in', '1f', '2f-left', '1f-right')],
#  (278, 195): [('in', '2f', '2f-right', '1f-left'),
#   ('out', 'in', '2f', '2f-right', '1f-left'),
#   ('out', '2f', '2f-right', '1f-left')],
#  (279, 154): [('out', '1f', '2f-left', '2f-right'),
#   ('in', '1f', '2f-left', '2f-right'),
#   ('out', 'in', '1f', '2f-left', '2f-right')],
#  (279, 197): [('out', 'in', '2f', '1f', '1f-inner'),
#   ('out', '2f', '1f', '1f-inner'),
#   ('in', '2f', '1f', '1f-inner')],
#  (280, 155): [('out', 'in', '2f-inner', '2f')],
#  (280, 171): [('out', '1f-left', '1f-right', '1f-inner'),
#   ('in', '1f-left', '1f-right', '1f-inner'),
#   ('out', 'in', '1f-left', '1f-right', '1f-inner')],
#  (284, 171): [('out', 'in', '1f-left', '1f', '1f-right'),
#   ('out', '1f-left', '1f', '1f-right'),
#   ('in', '1f-left', '1f', '1f-right')],
#  (285, 192): [('out', '1f', '1f-right', '1f-right'),
#   ('out', 'in', '1f', '1f-right', '1f-right'),
#   ('in', '1f', '1f-right', '1f-right')],
#  (287, 203): [('in', '1f', '2f-right', '1f-right'),
#   ('out', 'in', '1f', '2f-right', '1f-right'),
#   ('out', '1f', '2f-right', '1f-right')],
#  (290, 163): [('out', 'in', '2f-right', 'out')],
#  (290, 165): [('out', '1f', '1f-right', '2f', '2f-left'),
#   ('out', 'in', '1f', '1f-right', '2f', '2f-left'),
#   ('1f', '1f-right', '2f', '2f-left'),
#   ('in', '1f', '1f-right', '2f', '2f-left')],
#  (295, 211): [('out', 'in', 'in', '1f-right')],
#  (300, 207): [('out', 'in', '1f', 'out', 'in'),
#   ('in', '1f', 'out', 'in'),
#   ('out', '1f', 'out', 'in')],
#  (300, 218): [('out', '1f', '1f-right', '1f'),
#   ('out', 'in', '1f', '1f-right', '1f'),
#   ('in', '1f', '1f-right', '1f')],
#  (302, 204): [('out', 'out', 'out', '1f'), ('out', 'out', 'out', 'in', '1f')],
#  (303, 175): [('out', '2f', '2f-right', '2f-left'),
#   ('out', 'in', '2f', '2f-right', '2f-left'),
#   ('in', '2f', '2f-right', '2f-left')],
#  (304, 174): [('out', 'in', '1f', '1f-right', '2f-inner'),
#   ('in', '1f', '1f-right', '2f-inner'),
#   ('out', '1f', '1f-right', '2f-inner')],
#  (305, 174): [('out', 'out', 'in', '1f', '2f'), ('out', 'out', '1f', '2f')],
#  (308, 174): [('out', 'in', '1f', '1f-right', '2f', '2f-right'),
#   ('out', '1f', '1f-right', '2f', '2f-right'),
#   ('1f', '1f-right', '2f', '2f-right'),
#   ('in', '1f', '1f-right', '2f', '2f-right')],
#  (308, 212): [('out', 'in', '2f-left', '1f-left')],
#  (312, 193): [('out', 'in', '1f-right', '1f', '1f-inner'),
#   ('out', '1f-right', '1f', '1f-inner'),
#   ('in', '1f-right', '1f', '1f-inner')],
#  (313, 172): [('out', 'in', '2f-left', '2f-inner')],
#  (316, 211): [('out', 'in', '2f', '2f-inner', '1f-right'),
#   ('out', '2f', '2f-inner', '1f-right'),
#   ('in', '2f', '2f-inner', '1f-right')],
#  (321, 200): [('1f', '1f-right', '1f-left', '1f-inner'),
#   ('in', '1f', '1f-right', '1f-left', '1f-inner'),
#   ('out', '1f', '1f-right', '1f-left', '1f-inner'),
#   ('out', 'in', '1f', '1f-right', '1f-left', '1f-inner')],
#  (325, 207): [('out', 'out', 'in', '1f', '1f-left'),
#   ('out', 'out', '1f', '1f-left')],
#  (326, 225): [('out', 'in', '2f-right', '1f-left')],
#  (329, 183): [('in', '2f', '2f-left', '2f-right'),
#   ('out', '2f', '2f-left', '2f-right'),
#   ('out', 'in', '2f', '2f-left', '2f-right')],
#  (332, 205): [('out', 'out', 'in', '1f', 'out'), ('out', 'out', '1f', 'out')],
#  (332, 208): [('out', '1f-right', '1f-inner', '1f-left'),
#   ('out', 'in', '1f-right', '1f-inner', '1f-left'),
#   ('in', '1f-right', '1f-inner', '1f-left')],
#  (332, 215): [('out', 'in', '2f-inner', '1f')],
#  (334, 193): [('out', '1f-right', '2f', '2f-left'),
#   ('in', '1f-right', '2f', '2f-left'),
#   ('out', 'in', '1f-right', '2f', '2f-left')],
#  (335, 233): [('out', '2f', '1f-right', '1f-left'),
#   ('out', 'in', '2f', '1f-right', '1f-left'),
#   ('in', '2f', '1f-right', '1f-left')],
#  (336, 190): [('out', '1f', '1f-right', '2f-left'),
#   ('in', '1f', '1f-right', '2f-left'),
#   ('out', 'in', '1f', '1f-right', '2f-left')],
#  (336, 232): [('out', 'in', '1f-right', '1f-right')],
#  (338, 231): [('in', 'out', 'in', '1f'),
#   ('out', 'in', 'out', 'in', '1f'),
#   ('out', 'in', 'out', '1f')],
#  (339, 235): [('in', '1f', '2f', '1f-inner'),
#   ('out', 'in', '1f', '2f', '1f-inner'),
#   ('out', '1f', '2f', '1f-inner')],
#  (341, 236): [('out', '1f', '1f', '1f-right'),
#   ('out', 'in', '1f', '1f', '1f-right'),
#   ('in', '1f', '1f', '1f-right')],
#  (348, 194): [('out', 'out', 'in', '1f', '1f-inner'),
#   ('out', 'out', '1f', '1f-inner')],
#  (349, 251): [('out', '1f', '2f', '1f'),
#   ('out', 'in', '1f', '2f', '1f'),
#   ('in', '1f', '2f', '1f')],
#  (350, 196): [('out', 'in', '2f-inner', '2f-right')],
#  (350, 206): [('out', 'in', '2f-inner', '2f-left')],
#  (356, 219): [('out', 'in', '1f', 'out', 'out'), ('out', '1f', 'out', 'out')],
#  (357, 209): [('out', 'in', '1f-right', '2f-inner')],
#  (357, 220): [('in', '1f', 'out', 'out')],
#  (359, 201): [('out', 'in', '2f-right', '2f')],
#  (360, 249): [('out', '2f', '1f', '1f-left'),
#   ('in', '2f', '1f', '1f-left'),
#   ('out', 'in', '2f', '1f', '1f-left')],
#  (365, 198): [('out', '1f-right', '2f', '2f-right'),
#   ('in', '1f-right', '2f', '2f-right'),
#   ('out', 'in', '1f-right', '2f', '2f-right')],
#  (365, 259): [('out', 'out', 'out', 'out')],
#  (367, 243): [('in', '2f', '2f-right', '1f'),
#   ('out', 'in', '2f', '2f-right', '1f'),
#   ('out', '2f', '2f-right', '1f')],
#  (368, 260): [('out', 'in', '1f', 'in', '1f'),
#   ('out', '1f', 'in', '1f'),
#   ('in', '1f', 'in', '1f')],
#  (370, 206): [('out', 'in', '1f', '2f', 'out'),
#   ('out', '1f', '2f', 'out'),
#   ('in', '1f', '2f', 'out')],
#  (370, 229): [('out', 'out', 'in', '1f-left')],
#  (372, 211): [('out', 'in', '1f', '1f-right', '2f-right'),
#   ('out', '1f', '1f-right', '2f-right'),
#   ('in', '1f', '1f-right', '2f-right')],
#  (373, 233): [('in', '2f', '2f-left', '1f'),
#   ('out', '2f', '2f-left', '1f'),
#   ('out', 'in', '2f', '2f-left', '1f')],
#  (378, 270): [('out', '2f', '2f-right', '1f-right'),
#   ('out', 'in', '2f', '2f-right', '1f-right'),
#   ('in', '2f', '2f-right', '1f-right')],
#  (379, 247): [('out', 'in', '1f-right', '1f', '1f-left'),
#   ('in', '1f-right', '1f', '1f-left'),
#   ('out', '1f-right', '1f', '1f-left')],
#  (380, 260): [('in', '2f', '2f-left', '1f-right'),
#   ('out', '2f', '2f-left', '1f-right'),
#   ('out', 'in', '2f', '2f-left', '1f-right')],
#  (382, 257): [('out', 'in', '2f-inner', '1f-right')],
#  (384, 215): [('out', 'out', 'in', '1f-inner')],
#  (391, 240): [('out', 'in', '1f-inner', '1f')],
#  (395, 228): [('out', 'in', '1f-right', '2f-left')],
#  (398, 277): [('out', 'in', '1f', '2f', '1f-left'),
#   ('out', '1f', '2f', '1f-left'),
#   ('in', '1f', '2f', '1f-left')],
#  (400, 240): [('out', 'in', '1f-left', '1f')],
#  (405, 237): [('out', 'in', '1f', '1f-left', 'out'),
#   ('in', '1f', '1f-left', 'out'),
#   ('out', '1f', '1f-left', 'out')],
#  (407, 210): [('in', '1f', '1f-inner', 'out'),
#   ('out', '1f', '1f-inner', 'out'),
#   ('out', 'in', '1f', '1f-inner', 'out')],
#  (410, 283): [('out', 'in', 'out', 'in')],
#  (411, 237): [('out', 'in', '2f-right', '2f-left')],
#  (414, 250): [('out', '1f-right', '1f-left', '1f-inner'),
#   ('out', 'in', '1f-right', '1f-left', '1f-inner'),
#   ('in', '1f-right', '1f-left', '1f-inner')],
#  (418, 221): [('out', 'in', '2f', '3f')],
#  (420, 293): [('out', 'in', '1f', 'in')],
#  (429, 239): [('out', 'in', '2f-left', '2f-right')],
#  (431, 295): [('out', 'in', '2f-left', '1f-right')],
#  (432, 265): [('out', 'in', '1f', '1f-inner', '2f'),
#   ('in', '1f', '1f-inner', '2f'),
#   ('out', '1f', '1f-inner', '2f')],
#  (442, 301): [('out', 'out', 'out', 'in')],
#  (445, 248): [('out', 'in', '1f-right', '2f-right')],
#  (448, 256): [('out', 'in', '1f-left', 'out')],
#  (450, 279): [('out', 'in', '2f-left', '1f')],
#  (451, 233): [('out', 'in', '1f-inner', 'out')],
#  (453, 248): [('out', 'in', '1f', '3f')],
#  (453, 282): [('out', '1f', '1f-left', '2f'),
#   ('in', '1f', '1f-left', '2f'),
#   ('out', 'in', '1f', '1f-left', '2f')],
#  (456, 261): [('in', '1f', '2f', '2f-inner'),
#   ('out', '1f', '2f', '2f-inner'),
#   ('out', 'in', '1f', '2f', '2f-inner')],
#  (462, 321): [('out', 'in', '2f-right', '1f-right')],
#  (477, 303): [('out', 'in', '2f-right', '1f')],
#  (478, 294): [('out', 'in', '1f-inner', '2f')],
#  (482, 300): [('out', 'out', 'in', 'out')],
#  (491, 347): [('out', 'in', 'in', '1f')],
#  (499, 298): [('out', 'out', '1f', '1f-right'),
#   ('out', 'out', 'in', '1f', '1f-right')],
#  (503, 345): [('out', 'in', '2f', '1f-inner')],
#  (506, 311): [('out', 'in', '1f-left', '2f')],
#  (506, 350): [('out', 'in', '1f', '2f', '1f-right'),
#   ('out', '1f', '2f', '1f-right'),
#   ('in', '1f', '2f', '1f-right')],
#  (511, 319): [('out', 'in', 'out', 'out')],
#  (553, 381): [('in', '2f', '1f', '1f-right'),
#   ('out', 'in', '2f', '1f', '1f-right'),
#   ('out', '2f', '1f', '1f-right')],
#  (566, 315): [('out', '1f', '1f-right', 'out'),
#   ('in', '1f', '1f-right', 'out'),
#   ('out', 'in', '1f', '1f-right', 'out')],
#  (578, 309): [('out', 'out', 'in', '2f')],
#  (602, 338): [('in', '1f', '2f', '2f-left'),
#   ('out', 'in', '1f', '2f', '2f-left'),
#   ('out', '1f', '2f', '2f-left')],
#  (603, 358): [('out', 'out', 'in', '1f-right')],
#  (610, 372): [('in', '1f', '1f-inner', '1f-left'),
#   ('out', '1f', '1f-inner', '1f-left'),
#   ('out', 'in', '1f', '1f-inner', '1f-left')],
#  (611, 414): [('out', 'in', '2f', '1f-left')],
#  (616, 431): [('out', 'in', '1f', '1f')],
#  (624, 333): [('out', 'in', '1f', '2f', '2f-right'),
#   ('in', '1f', '2f', '2f-right'),
#   ('out', '1f', '2f', '2f-right')],
#  (657, 390): [('out', '1f', '1f-inner', '1f-right'),
#   ('out', 'in', '1f', '1f-inner', '1f-right'),
#   ('in', '1f', '1f-inner', '1f-right')],
#  (665, 375): [('out', 'in', '1f-right', 'out')],
#  (666, 368): [('out', 'in', '1f', '2f-inner')],
#  (676, 363): [('out', 'in', '2f', 'out')],
#  (681, 397): [('out', '1f', '1f-right', '2f'),
#   ('in', '1f', '1f-right', '2f'),
#   ('out', 'in', '1f', '1f-right', '2f')],
#  (683, 420): [('out', 'in', '1f-inner', '1f-left')],
#  (702, 394): [('out', 'in', '2f', '2f-inner')],
#  (717, 423): [('in', '1f', '1f-left', '1f-right'),
#   ('out', '1f', '1f-left', '1f-right'),
#   ('out', 'in', '1f', '1f-left', '1f-right')],
#  (729, 429): [('out', 'in', '1f', '1f-left', '1f-inner'),
#   ('out', '1f', '1f-left', '1f-inner'),
#   ('in', '1f', '1f-left', '1f-inner')],
#  (744, 412): [('out', 'in', '1f', '2f-left')],
#  (754, 449): [('out', 'in', '1f-inner', '1f-right')],
#  (805, 477): [('in', '1f', '1f-right', '1f-inner'),
#   ('out', '1f', '1f-right', '1f-inner'),
#   ('out', 'in', '1f', '1f-right', '1f-inner')],
#  (806, 437): [('out', 'in', '1f', '2f-right')],
#  (836, 486): [('out', 'in', '1f-right', '2f')],
#  (838, 485): [('out', 'in', '1f-left', '1f-inner')],
#  (872, 508): [('out', 'in', '1f-left', '1f-right')],
#  (884, 546): [('out', 'in', '1f-right', '1f')],
#  (898, 556): [('out', 'in', '1f', '1f-right', '1f-left'),
#   ('out', '1f', '1f-right', '1f-left'),
#   ('in', '1f', '1f-right', '1f-left')],
#  (914, 609): [('out', 'in', '2f', '1f-right')],
#  (995, 548): [('out', 'in', '2f', '2f-left')],
#  (1002, 589): [('out', 'in', '1f-right', '1f-inner')],
#  (1032, 564): [('out', 'in', '2f', '2f-right')],
#  (1094, 666): [('out', 'in', '2f', '1f')],
#  (1136, 700): [('out', 'in', '1f-right', '1f-left')],
#  (1390, 771): [('out', 'out', 'in', '1f')],
#  (1541, 832): [('out', 'in', '1f', 'out')],
#  (1612, 883): [('out', 'in', '1f', '2f')],
#  (1823, 1069): [('out', 'in', '1f', '1f-left')],
#  (1827, 1005): [('out', 'in', '1f', '1f-inner')],
#  (2607, 1486): [('out', 'in', '1f', '1f-right')]}

# %%
def recursivelyFindLongestSequence(aabaaba, new_list):

#     longest = []
#     for item in aabaaba:
#         if len(item)==len(aabaaba[0]):
#             longest.append(item)

#     new_list.extend(longest)
    try:
        for item in aabaaba:
            testval = 0
            for longt in new_list:
                testval += is_subseq(item, longt)

            if testval == 0:
                new_list.append(item)

        for item in new_list:
            aabaaba.remove(item)


        recursivelyFindLongestSequence(aabaaba, new_list)
    except:
        pass

# %%
freqfreqfreq = []

for k, v in freq_seqs_sample2.items():
    if len(v) > 1:
        v = sorted(v, key = len, reverse=True)
        new_list = []
        new_list.append(v[0])
        recursivelyFindLongestSequence(v, new_list) 
        for item in new_list:
            freqfreqfreq.append(tuple((item, k)))
    else:
        freqfreqfreq.append(tuple((v[0], k)))
        
        
freqfreqfreq = sorted(freqfreqfreq, key=lambda tup: tup[1], reverse=True)
print(len(freqfreqfreq))
freqfreqfreq
# Out:
# 217
# [(('out', 'in', '1f', '1f-right'), (2607, 1486)),
#  (('out', 'in', '1f', '1f-inner'), (1827, 1005)),
#  (('out', 'in', '1f', '1f-left'), (1823, 1069)),
#  (('out', 'in', '1f', '2f'), (1612, 883)),
#  (('out', 'in', '1f', 'out'), (1541, 832)),
#  (('out', 'out', 'in', '1f'), (1390, 771)),
#  (('out', 'in', '1f-right', '1f-left'), (1136, 700)),
#  (('out', 'in', '2f', '1f'), (1094, 666)),
#  (('out', 'in', '2f', '2f-right'), (1032, 564)),
#  (('out', 'in', '1f-right', '1f-inner'), (1002, 589)),
#  (('out', 'in', '2f', '2f-left'), (995, 548)),
#  (('out', 'in', '2f', '1f-right'), (914, 609)),
#  (('out', 'in', '1f', '1f-right', '1f-left'), (898, 556)),
#  (('out', 'in', '1f-right', '1f'), (884, 546)),
#  (('out', 'in', '1f-left', '1f-right'), (872, 508)),
#  (('out', 'in', '1f-left', '1f-inner'), (838, 485)),
#  (('out', 'in', '1f-right', '2f'), (836, 486)),
#  (('out', 'in', '1f', '2f-right'), (806, 437)),
#  (('out', 'in', '1f', '1f-right', '1f-inner'), (805, 477)),
#  (('out', 'in', '1f-inner', '1f-right'), (754, 449)),
#  (('out', 'in', '1f', '2f-left'), (744, 412)),
#  (('out', 'in', '1f', '1f-left', '1f-inner'), (729, 429)),
#  (('out', 'in', '1f', '1f-left', '1f-right'), (717, 423)),
#  (('out', 'in', '2f', '2f-inner'), (702, 394)),
#  (('out', 'in', '1f-inner', '1f-left'), (683, 420)),
#  (('out', 'in', '1f', '1f-right', '2f'), (681, 397)),
#  (('out', 'in', '2f', 'out'), (676, 363)),
#  (('out', 'in', '1f', '2f-inner'), (666, 368)),
#  (('out', 'in', '1f-right', 'out'), (665, 375)),
#  (('out', 'in', '1f', '1f-inner', '1f-right'), (657, 390)),
#  (('out', 'in', '1f', '2f', '2f-right'), (624, 333)),
#  (('out', 'in', '1f', '1f'), (616, 431)),
#  (('out', 'in', '2f', '1f-left'), (611, 414)),
#  (('out', 'in', '1f', '1f-inner', '1f-left'), (610, 372)),
#  (('out', 'out', 'in', '1f-right'), (603, 358)),
#  (('out', 'in', '1f', '2f', '2f-left'), (602, 338)),
#  (('out', 'out', 'in', '2f'), (578, 309)),
#  (('out', 'in', '1f', '1f-right', 'out'), (566, 315)),
#  (('out', 'in', '2f', '1f', '1f-right'), (553, 381)),
#  (('out', 'in', 'out', 'out'), (511, 319)),
#  (('out', 'in', '1f', '2f', '1f-right'), (506, 350)),
#  (('out', 'in', '1f-left', '2f'), (506, 311)),
#  (('out', 'in', '2f', '1f-inner'), (503, 345)),
#  (('out', 'out', 'in', '1f', '1f-right'), (499, 298)),
#  (('out', 'in', 'in', '1f'), (491, 347)),
#  (('out', 'out', 'in', 'out'), (482, 300)),
#  (('out', 'in', '1f-inner', '2f'), (478, 294)),
#  (('out', 'in', '2f-right', '1f'), (477, 303)),
#  (('out', 'in', '2f-right', '1f-right'), (462, 321)),
#  (('out', 'in', '1f', '2f', '2f-inner'), (456, 261)),
#  (('out', 'in', '1f', '1f-left', '2f'), (453, 282)),
#  (('out', 'in', '1f', '3f'), (453, 248)),
#  (('out', 'in', '1f-inner', 'out'), (451, 233)),
#  (('out', 'in', '2f-left', '1f'), (450, 279)),
#  (('out', 'in', '1f-left', 'out'), (448, 256)),
#  (('out', 'in', '1f-right', '2f-right'), (445, 248)),
#  (('out', 'out', 'out', 'in'), (442, 301)),
#  (('out', 'in', '1f', '1f-inner', '2f'), (432, 265)),
#  (('out', 'in', '2f-left', '1f-right'), (431, 295)),
#  (('out', 'in', '2f-left', '2f-right'), (429, 239)),
#  (('out', 'in', '1f', 'in'), (420, 293)),
#  (('out', 'in', '2f', '3f'), (418, 221)),
#  (('out', 'in', '1f-right', '1f-left', '1f-inner'), (414, 250)),
#  (('out', 'in', '2f-right', '2f-left'), (411, 237)),
#  (('out', 'in', 'out', 'in'), (410, 283)),
#  (('out', 'in', '1f', '1f-inner', 'out'), (407, 210)),
#  (('out', 'in', '1f', '1f-left', 'out'), (405, 237)),
#  (('out', 'in', '1f-left', '1f'), (400, 240)),
#  (('out', 'in', '1f', '2f', '1f-left'), (398, 277)),
#  (('out', 'in', '1f-right', '2f-left'), (395, 228)),
#  (('out', 'in', '1f-inner', '1f'), (391, 240)),
#  (('out', 'out', 'in', '1f-inner'), (384, 215)),
#  (('out', 'in', '2f-inner', '1f-right'), (382, 257)),
#  (('out', 'in', '2f', '2f-left', '1f-right'), (380, 260)),
#  (('out', 'in', '1f-right', '1f', '1f-left'), (379, 247)),
#  (('out', 'in', '2f', '2f-right', '1f-right'), (378, 270)),
#  (('out', 'in', '2f', '2f-left', '1f'), (373, 233)),
#  (('out', 'in', '1f', '1f-right', '2f-right'), (372, 211)),
#  (('out', 'out', 'in', '1f-left'), (370, 229)),
#  (('out', 'in', '1f', '2f', 'out'), (370, 206)),
#  (('out', 'in', '1f', 'in', '1f'), (368, 260)),
#  (('out', 'in', '2f', '2f-right', '1f'), (367, 243)),
#  (('out', 'out', 'out', 'out'), (365, 259)),
#  (('out', 'in', '1f-right', '2f', '2f-right'), (365, 198)),
#  (('out', 'in', '2f', '1f', '1f-left'), (360, 249)),
#  (('out', 'in', '2f-right', '2f'), (359, 201)),
#  (('in', '1f', 'out', 'out'), (357, 220)),
#  (('out', 'in', '1f-right', '2f-inner'), (357, 209)),
#  (('out', 'in', '1f', 'out', 'out'), (356, 219)),
#  (('out', 'in', '2f-inner', '2f-left'), (350, 206)),
#  (('out', 'in', '2f-inner', '2f-right'), (350, 196)),
#  (('out', 'in', '1f', '2f', '1f'), (349, 251)),
#  (('out', 'out', 'in', '1f', '1f-inner'), (348, 194)),
#  (('out', 'in', '1f', '1f', '1f-right'), (341, 236)),
#  (('out', 'in', '1f', '2f', '1f-inner'), (339, 235)),
#  (('out', 'in', 'out', 'in', '1f'), (338, 231)),
#  (('out', 'in', '1f-right', '1f-right'), (336, 232)),
#  (('out', 'in', '1f', '1f-right', '2f-left'), (336, 190)),
#  (('out', 'in', '2f', '1f-right', '1f-left'), (335, 233)),
#  (('out', 'in', '1f-right', '2f', '2f-left'), (334, 193)),
#  (('out', 'in', '2f-inner', '1f'), (332, 215)),
#  (('out', 'in', '1f-right', '1f-inner', '1f-left'), (332, 208)),
#  (('out', 'out', 'in', '1f', 'out'), (332, 205)),
#  (('out', 'in', '2f', '2f-left', '2f-right'), (329, 183)),
#  (('out', 'in', '2f-right', '1f-left'), (326, 225)),
#  (('out', 'out', 'in', '1f', '1f-left'), (325, 207)),
#  (('out', 'in', '1f', '1f-right', '1f-left', '1f-inner'), (321, 200)),
#  (('out', 'in', '2f', '2f-inner', '1f-right'), (316, 211)),
#  (('out', 'in', '2f-left', '2f-inner'), (313, 172)),
#  (('out', 'in', '1f-right', '1f', '1f-inner'), (312, 193)),
#  (('out', 'in', '2f-left', '1f-left'), (308, 212)),
#  (('out', 'in', '1f', '1f-right', '2f', '2f-right'), (308, 174)),
#  (('out', 'out', 'in', '1f', '2f'), (305, 174)),
#  (('out', 'in', '1f', '1f-right', '2f-inner'), (304, 174)),
#  (('out', 'in', '2f', '2f-right', '2f-left'), (303, 175)),
#  (('out', 'out', 'out', 'in', '1f'), (302, 204)),
#  (('out', 'in', '1f', '1f-right', '1f'), (300, 218)),
#  (('out', 'in', '1f', 'out', 'in'), (300, 207)),
#  (('out', 'in', 'in', '1f-right'), (295, 211)),
#  (('out', 'in', '1f', '1f-right', '2f', '2f-left'), (290, 165)),
#  (('out', 'in', '2f-right', 'out'), (290, 163)),
#  (('out', 'in', '1f', '2f-right', '1f-right'), (287, 203)),
#  (('out', 'in', '1f', '1f-right', '1f-right'), (285, 192)),
#  (('out', 'in', '1f-left', '1f', '1f-right'), (284, 171)),
#  (('out', 'in', '1f-left', '1f-right', '1f-inner'), (280, 171)),
#  (('out', 'in', '2f-inner', '2f'), (280, 155)),
#  (('out', 'in', '2f', '1f', '1f-inner'), (279, 197)),
#  (('out', 'in', '1f', '2f-left', '2f-right'), (279, 154)),
#  (('out', 'in', '2f', '2f-right', '1f-left'), (278, 195)),
#  (('out', 'in', '1f', '2f-left', '1f-right'), (278, 193)),
#  (('out', 'in', '1f', '2f-right', '2f-left'), (277, 162)),
#  (('out', 'in', '1f', '2f-inner', '2f-right'), (276, 151)),
#  (('out', 'in', '1f', '2f-inner', '2f-left'), (274, 160)),
#  (('out', 'in', '2f-left', '2f'), (273, 156)),
#  (('out', 'in', '1f', '2f', '3f'), (273, 149)),
#  (('out', 'in', '1f', '2f-inner', '1f-right'), (272, 183)),
#  (('out', 'in', '1f-inner', '1f-left', '1f-right'), (271, 167)),
#  (('out', 'in', '2f', '2f-left', '1f-left'), (266, 184)),
#  (('1f', 'out', 'in', '1f'), (266, 183)),
#  (('out', 'in', '1f', 'out', 'in', '1f'), (265, 183)),
#  (('out', 'in', '2f-inner', '1f-left'), (265, 182)),
#  (('out', 'in', '1f-right', '1f-left', '2f'), (265, 172)),
#  (('out', 'in', '2f-right', '1f', '1f-right'), (263, 185)),
#  (('out', 'in', '3f', '1f'), (262, 172)),
#  (('out', 'in', '2f', '2f-inner', '1f'), (262, 168)),
#  (('out', 'in', '1f', '1f-right', '1f-inner', '1f-left'), (259, 159)),
#  (('out', 'in', '1f-right', '2f', '2f-inner'), (255, 151)),
#  (('out', 'in', '1f-right', '1f-left', 'out'), (254, 158)),
#  (('out', 'in', '2f-right', '2f-inner'), (253, 141)),
#  (('out', 'in', '2f-left', 'out'), (252, 138)),
#  (('out', 'in', '1f-right', '3f'), (251, 146)),
#  (('out', 'in', '2f', 'in'), (250, 174)),
#  (('out', 'in', '2f-right', '1f-inner'), (249, 170)),
#  (('out', 'in', '1f-left', '1f-inner', '1f-right'), (249, 151)),
#  (('out', 'in', '1f-right', '1f-inner', '2f'), (247, 155)),
#  (('out', 'in', '1f-left', '2f-right'), (247, 141)),
#  (('out', 'in', '2f-left', '1f', '1f-right'), (246, 166)),
#  (('out', 'in', '2f', '2f-left', '2f-inner'), (245, 131)),
#  (('out', 'in', '1f-right', '1f-inner', 'out'), (238, 135)),
#  (('out', 'in', '1f-inner', '1f-right', '1f-left'), (236, 156)),
#  (('out', 'in', '1f-inner', '1f', '1f-right'), (235, 148)),
#  (('out', 'in', '2f', '2f-inner', '2f-right'), (235, 137)),
#  (('out', 'in', 'in', '1f', '1f-right'), (234, 164)),
#  (('out', 'in', '2f', '1f-right', '1f-inner'), (233, 164)),
#  (('out', 'in', '1f', '2f-right', '1f-left'), (233, 162)),
#  (('out', 'in', '3f', '1f-right'), (233, 161)),
#  (('out', 'in', '1f', '2f', '2f-left', '1f-right'), (232, 161)),
#  (('out', 'in', '1f', 'in', '1f-right'), (230, 159)),
#  (('out', 'in', '1f', '2f', '1f', '1f-right'), (229, 169)),
#  (('out', 'in', '1f', '1f-inner', '1f-left', '1f-right'), (229, 142)),
#  (('out', 'out', 'in', '2f-right'), (229, 126)),
#  (('out', 'in', '1f', '1f', '1f-left'), (225, 163)),
#  (('out', 'in', '2f', '2f-right', 'out'), (225, 130)),
#  (('out', 'in', '1f', '2f', '2f-right', '1f-right'), (224, 156)),
#  (('out', 'in', '1f-inner', '2f-right'), (223, 129)),
#  (('out', 'in', '1f-right', '2f', '1f-left'), (221, 152)),
#  (('out', 'in', '2f', '2f-inner', '2f-left'), (221, 139)),
#  (('out', 'in', '1f-left', '2f-left'), (221, 133)),
#  (('out', 'in', '1f', '2f-left', '1f-left'), (220, 153)),
#  (('out', 'in', '3f', '2f'), (220, 127)),
#  (('out', 'in', '2f', '2f'), (219, 162)),
#  (('out', 'in', '2f', '2f-inner', '1f-left'), (219, 145)),
#  (('out', 'in', '1f', '1f-right', '2f', '2f-inner'), (218, 124)),
#  (('2f', '2f-left', '1f', '1f-right'), (217, 146)),
#  (('out', 'in', '1f', '1f-left', '1f-right', '1f-inner'), (217, 134)),
#  (('out', 'in', '2f', '2f-left', 'out'), (217, 119)),
#  (('out', 'in', '2f', '2f-left', '1f', '1f-right'), (216, 146)),
#  (('out', 'in', '1f', '2f', '2f-left', '2f-right'), (214, 118)),
#  (('out', 'in', '1f-right', '1f', '2f'), (213, 129)),
#  (('out', 'in', '1f', '2f-left', '2f-inner'), (213, 121)),
#  (('out', 'in', '3f', '2f-right'), (213, 111)),
#  (('out', 'in', '1f-left', '1f-right', '2f'), (211, 126)),
#  (('out', 'in', '1f', '1f-inner', '2f-right'), (211, 122)),
#  (('out', 'in', '2f', '2f-right', '1f-inner'), (210, 146)),
#  (('out', 'in', '2f', '1f', '1f-right', '1f-left'), (208, 150)),
#  (('out', 'in', '2f', 'in', '1f'), (208, 145)),
#  (('out', 'in', '1f-right', '1f', '1f-right'), (207, 146)),
#  (('out', 'in', '1f', '1f-inner', '1f'), (207, 143)),
#  (('out', 'in', '1f', '2f-inner', '1f-left'), (207, 140)),
#  (('out', 'in', '2f', '2f-right', '1f', '1f-right'), (206, 152)),
#  (('out', 'in', '2f', '1f-left', '1f-right'), (206, 138)),
#  (('out', 'in', '1f', '1f-right', '1f-left', '2f'), (206, 135)),
#  (('out', 'in', '1f', '1f-left', '1f-inner', '1f-right'), (206, 132)),
#  (('out', 'in', '2f', '2f-right', '2f-inner'), (205, 117)),
#  (('out', 'in', '1f', '1f-right', '3f'), (205, 116)),
#  (('out', 'in', '1f-right', '2f', '1f-right'), (204, 150)),
#  (('out', 'in', '1f-right', 'in'), (204, 148)),
#  (('out', 'in', '2f-inner', 'out'), (204, 114)),
#  (('out', 'in', '2f-inner', '1f', '1f-right'), (203, 138)),
#  (('out', 'in', '2f', '1f-right', '1f'), (203, 135)),
#  (('out', 'in', '1f', '1f-inner', '1f-right', '1f-left'), (203, 130)),
#  (('out', 'in', 'out', 'in', '1f-right'), (202, 140)),
#  (('out', 'in', '1f', '1f-right', '1f-left', 'out'), (202, 131)),
#  (('out', 'in', '1f', '2f', '2f-right', '2f-left'), (202, 114)),
#  (('out', 'in', '1f', '1f', '1f-inner'), (201, 141)),
#  (('out', 'in', '1f', '1f-right', '1f-inner', '2f'), (201, 127)),
#  (('out', 'in', '1f-left', '2f-inner'), (200, 115))]

# %%
freqfreqfreqfreq = []
for x in freqfreqfreq:
    if (len(x[0]) >= 4):
#         if (x[0][0] != 'out') & (x[0][0] != 'in'):
        freqfreqfreqfreq.append(x[0])
freqfreqfreqfreq
# Out:
# [('out', 'in', '1f', '1f-right'),
#  ('out', 'in', '1f', '1f-inner'),
#  ('out', 'in', '1f', '1f-left'),
#  ('out', 'in', '1f', '2f'),
#  ('out', 'in', '1f', 'out'),
#  ('out', 'out', 'in', '1f'),
#  ('out', 'in', '1f-right', '1f-left'),
#  ('out', 'in', '2f', '1f'),
#  ('out', 'in', '2f', '2f-right'),
#  ('out', 'in', '1f-right', '1f-inner'),
#  ('out', 'in', '2f', '2f-left'),
#  ('out', 'in', '2f', '1f-right'),
#  ('out', 'in', '1f', '1f-right', '1f-left'),
#  ('out', 'in', '1f-right', '1f'),
#  ('out', 'in', '1f-left', '1f-right'),
#  ('out', 'in', '1f-left', '1f-inner'),
#  ('out', 'in', '1f-right', '2f'),
#  ('out', 'in', '1f', '2f-right'),
#  ('out', 'in', '1f', '1f-right', '1f-inner'),
#  ('out', 'in', '1f-inner', '1f-right'),
#  ('out', 'in', '1f', '2f-left'),
#  ('out', 'in', '1f', '1f-left', '1f-inner'),
#  ('out', 'in', '1f', '1f-left', '1f-right'),
#  ('out', 'in', '2f', '2f-inner'),
#  ('out', 'in', '1f-inner', '1f-left'),
#  ('out', 'in', '1f', '1f-right', '2f'),
#  ('out', 'in', '2f', 'out'),
#  ('out', 'in', '1f', '2f-inner'),
#  ('out', 'in', '1f-right', 'out'),
#  ('out', 'in', '1f', '1f-inner', '1f-right'),
#  ('out', 'in', '1f', '2f', '2f-right'),
#  ('out', 'in', '1f', '1f'),
#  ('out', 'in', '2f', '1f-left'),
#  ('out', 'in', '1f', '1f-inner', '1f-left'),
#  ('out', 'out', 'in', '1f-right'),
#  ('out', 'in', '1f', '2f', '2f-left'),
#  ('out', 'out', 'in', '2f'),
#  ('out', 'in', '1f', '1f-right', 'out'),
#  ('out', 'in', '2f', '1f', '1f-right'),
#  ('out', 'in', 'out', 'out'),
#  ('out', 'in', '1f', '2f', '1f-right'),
#  ('out', 'in', '1f-left', '2f'),
#  ('out', 'in', '2f', '1f-inner'),
#  ('out', 'out', 'in', '1f', '1f-right'),
#  ('out', 'in', 'in', '1f'),
#  ('out', 'out', 'in', 'out'),
#  ('out', 'in', '1f-inner', '2f'),
#  ('out', 'in', '2f-right', '1f'),
#  ('out', 'in', '2f-right', '1f-right'),
#  ('out', 'in', '1f', '2f', '2f-inner'),
#  ('out', 'in', '1f', '1f-left', '2f'),
#  ('out', 'in', '1f', '3f'),
#  ('out', 'in', '1f-inner', 'out'),
#  ('out', 'in', '2f-left', '1f'),
#  ('out', 'in', '1f-left', 'out'),
#  ('out', 'in', '1f-right', '2f-right'),
#  ('out', 'out', 'out', 'in'),
#  ('out', 'in', '1f', '1f-inner', '2f'),
#  ('out', 'in', '2f-left', '1f-right'),
#  ('out', 'in', '2f-left', '2f-right'),
#  ('out', 'in', '1f', 'in'),
#  ('out', 'in', '2f', '3f'),
#  ('out', 'in', '1f-right', '1f-left', '1f-inner'),
#  ('out', 'in', '2f-right', '2f-left'),
#  ('out', 'in', 'out', 'in'),
#  ('out', 'in', '1f', '1f-inner', 'out'),
#  ('out', 'in', '1f', '1f-left', 'out'),
#  ('out', 'in', '1f-left', '1f'),
#  ('out', 'in', '1f', '2f', '1f-left'),
#  ('out', 'in', '1f-right', '2f-left'),
#  ('out', 'in', '1f-inner', '1f'),
#  ('out', 'out', 'in', '1f-inner'),
#  ('out', 'in', '2f-inner', '1f-right'),
#  ('out', 'in', '2f', '2f-left', '1f-right'),
#  ('out', 'in', '1f-right', '1f', '1f-left'),
#  ('out', 'in', '2f', '2f-right', '1f-right'),
#  ('out', 'in', '2f', '2f-left', '1f'),
#  ('out', 'in', '1f', '1f-right', '2f-right'),
#  ('out', 'out', 'in', '1f-left'),
#  ('out', 'in', '1f', '2f', 'out'),
#  ('out', 'in', '1f', 'in', '1f'),
#  ('out', 'in', '2f', '2f-right', '1f'),
#  ('out', 'out', 'out', 'out'),
#  ('out', 'in', '1f-right', '2f', '2f-right'),
#  ('out', 'in', '2f', '1f', '1f-left'),
#  ('out', 'in', '2f-right', '2f'),
#  ('in', '1f', 'out', 'out'),
#  ('out', 'in', '1f-right', '2f-inner'),
#  ('out', 'in', '1f', 'out', 'out'),
#  ('out', 'in', '2f-inner', '2f-left'),
#  ('out', 'in', '2f-inner', '2f-right'),
#  ('out', 'in', '1f', '2f', '1f'),
#  ('out', 'out', 'in', '1f', '1f-inner'),
#  ('out', 'in', '1f', '1f', '1f-right'),
#  ('out', 'in', '1f', '2f', '1f-inner'),
#  ('out', 'in', 'out', 'in', '1f'),
#  ('out', 'in', '1f-right', '1f-right'),
#  ('out', 'in', '1f', '1f-right', '2f-left'),
#  ('out', 'in', '2f', '1f-right', '1f-left'),
#  ('out', 'in', '1f-right', '2f', '2f-left'),
#  ('out', 'in', '2f-inner', '1f'),
#  ('out', 'in', '1f-right', '1f-inner', '1f-left'),
#  ('out', 'out', 'in', '1f', 'out'),
#  ('out', 'in', '2f', '2f-left', '2f-right'),
#  ('out', 'in', '2f-right', '1f-left'),
#  ('out', 'out', 'in', '1f', '1f-left'),
#  ('out', 'in', '1f', '1f-right', '1f-left', '1f-inner'),
#  ('out', 'in', '2f', '2f-inner', '1f-right'),
#  ('out', 'in', '2f-left', '2f-inner'),
#  ('out', 'in', '1f-right', '1f', '1f-inner'),
#  ('out', 'in', '2f-left', '1f-left'),
#  ('out', 'in', '1f', '1f-right', '2f', '2f-right'),
#  ('out', 'out', 'in', '1f', '2f'),
#  ('out', 'in', '1f', '1f-right', '2f-inner'),
#  ('out', 'in', '2f', '2f-right', '2f-left'),
#  ('out', 'out', 'out', 'in', '1f'),
#  ('out', 'in', '1f', '1f-right', '1f'),
#  ('out', 'in', '1f', 'out', 'in'),
#  ('out', 'in', 'in', '1f-right'),
#  ('out', 'in', '1f', '1f-right', '2f', '2f-left'),
#  ('out', 'in', '2f-right', 'out'),
#  ('out', 'in', '1f', '2f-right', '1f-right'),
#  ('out', 'in', '1f', '1f-right', '1f-right'),
#  ('out', 'in', '1f-left', '1f', '1f-right'),
#  ('out', 'in', '1f-left', '1f-right', '1f-inner'),
#  ('out', 'in', '2f-inner', '2f'),
#  ('out', 'in', '2f', '1f', '1f-inner'),
#  ('out', 'in', '1f', '2f-left', '2f-right'),
#  ('out', 'in', '2f', '2f-right', '1f-left'),
#  ('out', 'in', '1f', '2f-left', '1f-right'),
#  ('out', 'in', '1f', '2f-right', '2f-left'),
#  ('out', 'in', '1f', '2f-inner', '2f-right'),
#  ('out', 'in', '1f', '2f-inner', '2f-left'),
#  ('out', 'in', '2f-left', '2f'),
#  ('out', 'in', '1f', '2f', '3f'),
#  ('out', 'in', '1f', '2f-inner', '1f-right'),
#  ('out', 'in', '1f-inner', '1f-left', '1f-right'),
#  ('out', 'in', '2f', '2f-left', '1f-left'),
#  ('1f', 'out', 'in', '1f'),
#  ('out', 'in', '1f', 'out', 'in', '1f'),
#  ('out', 'in', '2f-inner', '1f-left'),
#  ('out', 'in', '1f-right', '1f-left', '2f'),
#  ('out', 'in', '2f-right', '1f', '1f-right'),
#  ('out', 'in', '3f', '1f'),
#  ('out', 'in', '2f', '2f-inner', '1f'),
#  ('out', 'in', '1f', '1f-right', '1f-inner', '1f-left'),
#  ('out', 'in', '1f-right', '2f', '2f-inner'),
#  ('out', 'in', '1f-right', '1f-left', 'out'),
#  ('out', 'in', '2f-right', '2f-inner'),
#  ('out', 'in', '2f-left', 'out'),
#  ('out', 'in', '1f-right', '3f'),
#  ('out', 'in', '2f', 'in'),
#  ('out', 'in', '2f-right', '1f-inner'),
#  ('out', 'in', '1f-left', '1f-inner', '1f-right'),
#  ('out', 'in', '1f-right', '1f-inner', '2f'),
#  ('out', 'in', '1f-left', '2f-right'),
#  ('out', 'in', '2f-left', '1f', '1f-right'),
#  ('out', 'in', '2f', '2f-left', '2f-inner'),
#  ('out', 'in', '1f-right', '1f-inner', 'out'),
#  ('out', 'in', '1f-inner', '1f-right', '1f-left'),
#  ('out', 'in', '1f-inner', '1f', '1f-right'),
#  ('out', 'in', '2f', '2f-inner', '2f-right'),
#  ('out', 'in', 'in', '1f', '1f-right'),
#  ('out', 'in', '2f', '1f-right', '1f-inner'),
#  ('out', 'in', '1f', '2f-right', '1f-left'),
#  ('out', 'in', '3f', '1f-right'),
#  ('out', 'in', '1f', '2f', '2f-left', '1f-right'),
#  ('out', 'in', '1f', 'in', '1f-right'),
#  ('out', 'in', '1f', '2f', '1f', '1f-right'),
#  ('out', 'in', '1f', '1f-inner', '1f-left', '1f-right'),
#  ('out', 'out', 'in', '2f-right'),
#  ('out', 'in', '1f', '1f', '1f-left'),
#  ('out', 'in', '2f', '2f-right', 'out'),
#  ('out', 'in', '1f', '2f', '2f-right', '1f-right'),
#  ('out', 'in', '1f-inner', '2f-right'),
#  ('out', 'in', '1f-right', '2f', '1f-left'),
#  ('out', 'in', '2f', '2f-inner', '2f-left'),
#  ('out', 'in', '1f-left', '2f-left'),
#  ('out', 'in', '1f', '2f-left', '1f-left'),
#  ('out', 'in', '3f', '2f'),
#  ('out', 'in', '2f', '2f'),
#  ('out', 'in', '2f', '2f-inner', '1f-left'),
#  ('out', 'in', '1f', '1f-right', '2f', '2f-inner'),
#  ('2f', '2f-left', '1f', '1f-right'),
#  ('out', 'in', '1f', '1f-left', '1f-right', '1f-inner'),
#  ('out', 'in', '2f', '2f-left', 'out'),
#  ('out', 'in', '2f', '2f-left', '1f', '1f-right'),
#  ('out', 'in', '1f', '2f', '2f-left', '2f-right'),
#  ('out', 'in', '1f-right', '1f', '2f'),
#  ('out', 'in', '1f', '2f-left', '2f-inner'),
#  ('out', 'in', '3f', '2f-right'),
#  ('out', 'in', '1f-left', '1f-right', '2f'),
#  ('out', 'in', '1f', '1f-inner', '2f-right'),
#  ('out', 'in', '2f', '2f-right', '1f-inner'),
#  ('out', 'in', '2f', '1f', '1f-right', '1f-left'),
#  ('out', 'in', '2f', 'in', '1f'),
#  ('out', 'in', '1f-right', '1f', '1f-right'),
#  ('out', 'in', '1f', '1f-inner', '1f'),
#  ('out', 'in', '1f', '2f-inner', '1f-left'),
#  ('out', 'in', '2f', '2f-right', '1f', '1f-right'),
#  ('out', 'in', '2f', '1f-left', '1f-right'),
#  ('out', 'in', '1f', '1f-right', '1f-left', '2f'),
#  ('out', 'in', '1f', '1f-left', '1f-inner', '1f-right'),
#  ('out', 'in', '2f', '2f-right', '2f-inner'),
#  ('out', 'in', '1f', '1f-right', '3f'),
#  ('out', 'in', '1f-right', '2f', '1f-right'),
#  ('out', 'in', '1f-right', 'in'),
#  ('out', 'in', '2f-inner', 'out'),
#  ('out', 'in', '2f-inner', '1f', '1f-right'),
#  ('out', 'in', '2f', '1f-right', '1f'),
#  ('out', 'in', '1f', '1f-inner', '1f-right', '1f-left'),
#  ('out', 'in', 'out', 'in', '1f-right'),
#  ('out', 'in', '1f', '1f-right', '1f-left', 'out'),
#  ('out', 'in', '1f', '2f', '2f-right', '2f-left'),
#  ('out', 'in', '1f', '1f', '1f-inner'),
#  ('out', 'in', '1f', '1f-right', '1f-inner', '2f'),
#  ('out', 'in', '1f-left', '2f-inner')]

# %%
num1 = trajs_combined_balanced.revisit_intention.value_counts().loc[1]
num0 = trajs_combined_balanced.revisit_intention.value_counts().loc[0]

# %%
freqfreqfreq2 = []
for i in freqfreqfreq:
    z = []
    a = i[1][1]
    b = i[1][0] - i[1][1]
    c = num1 - a
    d = num0 - b
    z.append(a)
    z.append(b)
    z.append(c)
    z.append(d)
    ig = informationGain(a, b, c, d)
    z.append(ig)

    freqfreqfreq2.append((i[0], z))
freqfreqfreq2
# Out:
# [(('out', 'in', '1f', '1f-right'),
#   [1486, 1121, 2957, 3322, 0.0058854516458606287]),
#  (('out', 'in', '1f', '1f-inner'),
#   [1005, 822, 3438, 3621, 0.0018756587139771019]),
#  (('out', 'in', '1f', '1f-left'),
#   [1069, 754, 3374, 3689, 0.005581544098560598]),
#  (('out', 'in', '1f', '2f'), [883, 729, 3560, 3714, 0.0014608174348673675]),
#  (('out', 'in', '1f', 'out'), [832, 709, 3611, 3734, 0.00096504113499285005]),
#  (('out', 'out', 'in', '1f'), [771, 619, 3672, 3824, 0.0016022306616736426]),
#  (('out', 'in', '1f-right', '1f-left'),
#   [700, 436, 3743, 4007, 0.0057564452877962857]),
#  (('out', 'in', '2f', '1f'), [666, 428, 3777, 4015, 0.0048271636700197851]),
#  (('out', 'in', '2f', '2f-right'),
#   [564, 468, 3879, 3975, 0.00082124520261728229]),
#  (('out', 'in', '1f-right', '1f-inner'),
#   [589, 413, 3854, 4030, 0.0028415885563155552]),
#  (('out', 'in', '2f', '2f-left'),
#   [548, 447, 3895, 3996, 0.00093863777824565453]),
#  (('out', 'in', '2f', '1f-right'),
#   [609, 305, 3834, 4138, 0.0093077842964938151]),
#  (('out', 'in', '1f', '1f-right', '1f-left'),
#   [556, 342, 3887, 4101, 0.0046454558381293642]),
#  (('out', 'in', '1f-right', '1f'),
#   [546, 338, 3897, 4105, 0.004449392030535182]),
#  (('out', 'in', '1f-left', '1f-right'),
#   [508, 364, 3935, 4079, 0.0021493254123476913]),
#  (('out', 'in', '1f-left', '1f-inner'),
#   [485, 353, 3958, 4090, 0.0018706911305462759]),
#  (('out', 'in', '1f-right', '2f'),
#   [486, 350, 3957, 4093, 0.0019905477226457302]),
#  (('out', 'in', '1f', '2f-right'),
#   [437, 369, 4006, 4074, 0.00051272676646996196]),
#  (('out', 'in', '1f', '1f-right', '1f-inner'),
#   [477, 328, 3966, 4115, 0.0024747932977655651]),
#  (('out', 'in', '1f-inner', '1f-right'),
#   [449, 305, 3994, 4138, 0.0024532840632578434]),
#  (('out', 'in', '1f', '2f-left'),
#   [412, 332, 4031, 4111, 0.00076346788120351672]),
#  (('out', 'in', '1f', '1f-left', '1f-inner'),
#   [429, 300, 4014, 4143, 0.0020284739189391221]),
#  (('out', 'in', '1f', '1f-left', '1f-right'),
#   [423, 294, 4020, 4149, 0.0020597486892232064]),
#  (('out', 'in', '2f', '2f-inner'),
#   [394, 308, 4049, 4135, 0.00093077503991811916]),
#  (('out', 'in', '1f-inner', '1f-left'),
#   [420, 263, 4023, 4180, 0.0031999635672362858]),
#  (('out', 'in', '1f', '1f-right', '2f'),
#   [397, 284, 4046, 4159, 0.0016555167893372857]),
#  (('out', 'in', '2f', 'out'), [363, 313, 4080, 4130, 0.00032520814380410101]),
#  (('out', 'in', '1f', '2f-inner'),
#   [368, 298, 4075, 4145, 0.00064675129432112399]),
#  (('out', 'in', '1f-right', 'out'),
#   [375, 290, 4068, 4153, 0.0009557329744002141]),
#  (('out', 'in', '1f', '1f-inner', '1f-right'),
#   [390, 267, 4053, 4176, 0.0020296444235842204]),
#  (('out', 'in', '1f', '2f', '2f-right'),
#   [333, 291, 4110, 4152, 0.00024698968156977585]),
#  (('out', 'in', '1f', '1f'), [431, 185, 4012, 4258, 0.0087958376956862594]),
#  (('out', 'in', '2f', '1f-left'),
#   [414, 197, 4029, 4246, 0.0068569278804576639]),
#  (('out', 'in', '1f', '1f-inner', '1f-left'),
#   [372, 238, 4071, 4205, 0.0025852948012164978]),
#  (('out', 'out', 'in', '1f-right'),
#   [358, 245, 4085, 4198, 0.0018543600151501582]),
#  (('out', 'in', '1f', '2f', '2f-left'),
#   [338, 264, 4105, 4179, 0.00079395595890252579]),
#  (('out', 'out', 'in', '2f'), [309, 269, 4134, 4174, 0.00024052759907833288]),
#  (('out', 'in', '1f', '1f-right', 'out'),
#   [315, 251, 4128, 4192, 0.00062868791652415101]),
#  (('out', 'in', '2f', '1f', '1f-right'),
#   [381, 172, 4062, 4271, 0.0069998582169473744]),
#  (('out', 'in', 'out', 'out'), [319, 192, 4124, 4251, 0.0027456639745351286]),
#  (('out', 'in', '1f', '2f', '1f-right'),
#   [350, 156, 4093, 4287, 0.0065599673506357981]),
#  (('out', 'in', '1f-left', '2f'),
#   [311, 195, 4132, 4248, 0.0023084286232589735]),
#  (('out', 'in', '2f', '1f-inner'),
#   [345, 158, 4098, 4285, 0.0061199911937140916]),
#  (('out', 'out', 'in', '1f', '1f-right'),
#   [298, 201, 4145, 4242, 0.001631529136597254]),
#  (('out', 'in', 'in', '1f'), [347, 144, 4096, 4299, 0.0074204189040372182]),
#  (('out', 'out', 'in', 'out'), [300, 182, 4143, 4261, 0.002503574290575572]),
#  (('out', 'in', '1f-inner', '2f'),
#   [294, 184, 4149, 4259, 0.0021902835879982208]),
#  (('out', 'in', '2f-right', '1f'),
#   [303, 174, 4140, 4269, 0.00302826583816862]),
#  (('out', 'in', '2f-right', '1f-right'),
#   [321, 141, 4122, 4302, 0.006158808644885605]),
#  (('out', 'in', '1f', '2f', '2f-inner'),
#   [261, 195, 4182, 4248, 0.00082014096761640065]),
#  (('out', 'in', '1f', '1f-left', '2f'),
#   [282, 171, 4161, 4272, 0.0023491845539649336]),
#  (('out', 'in', '1f', '3f'), [248, 205, 4195, 4238, 0.00034964070464471586]),
#  (('out', 'in', '1f-inner', 'out'),
#   [233, 218, 4210, 4225, 4.2671850426168056e-05]),
#  (('out', 'in', '2f-left', '1f'),
#   [279, 171, 4164, 4272, 0.0022370566471514586]),
#  (('out', 'in', '1f-left', 'out'),
#   [256, 192, 4187, 4251, 0.00078415002853349236]),
#  (('out', 'in', '1f-right', '2f-right'),
#   [248, 197, 4195, 4246, 0.00050053915697723106]),
#  (('out', 'out', 'out', 'in'), [301, 141, 4142, 4302, 0.0050563133114865932]),
#  (('out', 'in', '1f', '1f-inner', '2f'),
#   [265, 167, 4178, 4276, 0.0019127360447693809]),
#  (('out', 'in', '2f-left', '1f-right'),
#   [295, 136, 4148, 4307, 0.0051187201949187688]),
#  (('out', 'in', '2f-left', '2f-right'),
#   [239, 190, 4204, 4253, 0.00047837193691990798]),
#  (('out', 'in', '1f', 'in'), [293, 127, 4150, 4316, 0.0057384269724725101]),
#  (('out', 'in', '2f', '3f'), [221, 197, 4222, 4246, 0.0001174458179453719]),
#  (('out', 'in', '1f-right', '1f-left', '1f-inner'),
#   [250, 164, 4193, 4279, 0.0015317062740167753]),
#  (('out', 'in', '2f-right', '2f-left'),
#   [237, 174, 4206, 4269, 0.00082504703287433756]),
#  (('out', 'in', 'out', 'in'), [283, 127, 4160, 4316, 0.0051750644054011641]),
#  (('out', 'in', '1f', '1f-inner', 'out'),
#   [210, 197, 4233, 4246, 3.5331550664485789e-05]),
#  (('out', 'in', '1f', '1f-left', 'out'),
#   [237, 168, 4206, 4275, 0.0010045348336445992]),
#  (('out', 'in', '1f-left', '1f'),
#   [240, 160, 4203, 4283, 0.001368872223050599]),
#  (('out', 'in', '1f', '2f', '1f-left'),
#   [277, 121, 4166, 4322, 0.0053320649724375446]),
#  (('out', 'in', '1f-right', '2f-left'),
#   [228, 167, 4215, 4276, 0.00080336090218557921]),
#  (('out', 'in', '1f-inner', '1f'),
#   [240, 151, 4203, 4292, 0.0017347267406705447]),
#  (('out', 'out', 'in', '1f-inner'),
#   [215, 169, 4228, 4274, 0.00046860441708884704]),
#  (('out', 'in', '2f-inner', '1f-right'),
#   [257, 125, 4186, 4318, 0.0039465196717300977]),
#  (('out', 'in', '2f', '2f-left', '1f-right'),
#   [260, 120, 4183, 4323, 0.0044744109802954402]),
#  (('out', 'in', '1f-right', '1f', '1f-left'),
#   [247, 132, 4196, 4311, 0.0030040166567740778]),
#  (('out', 'in', '2f', '2f-right', '1f-right'),
#   [270, 108, 4173, 4335, 0.0060731090524346332]),
#  (('out', 'in', '2f', '2f-left', '1f'),
#   [233, 140, 4210, 4303, 0.0019848088178557877]),
#  (('out', 'in', '1f', '1f-right', '2f-right'),
#   [211, 161, 4232, 4282, 0.0005710422965711226]),
#  (('out', 'out', 'in', '1f-left'),
#   [229, 141, 4214, 4302, 0.0017892454118609846]),
#  (('out', 'in', '1f', '2f', 'out'),
#   [206, 164, 4237, 4279, 0.00040467219649475972]),
#  (('out', 'in', '1f', 'in', '1f'),
#   [260, 108, 4183, 4335, 0.005472580436154173]),
#  (('out', 'in', '2f', '2f-right', '1f'),
#   [243, 124, 4200, 4319, 0.0033246004649449823]),
#  (('out', 'out', 'out', 'out'), [259, 106, 4184, 4337, 0.005593630169541175]),
#  (('out', 'in', '1f-right', '2f', '2f-right'),
#   [198, 167, 4245, 4276, 0.00022314459642069906]),
#  (('out', 'in', '2f', '1f', '1f-left'),
#   [249, 111, 4194, 4332, 0.0045875340273454634]),
#  (('out', 'in', '2f-right', '2f'),
#   [201, 158, 4242, 4285, 0.00043670876725265817]),
#  (('in', '1f', 'out', 'out'), [220, 137, 4223, 4306, 0.0016464810249001705]),
#  (('out', 'in', '1f-right', '2f-inner'),
#   [209, 148, 4234, 4295, 0.00088569794308845928]),
#  (('out', 'in', '1f', 'out', 'out'),
#   [219, 137, 4224, 4306, 0.0016111062541311894]),
#  (('out', 'in', '2f-inner', '2f-left'),
#   [206, 144, 4237, 4299, 0.00093284554634776029]),
#  (('out', 'in', '2f-inner', '2f-right'),
#   [196, 154, 4247, 4289, 0.00042690047797722119]),
#  (('out', 'in', '1f', '2f', '1f'),
#   [251, 98, 4192, 4345, 0.0058569702627397913]),
#  (('out', 'out', 'in', '1f', '1f-inner'),
#   [194, 154, 4249, 4289, 0.00038927091207241471]),
#  (('out', 'in', '1f', '1f', '1f-right'),
#   [236, 105, 4207, 4338, 0.0043552960435060406]),
#  (('out', 'in', '1f', '2f', '1f-inner'),
#   [235, 104, 4208, 4339, 0.0043813485852356449]),
#  (('out', 'in', 'out', 'in', '1f'),
#   [231, 107, 4212, 4336, 0.0039265518864838311]),
#  (('out', 'in', '1f-right', '1f-right'),
#   [232, 104, 4211, 4339, 0.0042157333558613397]),
#  (('out', 'in', '1f', '1f-right', '2f-left'),
#   [190, 146, 4253, 4297, 0.00048746731356774653]),
#  (('out', 'in', '2f', '1f-right', '1f-left'),
#   [233, 102, 4210, 4341, 0.0044344693682517589]),
#  (('out', 'in', '1f-right', '2f', '2f-left'),
#   [193, 141, 4250, 4302, 0.0006855497045712422]),
#  (('out', 'in', '2f-inner', '1f'),
#   [215, 117, 4228, 4326, 0.0024747866303351795]),
#  (('out', 'in', '1f-right', '1f-inner', '1f-left'),
#   [208, 124, 4235, 4319, 0.0018111349737734983]),
#  (('out', 'out', 'in', '1f', 'out'),
#   [205, 127, 4238, 4316, 0.0015593458479497002]),
#  (('out', 'in', '2f', '2f-left', '2f-right'),
#   [183, 146, 4260, 4297, 0.00035149226767505759]),
#  (('out', 'in', '2f-right', '1f-left'),
#   [225, 101, 4218, 4342, 0.0040727575662324877]),
#  (('out', 'out', 'in', '1f', '1f-left'),
#   [207, 118, 4236, 4325, 0.0020791068278602776]),
#  (('out', 'in', '1f', '1f-right', '1f-left', '1f-inner'),
#   [200, 121, 4243, 4322, 0.0016537757279525556]),
#  (('out', 'in', '2f', '2f-inner', '1f-right'),
#   [211, 105, 4232, 4338, 0.0030496020603485441]),
#  (('out', 'in', '2f-left', '2f-inner'),
#   [172, 141, 4271, 4302, 0.00025874857510888027]),
#  (('out', 'in', '1f-right', '1f', '1f-inner'),
#   [193, 119, 4250, 4324, 0.0014902928353679457]),
#  (('out', 'in', '2f-left', '1f-left'),
#   [212, 96, 4231, 4347, 0.0037628706164026804]),
#  (('out', 'in', '1f', '1f-right', '2f', '2f-right'),
#   [174, 134, 4269, 4309, 0.00043803895295946305]),
#  (('out', 'out', 'in', '1f', '2f'),
#   [174, 131, 4269, 4312, 0.00051126022371317248]),
#  (('out', 'in', '1f', '1f-right', '2f-inner'),
#   [174, 130, 4269, 4313, 0.00053710873958501271]),
#  (('out', 'in', '2f', '2f-right', '2f-left'),
#   [175, 128, 4268, 4315, 0.00061511154103044419]),
#  (('out', 'out', 'out', 'in', '1f'),
#   [204, 98, 4239, 4345, 0.0031917997740293913]),
#  (('out', 'in', '1f', '1f-right', '1f'),
#   [218, 82, 4225, 4361, 0.0053670757489980847]),
#  (('out', 'in', '1f', 'out', 'in'),
#   [207, 93, 4236, 4350, 0.0037294446920080881]),
#  (('out', 'in', 'in', '1f-right'),
#   [211, 84, 4232, 4359, 0.0047391890038244178]),
#  (('out', 'in', '1f', '1f-right', '2f', '2f-left'),
#   [165, 125, 4278, 4318, 0.00046441953106002298]),
#  (('out', 'in', '2f-right', 'out'),
#   [163, 127, 4280, 4316, 0.00037595819843272427]),
#  (('out', 'in', '1f', '2f-right', '1f-right'),
#   [203, 84, 4240, 4359, 0.0042626078950440682]),
#  (('out', 'in', '1f', '1f-right', '1f-right'),
#   [192, 93, 4251, 4350, 0.0029432158005179287]),
#  (('out', 'in', '1f-left', '1f', '1f-right'),
#   [171, 113, 4272, 4330, 0.0010001037251212708]),
#  (('out', 'in', '1f-left', '1f-right', '1f-inner'),
#   [171, 109, 4272, 4334, 0.0011600079072293656]),
#  (('out', 'in', '2f-inner', '2f'),
#   [155, 125, 4288, 4318, 0.00026992021546579092]),
#  (('out', 'in', '2f', '1f', '1f-inner'),
#   [197, 82, 4246, 4361, 0.0040898085898579684]),
#  (('out', 'in', '1f', '2f-left', '2f-right'),
#   [154, 125, 4289, 4318, 0.00025307232608884345]),
#  (('out', 'in', '2f', '2f-right', '1f-left'),
#   [195, 83, 4248, 4360, 0.0038873822226825894]),
#  (('out', 'in', '1f', '2f-left', '1f-right'),
#   [193, 85, 4250, 4358, 0.0036072793710132389]),
#  (('out', 'in', '1f', '2f-right', '2f-left'),
#   [162, 115, 4281, 4328, 0.0006713447229877989]),
#  (('out', 'in', '1f', '2f-inner', '2f-right'),
#   [151, 125, 4292, 4318, 0.00020549590943352847]),
#  (('out', 'in', '1f', '2f-inner', '2f-left'),
#   [160, 114, 4283, 4329, 0.00064983171741772594]),
#  (('out', 'in', '2f-left', '2f'),
#   [156, 117, 4287, 4326, 0.00046816392040915922]),
#  (('out', 'in', '1f', '2f', '3f'),
#   [149, 124, 4294, 4319, 0.00019199831483696084]),
#  (('out', 'in', '1f', '2f-inner', '1f-right'),
#   [183, 89, 4260, 4354, 0.0027755351920113469]),
#  (('out', 'in', '1f-inner', '1f-left', '1f-right'),
#   [167, 104, 4276, 4339, 0.0012372598364899234]),
#  (('out', 'in', '2f', '2f-left', '1f-left'),
#   [184, 82, 4259, 4361, 0.0033558625673574261]),
#  (('1f', 'out', 'in', '1f'), [183, 83, 4260, 4360, 0.0032222669599261122]),
#  (('out', 'in', '1f', 'out', 'in', '1f'),
#   [183, 82, 4260, 4361, 0.0033013774523582562]),
#  (('out', 'in', '2f-inner', '1f-left'),
#   [182, 83, 4261, 4360, 0.0031687071520958288]),
#  (('out', 'in', '1f-right', '1f-left', '2f'),
#   [172, 93, 4271, 4350, 0.0019999610637284615]),
#  (('out', 'in', '2f-right', '1f', '1f-right'),
#   [185, 78, 4258, 4365, 0.0037462330728355031]),
#  (('out', 'in', '3f', '1f'), [172, 90, 4271, 4353, 0.0021820754112458207]),
#  (('out', 'in', '2f', '2f-inner', '1f'),
#   [168, 94, 4275, 4349, 0.001771538814259066]),
#  (('out', 'in', '1f', '1f-right', '1f-inner', '1f-left'),
#   [159, 100, 4284, 4343, 0.0011334378584544336]),
#  (('out', 'in', '1f-right', '2f', '2f-inner'),
#   [151, 104, 4292, 4339, 0.00072803747541128061]),
#  (('out', 'in', '1f-right', '1f-left', 'out'),
#   [158, 96, 4285, 4347, 0.0012771866862218983]),
#  (('out', 'in', '2f-right', '2f-inner'),
#   [141, 112, 4302, 4331, 0.00027834673917204178]),
#  (('out', 'in', '2f-left', 'out'),
#   [138, 114, 4305, 4329, 0.00019124682014248773]),
#  (('out', 'in', '1f-right', '3f'),
#   [146, 105, 4297, 4338, 0.00056191314540698922]),
#  (('out', 'in', '2f', 'in'), [174, 76, 4269, 4367, 0.0032940364555544832]),
#  (('out', 'in', '2f-right', '1f-inner'),
#   [170, 79, 4273, 4364, 0.0028411304262943027]),
#  (('out', 'in', '1f-left', '1f-inner', '1f-right'),
#   [151, 98, 4292, 4345, 0.00094922390744600627]),
#  (('out', 'in', '1f-right', '1f-inner', '2f'),
#   [155, 92, 4288, 4351, 0.0013562555576583923]),
#  (('out', 'in', '1f-left', '2f-right'),
#   [141, 106, 4302, 4337, 0.00041547256099960794]),
#  (('out', 'in', '2f-left', '1f', '1f-right'),
#   [166, 80, 4277, 4363, 0.0025624265039043692]),
#  (('out', 'in', '2f', '2f-left', '2f-inner'),
#   [131, 114, 4312, 4329, 9.8548884812976745e-05]),
#  (('out', 'in', '1f-right', '1f-inner', 'out'),
#   [135, 103, 4308, 4340, 0.00035994219917012682]),
#  (('out', 'in', '1f-inner', '1f-right', '1f-left'),
#   [156, 80, 4287, 4363, 0.0020768531353926312]),
#  (('out', 'in', '1f-inner', '1f', '1f-right'),
#   [148, 87, 4295, 4356, 0.0013351306587909839]),
#  (('out', 'in', '2f', '2f-inner', '2f-right'),
#   [137, 98, 4306, 4345, 0.00054212287052368691]),
#  (('out', 'in', 'in', '1f', '1f-right'),
#   [164, 70, 4279, 4373, 0.0032365179269625566]),
#  (('out', 'in', '2f', '1f-right', '1f-inner'),
#   [164, 69, 4279, 4374, 0.0033224981503153783]),
#  (('out', 'in', '1f', '2f-right', '1f-left'),
#   [162, 71, 4281, 4372, 0.0030410446923357926]),
#  (('out', 'in', '3f', '1f-right'),
#   [161, 72, 4282, 4371, 0.0029053772890594853]),
#  (('out', 'in', '1f', '2f', '2f-left', '1f-right'),
#   [161, 71, 4282, 4372, 0.0029859614493540354]),
#  (('out', 'in', '1f', 'in', '1f-right'),
#   [159, 71, 4284, 4372, 0.0028767815440681188]),
#  (('out', 'in', '1f', '2f', '1f', '1f-right'),
#   [169, 60, 4274, 4383, 0.0044985828932254668]),
#  (('out', 'in', '1f', '1f-inner', '1f-left', '1f-right'),
#   [142, 87, 4301, 4356, 0.0011112501127275021]),
#  (('out', 'out', 'in', '2f-right'),
#   [126, 103, 4317, 4340, 0.00019280174955638163]),
#  (('out', 'in', '1f', '1f', '1f-left'),
#   [163, 62, 4280, 4381, 0.0039108396248831445]),
#  (('out', 'in', '2f', '2f-right', 'out'),
#   [130, 95, 4313, 4348, 0.00045525063540097221]),
#  (('out', 'in', '1f', '2f', '2f-right', '1f-right'),
#   [156, 68, 4287, 4375, 0.0029560687494456506]),
#  (('out', 'in', '1f-inner', '2f-right'),
#   [129, 94, 4314, 4349, 0.00045926102354543197]),
#  (('out', 'in', '1f-right', '2f', '1f-left'),
#   [152, 69, 4291, 4374, 0.0026581376367804666]),
#  (('out', 'in', '2f', '2f-inner', '2f-left'),
#   [139, 82, 4304, 4361, 0.0012374616154032791]),
#  (('out', 'in', '1f-left', '2f-left'),
#   [133, 88, 4310, 4355, 0.00076802380547291715]),
#  (('out', 'in', '1f', '2f-left', '1f-left'),
#   [153, 67, 4290, 4376, 0.0028724761484659744]),
#  (('out', 'in', '3f', '2f'), [127, 93, 4316, 4350, 0.00043909655502738509]),
#  (('out', 'in', '2f', '2f'), [162, 57, 4281, 4386, 0.0043630080638816793]),
#  (('out', 'in', '2f', '2f-inner', '1f-left'),
#   [145, 74, 4298, 4369, 0.0019499847143447102]),
#  (('out', 'in', '1f', '1f-right', '2f', '2f-inner'),
#   [124, 94, 4319, 4349, 0.00034463307862930836]),
#  (('2f', '2f-left', '1f', '1f-right'),
#   [146, 71, 4297, 4372, 0.0022009763391508397]),
#  (('out', 'in', '1f', '1f-left', '1f-right', '1f-inner'),
#   [134, 83, 4309, 4360, 0.0010065313245862795]),
#  (('out', 'in', '2f', '2f-left', 'out'),
#   [119, 98, 4324, 4345, 0.0001693626788118463]),
#  (('out', 'in', '2f', '2f-left', '1f', '1f-right'),
#   [146, 70, 4297, 4373, 0.0022720085545030466]),
#  (('out', 'in', '1f', '2f', '2f-left', '2f-right'),
#   [118, 96, 4325, 4347, 0.00018845426025937417]),
#  (('out', 'in', '1f-right', '1f', '2f'),
#   [129, 84, 4314, 4359, 0.00079656241899028757]),
#  (('out', 'in', '1f', '2f-left', '2f-inner'),
#   [121, 92, 4322, 4351, 0.00032938892954803567]),
#  (('out', 'in', '3f', '2f-right'),
#   [111, 102, 4332, 4341, 3.1637839392528733e-05]),
#  (('out', 'in', '1f-left', '1f-right', '2f'),
#   [126, 85, 4317, 4358, 0.00066659362002552403]),
#  (('out', 'in', '1f', '1f-inner', '2f-right'),
#   [122, 89, 4321, 4354, 0.00043088622102260832]),
#  (('out', 'in', '2f', '2f-right', '1f-inner'),
#   [146, 64, 4297, 4379, 0.0027326004785866997]),
#  (('out', 'in', '2f', '1f', '1f-right', '1f-left'),
#   [150, 58, 4293, 4385, 0.003499641249773866]),
#  (('out', 'in', '2f', 'in', '1f'),
#   [145, 63, 4298, 4380, 0.0027597258582063855]),
#  (('out', 'in', '1f-right', '1f', '1f-right'),
#   [146, 61, 4297, 4382, 0.0029865037320860877]),
#  (('out', 'in', '1f', '1f-inner', '1f'),
#   [143, 64, 4300, 4379, 0.0025690438212396804]),
#  (('out', 'in', '1f', '2f-inner', '1f-left'),
#   [140, 67, 4303, 4376, 0.0021853160413571882]),
#  (('out', 'in', '2f', '2f-right', '1f', '1f-right'),
#   [152, 54, 4291, 4389, 0.0040319549454669312]),
#  (('out', 'in', '2f', '1f-left', '1f-right'),
#   [138, 68, 4305, 4375, 0.0020157502098412383]),
#  (('out', 'in', '1f', '1f-right', '1f-left', '2f'),
#   [135, 71, 4308, 4372, 0.0016794330205467389]),
#  (('out', 'in', '1f', '1f-left', '1f-inner', '1f-right'),
#   [132, 74, 4311, 4369, 0.0013752003161149329]),
#  (('out', 'in', '2f', '2f-right', '2f-inner'),
#   [117, 88, 4326, 4355, 0.00034201184343851665]),
#  (('out', 'in', '1f', '1f-right', '3f'),
#   [116, 89, 4327, 4354, 0.00029633431579989544]),
#  (('out', 'in', '1f-right', '2f', '1f-right'),
#   [150, 54, 4293, 4389, 0.0039025084022051848]),
#  (('out', 'in', '1f-right', 'in'),
#   [148, 56, 4295, 4387, 0.0035718492064935603]),
#  (('out', 'in', '2f-inner', 'out'),
#   [114, 90, 4329, 4353, 0.00023512579099360664]),
#  (('out', 'in', '2f-inner', '1f', '1f-right'),
#   [138, 65, 4305, 4378, 0.0022293279384947295]),
#  (('out', 'in', '2f', '1f-right', '1f'),
#   [135, 68, 4308, 4375, 0.0018711814951303252]),
#  (('out', 'in', '1f', '1f-inner', '1f-right', '1f-left'),
#   [130, 73, 4313, 4370, 0.001347257781540212]),
#  (('out', 'in', 'out', 'in', '1f-right'),
#   [140, 62, 4303, 4381, 0.0025665604439488732]),
#  (('out', 'in', '1f', '1f-right', '1f-left', 'out'),
#   [131, 71, 4312, 4372, 0.001502451061763721]),
#  (('out', 'in', '1f', '2f', '2f-right', '2f-left'),
#   [114, 88, 4329, 4355, 0.00027873930045974049]),
#  (('out', 'in', '1f', '1f', '1f-inner'),
#   [141, 60, 4302, 4383, 0.0027879506490932071]),
#  (('out', 'in', '1f', '1f-right', '1f-inner', '2f'),
#   [127, 74, 4316, 4369, 0.0011742541181867239]),
#  (('out', 'in', '1f-left', '2f-inner'),
#   [115, 85, 4328, 4358, 0.0003750945370728509])]

# %%
igdict = {}

for traj in freqfreqfreq2:
    igdict[traj[0]] = traj[1]
    
sortE = sorted(igdict.items(), key=lambda value: value[1][-1], reverse=True)

# %%
sortE
# Out:
# [(('out', 'in', '2f', '1f-right'),
#   [609, 305, 3834, 4138, 0.0093077842964938151]),
#  (('out', 'in', '1f', '1f'), [431, 185, 4012, 4258, 0.0087958376956862594]),
#  (('out', 'in', 'in', '1f'), [347, 144, 4096, 4299, 0.0074204189040372182]),
#  (('out', 'in', '2f', '1f', '1f-right'),
#   [381, 172, 4062, 4271, 0.0069998582169473744]),
#  (('out', 'in', '2f', '1f-left'),
#   [414, 197, 4029, 4246, 0.0068569278804576639]),
#  (('out', 'in', '1f', '2f', '1f-right'),
#   [350, 156, 4093, 4287, 0.0065599673506357981]),
#  (('out', 'in', '2f-right', '1f-right'),
#   [321, 141, 4122, 4302, 0.006158808644885605]),
#  (('out', 'in', '2f', '1f-inner'),
#   [345, 158, 4098, 4285, 0.0061199911937140916]),
#  (('out', 'in', '2f', '2f-right', '1f-right'),
#   [270, 108, 4173, 4335, 0.0060731090524346332]),
#  (('out', 'in', '1f', '1f-right'),
#   [1486, 1121, 2957, 3322, 0.0058854516458606287]),
#  (('out', 'in', '1f', '2f', '1f'),
#   [251, 98, 4192, 4345, 0.0058569702627397913]),
#  (('out', 'in', '1f-right', '1f-left'),
#   [700, 436, 3743, 4007, 0.0057564452877962857]),
#  (('out', 'in', '1f', 'in'), [293, 127, 4150, 4316, 0.0057384269724725101]),
#  (('out', 'out', 'out', 'out'), [259, 106, 4184, 4337, 0.005593630169541175]),
#  (('out', 'in', '1f', '1f-left'),
#   [1069, 754, 3374, 3689, 0.005581544098560598]),
#  (('out', 'in', '1f', 'in', '1f'),
#   [260, 108, 4183, 4335, 0.005472580436154173]),
#  (('out', 'in', '1f', '1f-right', '1f'),
#   [218, 82, 4225, 4361, 0.0053670757489980847]),
#  (('out', 'in', '1f', '2f', '1f-left'),
#   [277, 121, 4166, 4322, 0.0053320649724375446]),
#  (('out', 'in', 'out', 'in'), [283, 127, 4160, 4316, 0.0051750644054011641]),
#  (('out', 'in', '2f-left', '1f-right'),
#   [295, 136, 4148, 4307, 0.0051187201949187688]),
#  (('out', 'out', 'out', 'in'), [301, 141, 4142, 4302, 0.0050563133114865932]),
#  (('out', 'in', '2f', '1f'), [666, 428, 3777, 4015, 0.0048271636700197851]),
#  (('out', 'in', 'in', '1f-right'),
#   [211, 84, 4232, 4359, 0.0047391890038244178]),
#  (('out', 'in', '1f', '1f-right', '1f-left'),
#   [556, 342, 3887, 4101, 0.0046454558381293642]),
#  (('out', 'in', '2f', '1f', '1f-left'),
#   [249, 111, 4194, 4332, 0.0045875340273454634]),
#  (('out', 'in', '1f', '2f', '1f', '1f-right'),
#   [169, 60, 4274, 4383, 0.0044985828932254668]),
#  (('out', 'in', '2f', '2f-left', '1f-right'),
#   [260, 120, 4183, 4323, 0.0044744109802954402]),
#  (('out', 'in', '1f-right', '1f'),
#   [546, 338, 3897, 4105, 0.004449392030535182]),
#  (('out', 'in', '2f', '1f-right', '1f-left'),
#   [233, 102, 4210, 4341, 0.0044344693682517589]),
#  (('out', 'in', '1f', '2f', '1f-inner'),
#   [235, 104, 4208, 4339, 0.0043813485852356449]),
#  (('out', 'in', '2f', '2f'), [162, 57, 4281, 4386, 0.0043630080638816793]),
#  (('out', 'in', '1f', '1f', '1f-right'),
#   [236, 105, 4207, 4338, 0.0043552960435060406]),
#  (('out', 'in', '1f', '2f-right', '1f-right'),
#   [203, 84, 4240, 4359, 0.0042626078950440682]),
#  (('out', 'in', '1f-right', '1f-right'),
#   [232, 104, 4211, 4339, 0.0042157333558613397]),
#  (('out', 'in', '2f', '1f', '1f-inner'),
#   [197, 82, 4246, 4361, 0.0040898085898579684]),
#  (('out', 'in', '2f-right', '1f-left'),
#   [225, 101, 4218, 4342, 0.0040727575662324877]),
#  (('out', 'in', '2f', '2f-right', '1f', '1f-right'),
#   [152, 54, 4291, 4389, 0.0040319549454669312]),
#  (('out', 'in', '2f-inner', '1f-right'),
#   [257, 125, 4186, 4318, 0.0039465196717300977]),
#  (('out', 'in', 'out', 'in', '1f'),
#   [231, 107, 4212, 4336, 0.0039265518864838311]),
#  (('out', 'in', '1f', '1f', '1f-left'),
#   [163, 62, 4280, 4381, 0.0039108396248831445]),
#  (('out', 'in', '1f-right', '2f', '1f-right'),
#   [150, 54, 4293, 4389, 0.0039025084022051848]),
#  (('out', 'in', '2f', '2f-right', '1f-left'),
#   [195, 83, 4248, 4360, 0.0038873822226825894]),
#  (('out', 'in', '2f-left', '1f-left'),
#   [212, 96, 4231, 4347, 0.0037628706164026804]),
#  (('out', 'in', '2f-right', '1f', '1f-right'),
#   [185, 78, 4258, 4365, 0.0037462330728355031]),
#  (('out', 'in', '1f', 'out', 'in'),
#   [207, 93, 4236, 4350, 0.0037294446920080881]),
#  (('out', 'in', '1f', '2f-left', '1f-right'),
#   [193, 85, 4250, 4358, 0.0036072793710132389]),
#  (('out', 'in', '1f-right', 'in'),
#   [148, 56, 4295, 4387, 0.0035718492064935603]),
#  (('out', 'in', '2f', '1f', '1f-right', '1f-left'),
#   [150, 58, 4293, 4385, 0.003499641249773866]),
#  (('out', 'in', '2f', '2f-left', '1f-left'),
#   [184, 82, 4259, 4361, 0.0033558625673574261]),
#  (('out', 'in', '2f', '2f-right', '1f'),
#   [243, 124, 4200, 4319, 0.0033246004649449823]),
#  (('out', 'in', '2f', '1f-right', '1f-inner'),
#   [164, 69, 4279, 4374, 0.0033224981503153783]),
#  (('out', 'in', '1f', 'out', 'in', '1f'),
#   [183, 82, 4260, 4361, 0.0033013774523582562]),
#  (('out', 'in', '2f', 'in'), [174, 76, 4269, 4367, 0.0032940364555544832]),
#  (('out', 'in', 'in', '1f', '1f-right'),
#   [164, 70, 4279, 4373, 0.0032365179269625566]),
#  (('1f', 'out', 'in', '1f'), [183, 83, 4260, 4360, 0.0032222669599261122]),
#  (('out', 'in', '1f-inner', '1f-left'),
#   [420, 263, 4023, 4180, 0.0031999635672362858]),
#  (('out', 'out', 'out', 'in', '1f'),
#   [204, 98, 4239, 4345, 0.0031917997740293913]),
#  (('out', 'in', '2f-inner', '1f-left'),
#   [182, 83, 4261, 4360, 0.0031687071520958288]),
#  (('out', 'in', '2f', '2f-inner', '1f-right'),
#   [211, 105, 4232, 4338, 0.0030496020603485441]),
#  (('out', 'in', '1f', '2f-right', '1f-left'),
#   [162, 71, 4281, 4372, 0.0030410446923357926]),
#  (('out', 'in', '2f-right', '1f'),
#   [303, 174, 4140, 4269, 0.00302826583816862]),
#  (('out', 'in', '1f-right', '1f', '1f-left'),
#   [247, 132, 4196, 4311, 0.0030040166567740778]),
#  (('out', 'in', '1f-right', '1f', '1f-right'),
#   [146, 61, 4297, 4382, 0.0029865037320860877]),
#  (('out', 'in', '1f', '2f', '2f-left', '1f-right'),
#   [161, 71, 4282, 4372, 0.0029859614493540354]),
#  (('out', 'in', '1f', '2f', '2f-right', '1f-right'),
#   [156, 68, 4287, 4375, 0.0029560687494456506]),
#  (('out', 'in', '1f', '1f-right', '1f-right'),
#   [192, 93, 4251, 4350, 0.0029432158005179287]),
#  (('out', 'in', '3f', '1f-right'),
#   [161, 72, 4282, 4371, 0.0029053772890594853]),
#  (('out', 'in', '1f', 'in', '1f-right'),
#   [159, 71, 4284, 4372, 0.0028767815440681188]),
#  (('out', 'in', '1f', '2f-left', '1f-left'),
#   [153, 67, 4290, 4376, 0.0028724761484659744]),
#  (('out', 'in', '1f-right', '1f-inner'),
#   [589, 413, 3854, 4030, 0.0028415885563155552]),
#  (('out', 'in', '2f-right', '1f-inner'),
#   [170, 79, 4273, 4364, 0.0028411304262943027]),
#  (('out', 'in', '1f', '1f', '1f-inner'),
#   [141, 60, 4302, 4383, 0.0027879506490932071]),
#  (('out', 'in', '1f', '2f-inner', '1f-right'),
#   [183, 89, 4260, 4354, 0.0027755351920113469]),
#  (('out', 'in', '2f', 'in', '1f'),
#   [145, 63, 4298, 4380, 0.0027597258582063855]),
#  (('out', 'in', 'out', 'out'), [319, 192, 4124, 4251, 0.0027456639745351286]),
#  (('out', 'in', '2f', '2f-right', '1f-inner'),
#   [146, 64, 4297, 4379, 0.0027326004785866997]),
#  (('out', 'in', '1f-right', '2f', '1f-left'),
#   [152, 69, 4291, 4374, 0.0026581376367804666]),
#  (('out', 'in', '1f', '1f-inner', '1f-left'),
#   [372, 238, 4071, 4205, 0.0025852948012164978]),
#  (('out', 'in', '1f', '1f-inner', '1f'),
#   [143, 64, 4300, 4379, 0.0025690438212396804]),
#  (('out', 'in', 'out', 'in', '1f-right'),
#   [140, 62, 4303, 4381, 0.0025665604439488732]),
#  (('out', 'in', '2f-left', '1f', '1f-right'),
#   [166, 80, 4277, 4363, 0.0025624265039043692]),
#  (('out', 'out', 'in', 'out'), [300, 182, 4143, 4261, 0.002503574290575572]),
#  (('out', 'in', '1f', '1f-right', '1f-inner'),
#   [477, 328, 3966, 4115, 0.0024747932977655651]),
#  (('out', 'in', '2f-inner', '1f'),
#   [215, 117, 4228, 4326, 0.0024747866303351795]),
#  (('out', 'in', '1f-inner', '1f-right'),
#   [449, 305, 3994, 4138, 0.0024532840632578434]),
#  (('out', 'in', '1f', '1f-left', '2f'),
#   [282, 171, 4161, 4272, 0.0023491845539649336]),
#  (('out', 'in', '1f-left', '2f'),
#   [311, 195, 4132, 4248, 0.0023084286232589735]),
#  (('out', 'in', '2f', '2f-left', '1f', '1f-right'),
#   [146, 70, 4297, 4373, 0.0022720085545030466]),
#  (('out', 'in', '2f-left', '1f'),
#   [279, 171, 4164, 4272, 0.0022370566471514586]),
#  (('out', 'in', '2f-inner', '1f', '1f-right'),
#   [138, 65, 4305, 4378, 0.0022293279384947295]),
#  (('2f', '2f-left', '1f', '1f-right'),
#   [146, 71, 4297, 4372, 0.0022009763391508397]),
#  (('out', 'in', '1f-inner', '2f'),
#   [294, 184, 4149, 4259, 0.0021902835879982208]),
#  (('out', 'in', '1f', '2f-inner', '1f-left'),
#   [140, 67, 4303, 4376, 0.0021853160413571882]),
#  (('out', 'in', '3f', '1f'), [172, 90, 4271, 4353, 0.0021820754112458207]),
#  (('out', 'in', '1f-left', '1f-right'),
#   [508, 364, 3935, 4079, 0.0021493254123476913]),
#  (('out', 'out', 'in', '1f', '1f-left'),
#   [207, 118, 4236, 4325, 0.0020791068278602776]),
#  (('out', 'in', '1f-inner', '1f-right', '1f-left'),
#   [156, 80, 4287, 4363, 0.0020768531353926312]),
#  (('out', 'in', '1f', '1f-left', '1f-right'),
#   [423, 294, 4020, 4149, 0.0020597486892232064]),
#  (('out', 'in', '1f', '1f-inner', '1f-right'),
#   [390, 267, 4053, 4176, 0.0020296444235842204]),
#  (('out', 'in', '1f', '1f-left', '1f-inner'),
#   [429, 300, 4014, 4143, 0.0020284739189391221]),
#  (('out', 'in', '2f', '1f-left', '1f-right'),
#   [138, 68, 4305, 4375, 0.0020157502098412383]),
#  (('out', 'in', '1f-right', '1f-left', '2f'),
#   [172, 93, 4271, 4350, 0.0019999610637284615]),
#  (('out', 'in', '1f-right', '2f'),
#   [486, 350, 3957, 4093, 0.0019905477226457302]),
#  (('out', 'in', '2f', '2f-left', '1f'),
#   [233, 140, 4210, 4303, 0.0019848088178557877]),
#  (('out', 'in', '2f', '2f-inner', '1f-left'),
#   [145, 74, 4298, 4369, 0.0019499847143447102]),
#  (('out', 'in', '1f', '1f-inner', '2f'),
#   [265, 167, 4178, 4276, 0.0019127360447693809]),
#  (('out', 'in', '1f', '1f-inner'),
#   [1005, 822, 3438, 3621, 0.0018756587139771019]),
#  (('out', 'in', '2f', '1f-right', '1f'),
#   [135, 68, 4308, 4375, 0.0018711814951303252]),
#  (('out', 'in', '1f-left', '1f-inner'),
#   [485, 353, 3958, 4090, 0.0018706911305462759]),
#  (('out', 'out', 'in', '1f-right'),
#   [358, 245, 4085, 4198, 0.0018543600151501582]),
#  (('out', 'in', '1f-right', '1f-inner', '1f-left'),
#   [208, 124, 4235, 4319, 0.0018111349737734983]),
#  (('out', 'out', 'in', '1f-left'),
#   [229, 141, 4214, 4302, 0.0017892454118609846]),
#  (('out', 'in', '2f', '2f-inner', '1f'),
#   [168, 94, 4275, 4349, 0.001771538814259066]),
#  (('out', 'in', '1f-inner', '1f'),
#   [240, 151, 4203, 4292, 0.0017347267406705447]),
#  (('out', 'in', '1f', '1f-right', '1f-left', '2f'),
#   [135, 71, 4308, 4372, 0.0016794330205467389]),
#  (('out', 'in', '1f', '1f-right', '2f'),
#   [397, 284, 4046, 4159, 0.0016555167893372857]),
#  (('out', 'in', '1f', '1f-right', '1f-left', '1f-inner'),
#   [200, 121, 4243, 4322, 0.0016537757279525556]),
#  (('in', '1f', 'out', 'out'), [220, 137, 4223, 4306, 0.0016464810249001705]),
#  (('out', 'out', 'in', '1f', '1f-right'),
#   [298, 201, 4145, 4242, 0.001631529136597254]),
#  (('out', 'in', '1f', 'out', 'out'),
#   [219, 137, 4224, 4306, 0.0016111062541311894]),
#  (('out', 'out', 'in', '1f'), [771, 619, 3672, 3824, 0.0016022306616736426]),
#  (('out', 'out', 'in', '1f', 'out'),
#   [205, 127, 4238, 4316, 0.0015593458479497002]),
#  (('out', 'in', '1f-right', '1f-left', '1f-inner'),
#   [250, 164, 4193, 4279, 0.0015317062740167753]),
#  (('out', 'in', '1f', '1f-right', '1f-left', 'out'),
#   [131, 71, 4312, 4372, 0.001502451061763721]),
#  (('out', 'in', '1f-right', '1f', '1f-inner'),
#   [193, 119, 4250, 4324, 0.0014902928353679457]),
#  (('out', 'in', '1f', '2f'), [883, 729, 3560, 3714, 0.0014608174348673675]),
#  (('out', 'in', '1f', '1f-left', '1f-inner', '1f-right'),
#   [132, 74, 4311, 4369, 0.0013752003161149329]),
#  (('out', 'in', '1f-left', '1f'),
#   [240, 160, 4203, 4283, 0.001368872223050599]),
#  (('out', 'in', '1f-right', '1f-inner', '2f'),
#   [155, 92, 4288, 4351, 0.0013562555576583923]),
#  (('out', 'in', '1f', '1f-inner', '1f-right', '1f-left'),
#   [130, 73, 4313, 4370, 0.001347257781540212]),
#  (('out', 'in', '1f-inner', '1f', '1f-right'),
#   [148, 87, 4295, 4356, 0.0013351306587909839]),
#  (('out', 'in', '1f-right', '1f-left', 'out'),
#   [158, 96, 4285, 4347, 0.0012771866862218983]),
#  (('out', 'in', '2f', '2f-inner', '2f-left'),
#   [139, 82, 4304, 4361, 0.0012374616154032791]),
#  (('out', 'in', '1f-inner', '1f-left', '1f-right'),
#   [167, 104, 4276, 4339, 0.0012372598364899234]),
#  (('out', 'in', '1f', '1f-right', '1f-inner', '2f'),
#   [127, 74, 4316, 4369, 0.0011742541181867239]),
#  (('out', 'in', '1f-left', '1f-right', '1f-inner'),
#   [171, 109, 4272, 4334, 0.0011600079072293656]),
#  (('out', 'in', '1f', '1f-right', '1f-inner', '1f-left'),
#   [159, 100, 4284, 4343, 0.0011334378584544336]),
#  (('out', 'in', '1f', '1f-inner', '1f-left', '1f-right'),
#   [142, 87, 4301, 4356, 0.0011112501127275021]),
#  (('out', 'in', '1f', '1f-left', '1f-right', '1f-inner'),
#   [134, 83, 4309, 4360, 0.0010065313245862795]),
#  (('out', 'in', '1f', '1f-left', 'out'),
#   [237, 168, 4206, 4275, 0.0010045348336445992]),
#  (('out', 'in', '1f-left', '1f', '1f-right'),
#   [171, 113, 4272, 4330, 0.0010001037251212708]),
#  (('out', 'in', '1f', 'out'), [832, 709, 3611, 3734, 0.00096504113499285005]),
#  (('out', 'in', '1f-right', 'out'),
#   [375, 290, 4068, 4153, 0.0009557329744002141]),
#  (('out', 'in', '1f-left', '1f-inner', '1f-right'),
#   [151, 98, 4292, 4345, 0.00094922390744600627]),
#  (('out', 'in', '2f', '2f-left'),
#   [548, 447, 3895, 3996, 0.00093863777824565453]),
#  (('out', 'in', '2f-inner', '2f-left'),
#   [206, 144, 4237, 4299, 0.00093284554634776029]),
#  (('out', 'in', '2f', '2f-inner'),
#   [394, 308, 4049, 4135, 0.00093077503991811916]),
#  (('out', 'in', '1f-right', '2f-inner'),
#   [209, 148, 4234, 4295, 0.00088569794308845928]),
#  (('out', 'in', '2f-right', '2f-left'),
#   [237, 174, 4206, 4269, 0.00082504703287433756]),
#  (('out', 'in', '2f', '2f-right'),
#   [564, 468, 3879, 3975, 0.00082124520261728229]),
#  (('out', 'in', '1f', '2f', '2f-inner'),
#   [261, 195, 4182, 4248, 0.00082014096761640065]),
#  (('out', 'in', '1f-right', '2f-left'),
#   [228, 167, 4215, 4276, 0.00080336090218557921]),
#  (('out', 'in', '1f-right', '1f', '2f'),
#   [129, 84, 4314, 4359, 0.00079656241899028757]),
#  (('out', 'in', '1f', '2f', '2f-left'),
#   [338, 264, 4105, 4179, 0.00079395595890252579]),
#  (('out', 'in', '1f-left', 'out'),
#   [256, 192, 4187, 4251, 0.00078415002853349236]),
#  (('out', 'in', '1f-left', '2f-left'),
#   [133, 88, 4310, 4355, 0.00076802380547291715]),
#  (('out', 'in', '1f', '2f-left'),
#   [412, 332, 4031, 4111, 0.00076346788120351672]),
#  (('out', 'in', '1f-right', '2f', '2f-inner'),
#   [151, 104, 4292, 4339, 0.00072803747541128061]),
#  (('out', 'in', '1f-right', '2f', '2f-left'),
#   [193, 141, 4250, 4302, 0.0006855497045712422]),
#  (('out', 'in', '1f', '2f-right', '2f-left'),
#   [162, 115, 4281, 4328, 0.0006713447229877989]),
#  (('out', 'in', '1f-left', '1f-right', '2f'),
#   [126, 85, 4317, 4358, 0.00066659362002552403]),
#  (('out', 'in', '1f', '2f-inner', '2f-left'),
#   [160, 114, 4283, 4329, 0.00064983171741772594]),
#  (('out', 'in', '1f', '2f-inner'),
#   [368, 298, 4075, 4145, 0.00064675129432112399]),
#  (('out', 'in', '1f', '1f-right', 'out'),
#   [315, 251, 4128, 4192, 0.00062868791652415101]),
#  (('out', 'in', '2f', '2f-right', '2f-left'),
#   [175, 128, 4268, 4315, 0.00061511154103044419]),
#  (('out', 'in', '1f', '1f-right', '2f-right'),
#   [211, 161, 4232, 4282, 0.0005710422965711226]),
#  (('out', 'in', '1f-right', '3f'),
#   [146, 105, 4297, 4338, 0.00056191314540698922]),
#  (('out', 'in', '2f', '2f-inner', '2f-right'),
#   [137, 98, 4306, 4345, 0.00054212287052368691]),
#  (('out', 'in', '1f', '1f-right', '2f-inner'),
#   [174, 130, 4269, 4313, 0.00053710873958501271]),
#  (('out', 'in', '1f', '2f-right'),
#   [437, 369, 4006, 4074, 0.00051272676646996196]),
#  (('out', 'out', 'in', '1f', '2f'),
#   [174, 131, 4269, 4312, 0.00051126022371317248]),
#  (('out', 'in', '1f-right', '2f-right'),
#   [248, 197, 4195, 4246, 0.00050053915697723106]),
#  (('out', 'in', '1f', '1f-right', '2f-left'),
#   [190, 146, 4253, 4297, 0.00048746731356774653]),
#  (('out', 'in', '2f-left', '2f-right'),
#   [239, 190, 4204, 4253, 0.00047837193691990798]),
#  (('out', 'out', 'in', '1f-inner'),
#   [215, 169, 4228, 4274, 0.00046860441708884704]),
#  (('out', 'in', '2f-left', '2f'),
#   [156, 117, 4287, 4326, 0.00046816392040915922]),
#  (('out', 'in', '1f', '1f-right', '2f', '2f-left'),
#   [165, 125, 4278, 4318, 0.00046441953106002298]),
#  (('out', 'in', '1f-inner', '2f-right'),
#   [129, 94, 4314, 4349, 0.00045926102354543197]),
#  (('out', 'in', '2f', '2f-right', 'out'),
#   [130, 95, 4313, 4348, 0.00045525063540097221]),
#  (('out', 'in', '3f', '2f'), [127, 93, 4316, 4350, 0.00043909655502738509]),
#  (('out', 'in', '1f', '1f-right', '2f', '2f-right'),
#   [174, 134, 4269, 4309, 0.00043803895295946305]),
#  (('out', 'in', '2f-right', '2f'),
#   [201, 158, 4242, 4285, 0.00043670876725265817]),
#  (('out', 'in', '1f', '1f-inner', '2f-right'),
#   [122, 89, 4321, 4354, 0.00043088622102260832]),
#  (('out', 'in', '2f-inner', '2f-right'),
#   [196, 154, 4247, 4289, 0.00042690047797722119]),
#  (('out', 'in', '1f-left', '2f-right'),
#   [141, 106, 4302, 4337, 0.00041547256099960794]),
#  (('out', 'in', '1f', '2f', 'out'),
#   [206, 164, 4237, 4279, 0.00040467219649475972]),
#  (('out', 'out', 'in', '1f', '1f-inner'),
#   [194, 154, 4249, 4289, 0.00038927091207241471]),
#  (('out', 'in', '2f-right', 'out'),
#   [163, 127, 4280, 4316, 0.00037595819843272427]),
#  (('out', 'in', '1f-left', '2f-inner'),
#   [115, 85, 4328, 4358, 0.0003750945370728509]),
#  (('out', 'in', '1f-right', '1f-inner', 'out'),
#   [135, 103, 4308, 4340, 0.00035994219917012682]),
#  (('out', 'in', '2f', '2f-left', '2f-right'),
#   [183, 146, 4260, 4297, 0.00035149226767505759]),
#  (('out', 'in', '1f', '3f'), [248, 205, 4195, 4238, 0.00034964070464471586]),
#  (('out', 'in', '1f', '1f-right', '2f', '2f-inner'),
#   [124, 94, 4319, 4349, 0.00034463307862930836]),
#  (('out', 'in', '2f', '2f-right', '2f-inner'),
#   [117, 88, 4326, 4355, 0.00034201184343851665]),
#  (('out', 'in', '1f', '2f-left', '2f-inner'),
#   [121, 92, 4322, 4351, 0.00032938892954803567]),
#  (('out', 'in', '2f', 'out'), [363, 313, 4080, 4130, 0.00032520814380410101]),
#  (('out', 'in', '1f', '1f-right', '3f'),
#   [116, 89, 4327, 4354, 0.00029633431579989544]),
#  (('out', 'in', '1f', '2f', '2f-right', '2f-left'),
#   [114, 88, 4329, 4355, 0.00027873930045974049]),
#  (('out', 'in', '2f-right', '2f-inner'),
#   [141, 112, 4302, 4331, 0.00027834673917204178]),
#  (('out', 'in', '2f-inner', '2f'),
#   [155, 125, 4288, 4318, 0.00026992021546579092]),
#  (('out', 'in', '2f-left', '2f-inner'),
#   [172, 141, 4271, 4302, 0.00025874857510888027]),
#  (('out', 'in', '1f', '2f-left', '2f-right'),
#   [154, 125, 4289, 4318, 0.00025307232608884345]),
#  (('out', 'in', '1f', '2f', '2f-right'),
#   [333, 291, 4110, 4152, 0.00024698968156977585]),
#  (('out', 'out', 'in', '2f'), [309, 269, 4134, 4174, 0.00024052759907833288]),
#  (('out', 'in', '2f-inner', 'out'),
#   [114, 90, 4329, 4353, 0.00023512579099360664]),
#  (('out', 'in', '1f-right', '2f', '2f-right'),
#   [198, 167, 4245, 4276, 0.00022314459642069906]),
#  (('out', 'in', '1f', '2f-inner', '2f-right'),
#   [151, 125, 4292, 4318, 0.00020549590943352847]),
#  (('out', 'out', 'in', '2f-right'),
#   [126, 103, 4317, 4340, 0.00019280174955638163]),
#  (('out', 'in', '1f', '2f', '3f'),
#   [149, 124, 4294, 4319, 0.00019199831483696084]),
#  (('out', 'in', '2f-left', 'out'),
#   [138, 114, 4305, 4329, 0.00019124682014248773]),
#  (('out', 'in', '1f', '2f', '2f-left', '2f-right'),
#   [118, 96, 4325, 4347, 0.00018845426025937417]),
#  (('out', 'in', '2f', '2f-left', 'out'),
#   [119, 98, 4324, 4345, 0.0001693626788118463]),
#  (('out', 'in', '2f', '3f'), [221, 197, 4222, 4246, 0.0001174458179453719]),
#  (('out', 'in', '2f', '2f-left', '2f-inner'),
#   [131, 114, 4312, 4329, 9.8548884812976745e-05]),
#  (('out', 'in', '1f-inner', 'out'),
#   [233, 218, 4210, 4225, 4.2671850426168056e-05]),
#  (('out', 'in', '1f', '1f-inner', 'out'),
#   [210, 197, 4233, 4246, 3.5331550664485789e-05]),
#  (('out', 'in', '3f', '2f-right'),
#   [111, 102, 4332, 4341, 3.1637839392528733e-05])]

# %%
def is_subseq(x, y):
    it = iter(y)
    return all(c in it for c in x)

assert is_subseq('india', 'indonesia')
assert is_subseq('oman', 'romania')
assert is_subseq('mali', 'malawi')
assert is_subseq((''), ('a', 'b', 'c', 'd', 'e'))
assert not is_subseq('mali', 'banana')
assert not is_subseq('ais', 'indonesia')
assert not is_subseq('ca', 'abc')

# %%
xc = ('out', '1f')

# %%
def entropy(prob1, prob2):
    return(-prob1*np.log2(prob1)-prob2*np.log2(prob2))

# %%
def informationGain(a, b, c, d):
    ''' 
    a = (True, 1.0) - Subsequence, Revisit intention      
    b = (True, 0.0)       
    c = (False, 1.0)    
    d = (False, 0.0) 
    '''
    # Entropy before
    prob1a = (a+c) / (a+b+c+d)
    prob2a = 1-prob1a
    entropy_before = entropy(prob1a, prob2a)
    
    # Entropy after sequence
    prob1b = a / (a+b)
    prob2b = 1 - prob1b
    prob3b = c / (c+d)
    prob4b = 1 - prob3b
    
    entropy1 = entropy(prob1b, prob2b)
    entropy2 = entropy(prob3b, prob4b)
    entropy_after = (a+b)/(a+b+c+d)*entropy1 + (c+d)/(a+b+c+d)*entropy2
    
    IG = entropy_before-entropy_after
    
    return IG

# %%
# def countforentropy(x, traj):
#     c = is_subseq(traj, x['traj']), x['revisit_intention']
#     print (c)
#     return c

# # countforentropy(x, traj)

# %%
igdict = {}

for traj in freqfreqfreqfreq:
    c = trajs_combined_balanced.apply(lambda x: (is_subseq(traj, x['traj']), x['revisit_intention']), axis=1)
    cc = c.value_counts().sort_index(ascending=False)
    IG = informationGain(cc[0], cc[1], cc[2], cc[3])
    igdict[traj] = IG

# %%
sortE = sorted(igdict.items(), key=lambda value: value[1], reverse=True)

# %%
sortE[:30] ### Information Gain 순으로 뽑은 sequence feature (descending order)
# Out:
# [(('out', 'in', '2f', '1f-right'), 0.0093077842964938151),
#  (('out', 'in', '1f', '1f'), 0.0087958376956862594),
#  (('out', 'in', 'in', '1f'), 0.0074204189040372182),
#  (('out', 'in', '2f', '1f', '1f-right'), 0.0069998582169473744),
#  (('out', 'in', '2f', '1f-left'), 0.0068569278804576639),
#  (('out', 'in', '1f', '2f', '1f-right'), 0.0065599673506357981),
#  (('out', 'in', '2f-right', '1f-right'), 0.006158808644885605),
#  (('out', 'in', '2f', '1f-inner'), 0.0061199911937140916),
#  (('out', 'in', '2f', '2f-right', '1f-right'), 0.0060731090524346332),
#  (('out', 'in', '1f', '1f-right'), 0.0058854516458606287),
#  (('out', 'in', '1f', '2f', '1f'), 0.0058569702627397913),
#  (('out', 'in', '1f-right', '1f-left'), 0.0057564452877962857),
#  (('out', 'in', '1f', 'in'), 0.0057384269724725101),
#  (('out', 'in', '1f', '1f-left'), 0.005581544098560598),
#  (('out', 'in', '1f', 'in', '1f'), 0.005472580436154173),
#  (('out', 'in', '1f', '2f', '1f-left'), 0.0053320649724375446),
#  (('out', 'in', 'out', 'in'), 0.0051750644054011641),
#  (('out', 'in', '2f-left', '1f-right'), 0.0051187201949187688),
#  (('out', 'out', 'out', 'in'), 0.0050563133114865932),
#  (('out', 'in', '2f', '1f'), 0.0048271636700197851),
#  (('out', 'in', 'in', '1f-right'), 0.0047391890038244178),
#  (('out', 'in', '1f', '1f-right', '1f-left'), 0.0046454558381293642),
#  (('out', 'in', '2f', '1f', '1f-left'), 0.0045875340273454634),
#  (('out', 'in', '1f', '2f', '1f', '1f-right'), 0.0044985828932254668),
#  (('out', 'in', '2f', '2f-left', '1f-right'), 0.0044744109802954402),
#  (('out', 'in', '1f-right', '1f'), 0.004449392030535182),
#  (('out', 'in', '2f', '1f-right', '1f-left'), 0.0044344693682517589),
#  (('out', 'in', '1f', '2f', '1f-inner'), 0.0043813485852356449),
#  (('out', 'in', '1f', '1f', '1f-right'), 0.0043552960435060406),
#  (('out', 'in', '1f', '2f-right', '1f-right'), 0.0042626078950440682)]

# %%
# 일단은 이거를 feature로 이용하는 것까지 하고, 
# 1f-long, 1f-short 등 머무른 시간도 넣어서 해보기
# 
seqE = []
for item in sortE[:30]:
    seqE.append(item[0])
len(seqE)
# Out:
# 30

# %%
seqE
# Out:
# [('out', 'in', '2f', '1f-right'),
#  ('out', 'in', '1f', '1f'),
#  ('out', 'in', 'in', '1f'),
#  ('out', 'in', '2f', '1f', '1f-right'),
#  ('out', 'in', '2f', '1f-left'),
#  ('out', 'in', '1f', '2f', '1f-right'),
#  ('out', 'in', '2f-right', '1f-right'),
#  ('out', 'in', '2f', '1f-inner'),
#  ('out', 'in', '2f', '2f-right', '1f-right'),
#  ('out', 'in', '1f', '1f-right'),
#  ('out', 'in', '1f', '2f', '1f'),
#  ('out', 'in', '1f-right', '1f-left'),
#  ('out', 'in', '1f', 'in'),
#  ('out', 'out', 'out', 'out'),
#  ('out', 'in', '1f', '1f-left'),
#  ('out', 'in', '1f', 'in', '1f'),
#  ('out', 'in', '1f', '1f-right', '1f'),
#  ('out', 'in', '1f', '2f', '1f-left'),
#  ('out', 'in', 'out', 'in'),
#  ('out', 'in', '2f-left', '1f-right'),
#  ('out', 'out', 'out', 'in'),
#  ('out', 'in', '2f', '1f'),
#  ('out', 'in', 'in', '1f-right'),
#  ('out', 'in', '1f', '1f-right', '1f-left'),
#  ('out', 'in', '2f', '1f', '1f-left'),
#  ('out', 'in', '1f', '2f', '1f', '1f-right'),
#  ('out', 'in', '2f', '2f-left', '1f-right'),
#  ('out', 'in', '1f-right', '1f'),
#  ('out', 'in', '2f', '1f-right', '1f-left'),
#  ('out', 'in', '1f', '2f', '1f-inner')]

# %%
# for row in trajs_combined_balanced.iterrows():
#     for log in row[1]['logs']:
#         print (log)
#     break

# %%
# 포함/불포함 여부로 binary variable 만들면 됨.

def relatedfeatures(traj, seqE):
    sss = 2001
    ddd = []
    for seq in seqE:
        if is_subseq(seq, traj) == True:
            ddd.append(sss)
        sss += 1
    return ddd

def generateIGFeatureColumns(df, seqE):
    sss = 2001
    for seq in seqE:
        df[sss] = 0
        sss += 1
    for row in df.iterrows():
        for seq_ig in row[1]['seq_ig_ft']:
            df.set_value(row[0], seq_ig, 1) 
        
#     df.apply(lambda x: df.set_value('y', 1) for y in x['seq_ig_ft'], axis=1 )
    
    

def add_indoor_sequence_IG_features(df, seqE):

    newdf = df
    newdf['seq_ig_ft'] = df.apply(lambda x: relatedfeatures(x['traj'], seqE), axis=1)
    generateIGFeatureColumns(newdf, seqE)
    
#     newdf.apply(lambda x: newdf[y] = 1 for y in x)

    
    #     newdf['']
    #     seqE
#     df.traj.apply(lambda x: x)
#     print(is_subseq(seqE[0],df.traj[2]))
    return newdf
    

newdf = add_indoor_sequence_IG_features(trajs_combined_balanced, seqE)


### 확인완료. 맞게 됨.
newdf_samplerow = newdf.ix['16991_ebe19542cfead37db10244c163fbf76c']
print(newdf_samplerow)
print(newdf_samplerow['seq_ig_ft'])
# Out:
# logs                [568504, 567964, 567693, 567669, 567667, 56766...
# traj                [out, out, out, in, 1f, 1f-inner, 2f, 2f-right...
# ts                  [1468031077, 1468033418, 1468034623, 146803473...
# dwell_time          [326, 42, 1070, 955, 710, 124, 526, 488, 394, ...
# hour_start               [11, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12]
# time_start          [11:24:37, 12:03:38, 12:23:43, 12:25:38, 12:25...
# ts_end              [1468031403, 1468033460, 1468035693, 146803569...
# hour_end                 [11, 12, 12, 12, 12, 12, 12, 12, 13, 13, 13]
# device_id                            ebe19542cfead37db10244c163fbf76c
# date                                                            16991
# out                                                              1832
# in                                                               1349
# 1f                                                               1104
# 1f-inner                                                          124
# 1f-left                                                             0
# 1f-right                                                            0
# 2f                                                                526
# 2f-inner                                                            0
# 2f-left                                                             0
# 2f-right                                                          488
# 3f                                                                  0
# num_logs                                                           11
# total_dwell_time                                                 5423
# num_sp_100                                                          7
# prob_dwell_100                                                      1
# time_sp_100                                                      3591
# std_sp_100                                                    262.872
# Fri                                                                 0
# Mon                                                                 0
# Sat                                                                 1
#                                           ...
# 2001                                                                0
# 2002                                                                1
# 2003                                                                1
# 2004                                                                0
# 2005                                                                0
# 2006                                                                0
# 2007                                                                0
# 2008                                                                0
# 2009                                                                0
# 2010                                                                0
# 2011                                                                1
# 2012                                                                0
# 2013                                                                1
# 2014                                                                0
# 2015                                                                1
# 2016                                                                0
# 2017                                                                1
# 2018                                                                0
# 2019                                                                1
# 2020                                                                1
# 2021                                                                0
# 2022                                                                0
# 2023                                                                0
# 2024                                                                0
# 2025                                                                0
# 2026                                                                0
# 2027                                                                0
# 2028                                                                0
# 2029                                                                0
# 2030                                                                0
# Name: 16991_ebe19542cfead37db10244c163fbf76c, dtype: object
# [2002, 2003, 2011, 2013, 2015, 2017, 2019, 2020]

# %%
del newdf['traj2'] 
del newdf['seq_ig_ft']

# %% [markdown]
# --------------------------------------

# %% [markdown]
# 내 스크립트 파일을 라이브러리처럼 import해서 써보자.

# %%
# %load ../code/code/preprocessing.py

# %%
from code import preprocessing

import pickle
import pandas as pd
import numpy as np
from numpy import inf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-f4c0a99faff8> in <module>()
# ----> 1 from code import preprocessing
#       2
#       3 import pickle
#       4 import pandas as pd
#       5 import numpy as np
#
# ImportError: cannot import name 'preprocessing'

# %%
placeNum = str(786)

rawdata_picklePath = "../code/data/"+placeNum+"/"+placeNum+".p"
reindexed_picklePath = "../code/data/"+placeNum+"/"+placeNum+"_mpframe.p"
reindexed_picklePath2 = "../code/data/"+placeNum+"/"+placeNum+"_mpframe2.p"
statistical_picklePath = "../code/data/"+placeNum+"/"+placeNum+"_mpframe3.p"

# %%
df = pd.read_pickle(rawdata_picklePath)

# %%
mpframe3 = pd.read_pickle(statistical_picklePath)

result1 = []
result2 = []
result3 = []

for i in range(10):

    print('initial shape of the data frame: ', mpframe3.shape)
    # mpframe3 = mpframe3.reindex(np.random.permutation(mpframe3.index)).tail(5000)
    mpframe4 = preprocessing.label_balancing(mpframe3, 90, 10)
    print('Label balancing has been done: ', mpframe4.shape)
    mpframe5 = featuregenerator.add_indoor_temporal_movement_features(mpframe4)
    print('Indoor temporal movement features has been added: ', mpframe5.shape)
    mpframe6 = sequencefeaturegenerator.add_frequent_sequence_features(mpframe5, int(round(mpframe5.shape[0]*0.02)))
    print('Frequent sequence features has been added: ', mpframe6.shape)	

    df_learning1 = preprocessing.finalprocessing(mpframe4)
    df_learning2 = preprocessing.finalprocessing(mpframe5)
    df_learning3 = preprocessing.finalprocessing(mpframe6)


    data = np.asarray(df_learning1)
    data[data == inf] = 0
    X, y = data[:, 11:-1], data[:, -1].astype(int)
    # print('Number of features:', X.shape[1])
    cvresults = predict.basicDecisionTree(X, y)
    print("Result 1: ", np.mean(cvresults))
    result1.append(np.mean(cvresults))


    data = np.asarray(df_learning2)
    data[data == inf] = 0
    X, y = data[:, 11:-1], data[:, -1].astype(int)
    # print('Number of features:', X.shape[1])
    cvresults = predict.basicDecisionTree(X, y)
    print("Result 2: ", np.mean(cvresults))
    result2.append(np.mean(cvresults))


    data = np.asarray(df_learning3)
    data[data == inf] = 0
    X, y = data[:, 11:-1], data[:, -1].astype(int)
    # print('Number of features:', X.shape[1])
    cvresults = predict.basicDecisionTree(X, y)
    print("Result 3: ", np.mean(cvresults))
    result3.append(np.mean(cvresults))


print("Average results for exp 1",df_learning1.shape,": ", np.mean(result1))
print("Average results for exp 2",df_learning2.shape,": ", np.mean(result2))
print("Average results for exp 3",df_learning3.shape,": ", np.mean(result3))
# Out:
# initial shape of the data frame:  (98993, 42)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-0d8f161c0e89> in <module>()
#       9     print('initial shape of the data frame: ', mpframe3.shape)
#      10     # mpframe3 = mpframe3.reindex(np.random.permutation(mpframe3.index)).tail(5000)
# ---> 11     mpframe4 = preprocessing.label_balancing(mpframe3, 90, 10)
#      12     print('Label balancing has been done: ', mpframe4.shape)
#      13     mpframe5 = featuregenerator.add_indoor_temporal_movement_features(mpframe4)
#
# NameError: name 'preprocessing' is not defined

# %% [markdown]
# ```
# (py35) Sundongui-MacBook-Pro:code sundong$ python main.py
# ========================================
# 0:00:01.960 - Start Program
# ========================================
# initial shape of the data frame:  (98993, 42)
# label_balancing function took 484.636 ms
# Label balancing has been done:  (38442, 41)
# add_indoor_temporal_movement_features function took 5400.785 ms
# Indoor temporal movement features has been added:  (38442, 68)
# pymining package has been done
# longest subsequence has been calcualated
# ig calculation has been done
# generate_sortE function took 2120932.245 ms
# generate_seqE function took 0.244 ms
# Frequent sequence features has been added:  (38442, 837)
# Result 1:  0.679699180683
# Result 2:  0.680115819617
# Result 3:  0.680635407518
# initial shape of the data frame:  (98993, 42)
# label_balancing function took 507.315 ms
# Label balancing has been done:  (38442, 41)
# add_indoor_temporal_movement_features function took 5223.394 ms
# Indoor temporal movement features has been added:  (38442, 66)
# pymining package has been done
# longest subsequence has been calcualated
# ig calculation has been done
# generate_sortE function took 1797211.518 ms
# generate_seqE function took 0.134 ms
# Frequent sequence features has been added:  (38442, 835)
# Result 1:  0.679777116163
# Result 2:  0.679438872664
# Result 3:  0.679569446045
# initial shape of the data frame:  (98993, 42)
# label_balancing function took 438.450 ms
# Label balancing has been done:  (38442, 41)
# add_indoor_temporal_movement_features function took 5038.465 ms
# Indoor temporal movement features has been added:  (38442, 67)
# pymining package has been done
# longest subsequence has been calcualated
# ig calculation has been done
# generate_sortE function took 1849163.265 ms
# generate_seqE function took 0.138 ms
# Frequent sequence features has been added:  (38442, 836)
# Result 1:  0.681000071428
# Result 2:  0.681650787363
# Result 3:  0.681806184838
# initial shape of the data frame:  (98993, 42)
# label_balancing function took 456.566 ms
# Label balancing has been done:  (38442, 41)
# add_indoor_temporal_movement_features function took 5016.674 ms
# Indoor temporal movement features has been added:  (38442, 67)
# pymining package has been done
# longest subsequence has been calcualated
# ig calculation has been done
# generate_sortE function took 1826511.238 ms
# generate_seqE function took 0.155 ms
# Frequent sequence features has been added:  (38442, 836)
# Result 1:  0.680791887243
# Result 2:  0.679413385693
# Result 3:  0.679439035002
# initial shape of the data frame:  (98993, 42)
# label_balancing function took 451.288 ms
# Label balancing has been done:  (38442, 41)
# add_indoor_temporal_movement_features function took 5368.173 ms
# Indoor temporal movement features has been added:  (38442, 66)
# pymining package has been done
# longest subsequence has been calcualated
# ig calculation has been done
# generate_sortE function took 1913510.662 ms
# generate_seqE function took 0.152 ms
# Frequent sequence features has been added:  (38442, 835)
# Result 1:  0.681156023556
# Result 2:  0.681286502241
# Result 3:  0.680349774865
# initial shape of the data frame:  (98993, 42)
# label_balancing function took 438.086 ms
# Label balancing has been done:  (38442, 41)
# add_indoor_temporal_movement_features function took 5313.705 ms
# Indoor temporal movement features has been added:  (38442, 67)
# pymining package has been done
# longest subsequence has been calcualated
# ig calculation has been done
# generate_sortE function took 1784981.903 ms
# generate_seqE function took 0.143 ms
# Frequent sequence features has been added:  (38442, 836)
# Result 1:  0.681883809171
# Result 2:  0.68154616091
# Result 3:  0.681754236871
# initial shape of the data frame:  (98993, 42)
# label_balancing function took 499.207 ms
# Label balancing has been done:  (38442, 41)
# add_indoor_temporal_movement_features function took 5214.580 ms
# Indoor temporal movement features has been added:  (38442, 67)
# pymining package has been done
# longest subsequence has been calcualated
# ig calculation has been done
# generate_sortE function took 1889672.010 ms
# generate_seqE function took 0.139 ms
# Frequent sequence features has been added:  (38442, 836)
# Result 1:  0.682352463714
# Result 2:  0.681389992332
# Result 3:  0.681597811259
# initial shape of the data frame:  (98993, 42)
# label_balancing function took 439.690 ms
# Label balancing has been done:  (38442, 41)
# add_indoor_temporal_movement_features function took 5143.135 ms
# Indoor temporal movement features has been added:  (38442, 67)
# pymining package has been done
# longest subsequence has been calcualated
# ig calculation has been done
# generate_sortE function took 1748855.295 ms
# generate_seqE function took 0.140 ms
# Frequent sequence features has been added:  (38442, 836)
# Result 1:  0.683835564661
# Result 2:  0.683367085984
# Result 3:  0.682690910134
# initial shape of the data frame:  (98993, 42)
# label_balancing function took 443.224 ms
# Label balancing has been done:  (38442, 41)
# add_indoor_temporal_movement_features function took 5342.338 ms
# Indoor temporal movement features has been added:  (38442, 66)
# pymining package has been done
# longest subsequence has been calcualated
# ig calculation has been done
# generate_sortE function took 1894269.483 ms
# generate_seqE function took 0.143 ms
# Frequent sequence features has been added:  (38442, 835)
# Result 1:  0.680688451263
# Result 2:  0.680739668713
# Result 3:  0.680765493887
# initial shape of the data frame:  (98993, 42)
# label_balancing function took 495.460 ms
# Label balancing has been done:  (38442, 41)
# add_indoor_temporal_movement_features function took 5133.643 ms
# Indoor temporal movement features has been added:  (38442, 67)
# pymining package has been done
# longest subsequence has been calcualated
# ig calculation has been done
# generate_sortE function took 1801389.487 ms
# generate_seqE function took 0.142 ms
# Frequent sequence features has been added:  (38442, 836)
# Result 1:  0.680426966298
# Result 2:  0.682508361729
# Result 3:  0.681884431465
# Average results for exp 1 (38442, 41) :  0.681161153418
# Average results for exp 2 (38442, 836) :  0.681145663725
# Average results for exp 3 (38442, 836) :  0.681049273188
# ========================================
# 5:33:57.272 - End Program
# Elapsed time: 5:33:55.311
# ========================================
# (py35) Sundongui-MacBook-Pro:code sundong$
# ```

# %%
### 이 코드에서 계산중에 같이 collect할 수 있을거라 생각했는데 , 포기.
from collections import defaultdict

def freq_seq_enum(sequences, min_support):
    '''Enumerates all frequent sequences.

       :param sequences: A sequence of sequences.
       :param min_support: The minimal support of a set to be included.
       :rtype: A set of (frequent_sequence, support).
    '''
    freq_seqs = set()
    _freq_seq(sequences, tuple(), 0, 0, min_support, freq_seqs)
    return freq_seqs


def _freq_seq(sdb, prefix, prefix_support, revisit_support, min_support, freq_seqs):
    if prefix:
#         print('prefix: yes', prefix)
        freq_seqs.add((prefix, prefix_support, revisit_support))
#         print('freq seqs', freq_seqs)
    locally_frequents = _local_freq_items(sdb, prefix, min_support)
#     print('locally frequents', locally_frequents)
    if not locally_frequents:
#         print ('not locally frequents')
        return
    for (item, support1, support2) in locally_frequents:
        new_prefix = prefix + (item,)
        new_sdb = _project(sdb, new_prefix)
#         print('new_prefix', new_prefix)
#         print('new_sdb', new_sdb)
        _freq_seq(new_sdb, new_prefix, support1, support2, min_support, freq_seqs)


def _local_freq_items(sdb, prefix, min_support):
    items = defaultdict(int)  ## for support
    items2 = defaultdict(int)  ## for revisit_intention_support
    freq_items = []
    for entry in sdb:
        visited = set()
        for element in entry[0]:
#             print (element)
            if element not in visited:
                items[element] += 1
                items2[element] += entry[1]
                visited.add(element)
    # Sorted is optional. Just useful for debugging for now.
    for item in items:
        support = items[item] ## support
        support2 = items2[item] ## revisit_intention
        if support >= min_support:
            freq_items.append((item, support, support2))
    return freq_items


def _project(sdb, prefix):
    new_sdb = []
    if not prefix:
        return sdb
    current_prefix_item = prefix[-1]
    for entry in sdb:
        j = 0
        projection = None
        for item in entry[0]:
            if item == current_prefix_item:
                projection = (entry[0][j + 1:], entry[1])
                break
            j += 1
        if projection:
            new_sdb.append(projection)
    return new_sdb

# %%
trajs_combined_balanced['revisit_intention'].astype(int)
# Out:
# 16767_25e9517c47319ab64486403f94348dd6    0
# 16955_53f0a6276486cc80405cf534d913fcbb    0
# 16734_5b37d580c76a8c8c245cad3418349acb    0
# 16736_70968e4fb8894b74997f6f4e89b32bee    1
# 16847_e0b87d079ff087efd100c423d88d0fbd    0
# 16706_3352c133a2ee0a29ed3351ab69dae032    0
# 16760_b210865acfd2674ae0017b11271afc33    1
# 16866_ec0ff57c50c68919aa1b5d3bd9424028    0
# 16724_8eb18e0cbf9c29ea1e5ed4f98cb05171    1
# 16798_20ee02428cacb74eee06f0a155933689    0
# 16833_c751fe946b3c00c90874339929e99f06    0
# 16935_a176960c74009d94369ede0614a5288f    0
# 16764_3d2f176265bea59caaff155857c2b2e8    0
# 16732_a6a7fce63f5da450cccee8a0099d58e2    0
# 16869_56d15da75690ce19d9e8cf5f82282ce9    0
# 16941_a7bdc8d8b2b694c6f25f81f7382f41b5    0
# 16744_fe1acb395a7475844a1eb29a618ec566    0
# 16831_3e5edaf2d72ac48a405c280c54eebdee    0
# 16991_ebe19542cfead37db10244c163fbf76c    1
# 16813_7d9dc6f5f24a5ee36bbc7f1b1ecfe027    1
# 16855_7ea0e50b8a95c9c29595b323c7ce649b    1
# 16714_f59239d966989d77610087d5e9b9b802    1
# 16721_197b75b623c8e0d837d878a6b8cee4d7    0
# 16695_30af8a33b37670bd1330fe65e68eddee    1
# 16927_dedf509af2003d829b2c3dd8e718bae7    0
# 17003_9384cc5aba6646a4de72d6e874db5bf7    1
# 16682_66a114ac96ff7f6fe41b2a4808cea739    1
# 16918_1c7317b41e24897fd4912e0c6ca86744    1
# 16889_2dae56b75aed7823db01f5d6fe878fa5    1
# 16749_88ebe12af5b16d847d26a22d71f34a40    1
#                                          ..
# 16890_d258dfaa409566ebd21b5668eca43a82    0
# 16841_749f962249e927bad4d0e5d2b74ca619    0
# 16905_ccae76c88a74e406ae039ef8b62af2bc    1
# 16899_5d8365a41f8eea115920d5a449b6be9c    0
# 16717_6dfb321de77e19b0a4834a691bb793b2    0
# 16887_21efa9b0e13a0d64e80749661c1d8986    0
# 16936_9809180bc83bfedd29e0b57bde9661f6    1
# 16723_9276f24dfa557946c7e3fb7b3556527f    0
# 16796_99c859c21b16569f3772d0dbe68e9d44    1
# 16869_9eb839b744bb1dbeb4338c0af8920318    1
# 16773_334080b4178d42d45f3c5f893c9c038a    1
# 16917_16ca4376844394e9324dadc14ad36d98    0
# 16759_307a2ce4ff96bf9c8c99c2409eb202a7    1
# 16907_1c5a168af466081180ba3adf22f61bd8    1
# 16768_af314e14d153e28d550d983731aee01a    0
# 16794_a0ca5b04cf5e0e3508a73884fb6ac96e    0
# 16819_334080b4178d42d45f3c5f893c9c038a    1
# 16769_db64620755b34d91cc03ac5122c3a5b5    0
# 16703_1e8d13275c2f7738c2063c421606deaf    0
# 16816_67f4d764d911e7b8c1fc1afdf374dd28    1
# 16746_d63d9e6c9cacbf8ddbc13080487983ed    1
# 16770_3a37076dc4a46ac11a98ae97ad3e8b0d    0
# 16712_109be744121ce98cbba95fbd3385b76e    1
# 16741_cc84224455caee51b8a20612da86502d    1
# 16890_68d59e794448dd680e938b011310cac4    0
# 17005_bfdc954eaac74d58c55dbed2c5470cd9    1
# 16781_9e43b15d0c56409322f15776e970ce0e    0
# 16777_217ca89dc99254e9d835ee5e168e8c77    0
# 16744_f1118318ce0f914f1592eb1f4ad9e4de    1
# 16929_b62d90196eb3344755ba6cef21ce1b6c    1
# Name: revisit_intention, dtype: int64

# %%
trajs_combined_balanced['revisit_intention'] = trajs_combined_balanced['revisit_intention'].astype(int)
yopoup = trajs_combined_balanced.apply(lambda x: (x['traj'], x['revisit_intention']), axis=1)

# %%
sample = [(['1f-left', '1f-inner'],1),(['1f-left', '1f-right', '1f-inner'],0), (['1f-left'],1)]

sample[1]
_project(sample, ('1f-left', '1f-inner',))
_local_freq_items(sample, ('1f-inner',), 1 )
# Out:
# [('1f-inner', 2, 1), ('1f-right', 1, 0), ('1f-left', 3, 2)]

# %%
freq_seq_enum(yopoup, 200)
# Out:
# {(('1f',), 6509, 3359),
#  (('1f', '1f'), 617, 431),
#  (('1f', '1f', '1f-inner'), 201, 141),
#  (('1f', '1f', '1f-left'), 225, 163),
#  (('1f', '1f', '1f-right'), 341, 236),
#  (('1f', '1f-inner'), 1827, 1005),
#  (('1f', '1f-inner', '1f'), 207, 143),
#  (('1f', '1f-inner', '1f-left'), 610, 372),
#  (('1f', '1f-inner', '1f-left', '1f-right'), 229, 142),
#  (('1f', '1f-inner', '1f-right'), 657, 390),
#  (('1f', '1f-inner', '1f-right', '1f-left'), 203, 130),
#  (('1f', '1f-inner', '2f'), 432, 265),
#  (('1f', '1f-inner', '2f-right'), 211, 122),
#  (('1f', '1f-inner', 'out'), 407, 210),
#  (('1f', '1f-left'), 1823, 1069),
#  (('1f', '1f-left', '1f-inner'), 729, 429),
#  (('1f', '1f-left', '1f-inner', '1f-right'), 206, 132),
#  (('1f', '1f-left', '1f-right'), 717, 423),
#  (('1f', '1f-left', '1f-right', '1f-inner'), 217, 134),
#  (('1f', '1f-left', '2f'), 453, 282),
#  (('1f', '1f-left', '2f-right'), 218, 124),
#  (('1f', '1f-left', 'out'), 405, 237),
#  (('1f', '1f-right'), 2608, 1486),
#  (('1f', '1f-right', '1f'), 301, 218),
#  (('1f', '1f-right', '1f-inner'), 805, 477),
#  (('1f', '1f-right', '1f-inner', '1f-left'), 259, 159),
#  (('1f', '1f-right', '1f-inner', '2f'), 201, 127),
#  (('1f', '1f-right', '1f-left'), 898, 556),
#  (('1f', '1f-right', '1f-left', '1f-inner'), 321, 200),
#  (('1f', '1f-right', '1f-left', '2f'), 206, 135),
#  (('1f', '1f-right', '1f-left', 'out'), 202, 131),
#  (('1f', '1f-right', '1f-right'), 285, 192),
#  (('1f', '1f-right', '2f'), 681, 397),
#  (('1f', '1f-right', '2f', '2f-inner'), 218, 124),
#  (('1f', '1f-right', '2f', '2f-left'), 290, 165),
#  (('1f', '1f-right', '2f', '2f-right'), 308, 174),
#  (('1f', '1f-right', '2f-inner'), 304, 174),
#  (('1f', '1f-right', '2f-left'), 336, 190),
#  (('1f', '1f-right', '2f-right'), 372, 211),
#  (('1f', '1f-right', '3f'), 205, 116),
#  (('1f', '1f-right', 'out'), 567, 315),
#  (('1f', '2f'), 1612, 883),
#  (('1f', '2f', '1f'), 349, 251),
#  (('1f', '2f', '1f', '1f-right'), 229, 169),
#  (('1f', '2f', '1f-inner'), 339, 235),
#  (('1f', '2f', '1f-left'), 398, 277),
#  (('1f', '2f', '1f-right'), 506, 350),
#  (('1f', '2f', '2f-inner'), 456, 261),
#  (('1f', '2f', '2f-left'), 602, 338),
#  (('1f', '2f', '2f-left', '1f-right'), 232, 161),
#  (('1f', '2f', '2f-left', '2f-right'), 214, 118),
#  (('1f', '2f', '2f-right'), 624, 333),
#  (('1f', '2f', '2f-right', '1f-right'), 224, 156),
#  (('1f', '2f', '2f-right', '2f-left'), 202, 114),
#  (('1f', '2f', '3f'), 273, 149),
#  (('1f', '2f', 'out'), 370, 206),
#  (('1f', '2f-inner'), 666, 368),
#  (('1f', '2f-inner', '1f-left'), 207, 140),
#  (('1f', '2f-inner', '1f-right'), 272, 183),
#  (('1f', '2f-inner', '2f-left'), 274, 160),
#  (('1f', '2f-inner', '2f-right'), 276, 151),
#  (('1f', '2f-left'), 744, 412),
#  (('1f', '2f-left', '1f-left'), 220, 153),
#  (('1f', '2f-left', '1f-right'), 278, 193),
#  (('1f', '2f-left', '2f-inner'), 213, 121),
#  (('1f', '2f-left', '2f-right'), 279, 154),
#  (('1f', '2f-right'), 806, 437),
#  (('1f', '2f-right', '1f-left'), 233, 162),
#  (('1f', '2f-right', '1f-right'), 287, 203),
#  (('1f', '2f-right', '2f-left'), 277, 162),
#  (('1f', '3f'), 453, 248),
#  (('1f', 'in'), 421, 293),
#  (('1f', 'in', '1f'), 369, 260),
#  (('1f', 'in', '1f-right'), 230, 159),
#  (('1f', 'out'), 1543, 833),
#  (('1f', 'out', '1f'), 266, 183),
#  (('1f', 'out', 'in'), 301, 207),
#  (('1f', 'out', 'in', '1f'), 266, 183),
#  (('1f', 'out', 'out'), 357, 220),
#  (('1f-inner',), 2000, 1095),
#  (('1f-inner', '1f'), 391, 240),
#  (('1f-inner', '1f', '1f-right'), 235, 148),
#  (('1f-inner', '1f-left'), 683, 420),
#  (('1f-inner', '1f-left', '1f-right'), 271, 167),
#  (('1f-inner', '1f-right'), 754, 449),
#  (('1f-inner', '1f-right', '1f-left'), 236, 156),
#  (('1f-inner', '2f'), 478, 294),
#  (('1f-inner', '2f-right'), 223, 129),
#  (('1f-inner', 'out'), 451, 233),
#  (('1f-left',), 2015, 1167),
#  (('1f-left', '1f'), 400, 240),
#  (('1f-left', '1f', '1f-right'), 284, 171),
#  (('1f-left', '1f-inner'), 838, 485),
#  (('1f-left', '1f-inner', '1f-right'), 249, 151),
#  (('1f-left', '1f-right'), 872, 508),
#  (('1f-left', '1f-right', '1f-inner'), 280, 171),
#  (('1f-left', '1f-right', '2f'), 211, 126),
#  (('1f-left', '2f'), 506, 311),
#  (('1f-left', '2f-inner'), 200, 115),
#  (('1f-left', '2f-left'), 221, 133),
#  (('1f-left', '2f-right'), 247, 141),
#  (('1f-left', 'out'), 448, 256),
#  (('1f-right',), 3145, 1778),
#  (('1f-right', '1f'), 885, 546),
#  (('1f-right', '1f', '1f-inner'), 312, 193),
#  (('1f-right', '1f', '1f-left'), 379, 247),
#  (('1f-right', '1f', '1f-right'), 207, 146),
#  (('1f-right', '1f', '2f'), 213, 129),
#  (('1f-right', '1f-inner'), 1002, 589),
#  (('1f-right', '1f-inner', '1f-left'), 332, 208),
#  (('1f-right', '1f-inner', '2f'), 247, 155),
#  (('1f-right', '1f-inner', 'out'), 238, 135),
#  (('1f-right', '1f-left'), 1136, 700),
#  (('1f-right', '1f-left', '1f-inner'), 414, 250),
#  (('1f-right', '1f-left', '2f'), 265, 172),
#  (('1f-right', '1f-left', 'out'), 254, 158),
#  (('1f-right', '1f-right'), 336, 232),
#  (('1f-right', '2f'), 836, 486),
#  (('1f-right', '2f', '1f-left'), 221, 152),
#  (('1f-right', '2f', '1f-right'), 204, 150),
#  (('1f-right', '2f', '2f-inner'), 255, 151),
#  (('1f-right', '2f', '2f-left'), 334, 193),
#  (('1f-right', '2f', '2f-right'), 365, 198),
#  (('1f-right', '2f-inner'), 357, 209),
#  (('1f-right', '2f-left'), 395, 228),
#  (('1f-right', '2f-right'), 445, 248),
#  (('1f-right', '3f'), 251, 146),
#  (('1f-right', 'in'), 205, 148),
#  (('1f-right', 'out'), 666, 375),
#  (('2f',), 3189, 1664),
#  (('2f', '1f'), 1095, 666),
#  (('2f', '1f', '1f-inner'), 279, 197),
#  (('2f', '1f', '1f-left'), 360, 249),
#  (('2f', '1f', '1f-right'), 554, 381),
#  (('2f', '1f', '1f-right', '1f-left'), 208, 150),
#  (('2f', '1f-inner'), 503, 345),
#  (('2f', '1f-left'), 611, 414),
#  (('2f', '1f-left', '1f-right'), 206, 138),
#  (('2f', '1f-right'), 915, 609),
#  (('2f', '1f-right', '1f'), 204, 135),
#  (('2f', '1f-right', '1f-inner'), 233, 164),
#  (('2f', '1f-right', '1f-left'), 335, 233),
#  (('2f', '2f'), 219, 162),
#  (('2f', '2f-inner'), 702, 394),
#  (('2f', '2f-inner', '1f'), 262, 168),
#  (('2f', '2f-inner', '1f-left'), 219, 145),
#  (('2f', '2f-inner', '1f-right'), 316, 211),
#  (('2f', '2f-inner', '2f-left'), 221, 139),
#  (('2f', '2f-inner', '2f-right'), 235, 137),
#  (('2f', '2f-left'), 996, 548),
#  (('2f', '2f-left', '1f'), 374, 233),
#  (('2f', '2f-left', '1f', '1f-right'), 217, 146),
#  (('2f', '2f-left', '1f-left'), 266, 184),
#  (('2f', '2f-left', '1f-right'), 381, 260),
#  (('2f', '2f-left', '2f-inner'), 245, 131),
#  (('2f', '2f-left', '2f-right'), 329, 183),
#  (('2f', '2f-left', 'out'), 218, 119),
#  (('2f', '2f-right'), 1032, 564),
#  (('2f', '2f-right', '1f'), 367, 243),
#  (('2f', '2f-right', '1f', '1f-right'), 206, 152),
#  (('2f', '2f-right', '1f-inner'), 210, 146),
#  (('2f', '2f-right', '1f-left'), 278, 195),
#  (('2f', '2f-right', '1f-right'), 378, 270),
#  (('2f', '2f-right', '2f-inner'), 205, 117),
#  (('2f', '2f-right', '2f-left'), 303, 175),
#  (('2f', '2f-right', 'out'), 225, 130),
#  (('2f', '3f'), 418, 221),
#  (('2f', 'in'), 251, 174),
#  (('2f', 'in', '1f'), 209, 145),
#  (('2f', 'out'), 677, 363),
#  (('2f-inner',), 917, 505),
#  (('2f-inner', '1f'), 332, 215),
#  (('2f-inner', '1f', '1f-right'), 203, 138),
#  (('2f-inner', '1f-left'), 265, 182),
#  (('2f-inner', '1f-right'), 382, 257),
#  (('2f-inner', '2f'), 280, 155),
#  (('2f-inner', '2f-left'), 350, 206),
#  (('2f-inner', '2f-right'), 350, 196),
#  (('2f-inner', 'out'), 204, 114),
#  (('2f-left',), 1198, 657),
#  (('2f-left', '1f'), 451, 279),
#  (('2f-left', '1f', '1f-right'), 247, 166),
#  (('2f-left', '1f-inner'), 224, 156),
#  (('2f-left', '1f-left'), 308, 212),
#  (('2f-left', '1f-right'), 432, 295),
#  (('2f-left', '2f'), 273, 156),
#  (('2f-left', '2f-inner'), 313, 172),
#  (('2f-left', '2f-right'), 429, 239),
#  (('2f-left', 'out'), 253, 138),
#  (('2f-right',), 1304, 700),
#  (('2f-right', '1f'), 477, 303),
#  (('2f-right', '1f', '1f-right'), 263, 185),
#  (('2f-right', '1f-inner'), 249, 170),
#  (('2f-right', '1f-left'), 326, 225),
#  (('2f-right', '1f-right'), 462, 321),
#  (('2f-right', '2f'), 359, 201),
#  (('2f-right', '2f-inner'), 253, 141),
#  (('2f-right', '2f-left'), 411, 237),
#  (('2f-right', 'out'), 290, 163),
#  (('3f',), 756, 418),
#  (('3f', '1f'), 262, 172),
#  (('3f', '1f-right'), 233, 161),
#  (('3f', '2f'), 220, 127),
#  (('3f', '2f-right'), 213, 111),
#  (('in',), 8886, 4443),
#  (('in', '1f'), 6509, 3359),
#  (('in', '1f', '1f'), 616, 431),
#  (('in', '1f', '1f', '1f-inner'), 201, 141),
#  (('in', '1f', '1f', '1f-left'), 225, 163),
#  (('in', '1f', '1f', '1f-right'), 341, 236),
#  (('in', '1f', '1f-inner'), 1827, 1005),
#  (('in', '1f', '1f-inner', '1f'), 207, 143),
#  (('in', '1f', '1f-inner', '1f-left'), 610, 372),
#  (('in', '1f', '1f-inner', '1f-left', '1f-right'), 229, 142),
#  (('in', '1f', '1f-inner', '1f-right'), 657, 390),
#  (('in', '1f', '1f-inner', '1f-right', '1f-left'), 203, 130),
#  (('in', '1f', '1f-inner', '2f'), 432, 265),
#  (('in', '1f', '1f-inner', '2f-right'), 211, 122),
#  (('in', '1f', '1f-inner', 'out'), 407, 210),
#  (('in', '1f', '1f-left'), 1823, 1069),
#  (('in', '1f', '1f-left', '1f-inner'), 729, 429),
#  (('in', '1f', '1f-left', '1f-inner', '1f-right'), 206, 132),
#  (('in', '1f', '1f-left', '1f-right'), 717, 423),
#  (('in', '1f', '1f-left', '1f-right', '1f-inner'), 217, 134),
#  (('in', '1f', '1f-left', '2f'), 453, 282),
#  (('in', '1f', '1f-left', '2f-right'), 218, 124),
#  (('in', '1f', '1f-left', 'out'), 405, 237),
#  (('in', '1f', '1f-right'), 2607, 1486),
#  (('in', '1f', '1f-right', '1f'), 300, 218),
#  (('in', '1f', '1f-right', '1f-inner'), 805, 477),
#  (('in', '1f', '1f-right', '1f-inner', '1f-left'), 259, 159),
#  (('in', '1f', '1f-right', '1f-inner', '2f'), 201, 127),
#  (('in', '1f', '1f-right', '1f-left'), 898, 556),
#  (('in', '1f', '1f-right', '1f-left', '1f-inner'), 321, 200),
#  (('in', '1f', '1f-right', '1f-left', '2f'), 206, 135),
#  (('in', '1f', '1f-right', '1f-left', 'out'), 202, 131),
#  (('in', '1f', '1f-right', '1f-right'), 285, 192),
#  (('in', '1f', '1f-right', '2f'), 681, 397),
#  (('in', '1f', '1f-right', '2f', '2f-inner'), 218, 124),
#  (('in', '1f', '1f-right', '2f', '2f-left'), 290, 165),
#  (('in', '1f', '1f-right', '2f', '2f-right'), 308, 174),
#  (('in', '1f', '1f-right', '2f-inner'), 304, 174),
#  (('in', '1f', '1f-right', '2f-left'), 336, 190),
#  (('in', '1f', '1f-right', '2f-right'), 372, 211),
#  (('in', '1f', '1f-right', '3f'), 205, 116),
#  (('in', '1f', '1f-right', 'out'), 566, 315),
#  (('in', '1f', '2f'), 1612, 883),
#  (('in', '1f', '2f', '1f'), 349, 251),
#  (('in', '1f', '2f', '1f', '1f-right'), 229, 169),
#  (('in', '1f', '2f', '1f-inner'), 339, 235),
#  (('in', '1f', '2f', '1f-left'), 398, 277),
#  (('in', '1f', '2f', '1f-right'), 506, 350),
#  (('in', '1f', '2f', '2f-inner'), 456, 261),
#  (('in', '1f', '2f', '2f-left'), 602, 338),
#  (('in', '1f', '2f', '2f-left', '1f-right'), 232, 161),
#  (('in', '1f', '2f', '2f-left', '2f-right'), 214, 118),
#  (('in', '1f', '2f', '2f-right'), 624, 333),
#  (('in', '1f', '2f', '2f-right', '1f-right'), 224, 156),
#  (('in', '1f', '2f', '2f-right', '2f-left'), 202, 114),
#  (('in', '1f', '2f', '3f'), 273, 149),
#  (('in', '1f', '2f', 'out'), 370, 206),
#  (('in', '1f', '2f-inner'), 666, 368),
#  (('in', '1f', '2f-inner', '1f-left'), 207, 140),
#  (('in', '1f', '2f-inner', '1f-right'), 272, 183),
#  (('in', '1f', '2f-inner', '2f-left'), 274, 160),
#  (('in', '1f', '2f-inner', '2f-right'), 276, 151),
#  (('in', '1f', '2f-left'), 744, 412),
#  (('in', '1f', '2f-left', '1f-left'), 220, 153),
#  (('in', '1f', '2f-left', '1f-right'), 278, 193),
#  (('in', '1f', '2f-left', '2f-inner'), 213, 121),
#  (('in', '1f', '2f-left', '2f-right'), 279, 154),
#  (('in', '1f', '2f-right'), 806, 437),
#  (('in', '1f', '2f-right', '1f-left'), 233, 162),
#  (('in', '1f', '2f-right', '1f-right'), 287, 203),
#  (('in', '1f', '2f-right', '2f-left'), 277, 162),
#  (('in', '1f', '3f'), 453, 248),
#  (('in', '1f', 'in'), 420, 293),
#  (('in', '1f', 'in', '1f'), 368, 260),
#  (('in', '1f', 'in', '1f-right'), 230, 159),
#  (('in', '1f', 'out'), 1542, 833),
#  (('in', '1f', 'out', '1f'), 265, 183),
#  (('in', '1f', 'out', 'in'), 300, 207),
#  (('in', '1f', 'out', 'in', '1f'), 265, 183),
#  (('in', '1f', 'out', 'out'), 357, 220),
#  (('in', '1f-inner'), 2000, 1095),
#  (('in', '1f-inner', '1f'), 391, 240),
#  (('in', '1f-inner', '1f', '1f-right'), 235, 148),
#  (('in', '1f-inner', '1f-left'), 683, 420),
#  (('in', '1f-inner', '1f-left', '1f-right'), 271, 167),
#  (('in', '1f-inner', '1f-right'), 754, 449),
#  (('in', '1f-inner', '1f-right', '1f-left'), 236, 156),
#  (('in', '1f-inner', '2f'), 478, 294),
#  (('in', '1f-inner', '2f-right'), 223, 129),
#  (('in', '1f-inner', 'out'), 451, 233),
#  (('in', '1f-left'), 2015, 1167),
#  (('in', '1f-left', '1f'), 400, 240),
#  (('in', '1f-left', '1f', '1f-right'), 284, 171),
#  (('in', '1f-left', '1f-inner'), 838, 485),
#  (('in', '1f-left', '1f-inner', '1f-right'), 249, 151),
#  (('in', '1f-left', '1f-right'), 872, 508),
#  (('in', '1f-left', '1f-right', '1f-inner'), 280, 171),
#  (('in', '1f-left', '1f-right', '2f'), 211, 126),
#  (('in', '1f-left', '2f'), 506, 311),
#  (('in', '1f-left', '2f-inner'), 200, 115),
#  (('in', '1f-left', '2f-left'), 221, 133),
#  (('in', '1f-left', '2f-right'), 247, 141),
#  (('in', '1f-left', 'out'), 448, 256),
#  (('in', '1f-right'), 3144, 1778),
#  (('in', '1f-right', '1f'), 884, 546),
#  (('in', '1f-right', '1f', '1f-inner'), 312, 193),
#  (('in', '1f-right', '1f', '1f-left'), 379, 247),
#  (('in', '1f-right', '1f', '1f-right'), 207, 146),
#  (('in', '1f-right', '1f', '2f'), 213, 129),
#  (('in', '1f-right', '1f-inner'), 1002, 589),
#  (('in', '1f-right', '1f-inner', '1f-left'), 332, 208),
#  (('in', '1f-right', '1f-inner', '2f'), 247, 155),
#  (('in', '1f-right', '1f-inner', 'out'), 238, 135),
#  (('in', '1f-right', '1f-left'), 1136, 700),
#  (('in', '1f-right', '1f-left', '1f-inner'), 414, 250),
#  (('in', '1f-right', '1f-left', '2f'), 265, 172),
#  (('in', '1f-right', '1f-left', 'out'), 254, 158),
#  (('in', '1f-right', '1f-right'), 336, 232),
#  (('in', '1f-right', '2f'), 836, 486),
#  (('in', '1f-right', '2f', '1f-left'), 221, 152),
#  (('in', '1f-right', '2f', '1f-right'), 204, 150),
#  (('in', '1f-right', '2f', '2f-inner'), 255, 151),
#  (('in', '1f-right', '2f', '2f-left'), 334, 193),
#  (('in', '1f-right', '2f', '2f-right'), 365, 198),
#  (('in', '1f-right', '2f-inner'), 357, 209),
#  (('in', '1f-right', '2f-left'), 395, 228),
#  (('in', '1f-right', '2f-right'), 445, 248),
#  (('in', '1f-right', '3f'), 251, 146),
#  (('in', '1f-right', 'in'), 204, 148),
#  (('in', '1f-right', 'out'), 665, 375),
#  (('in', '2f'), 3188, 1664),
#  (('in', '2f', '1f'), 1094, 666),
#  (('in', '2f', '1f', '1f-inner'), 279, 197),
#  (('in', '2f', '1f', '1f-left'), 360, 249),
#  (('in', '2f', '1f', '1f-right'), 553, 381),
#  (('in', '2f', '1f', '1f-right', '1f-left'), 208, 150),
#  (('in', '2f', '1f-inner'), 503, 345),
#  (('in', '2f', '1f-left'), 611, 414),
#  (('in', '2f', '1f-left', '1f-right'), 206, 138),
#  (('in', '2f', '1f-right'), 914, 609),
#  (('in', '2f', '1f-right', '1f'), 203, 135),
#  (('in', '2f', '1f-right', '1f-inner'), 233, 164),
#  (('in', '2f', '1f-right', '1f-left'), 335, 233),
#  (('in', '2f', '2f'), 219, 162),
#  (('in', '2f', '2f-inner'), 702, 394),
#  (('in', '2f', '2f-inner', '1f'), 262, 168),
#  (('in', '2f', '2f-inner', '1f-left'), 219, 145),
#  (('in', '2f', '2f-inner', '1f-right'), 316, 211),
#  (('in', '2f', '2f-inner', '2f-left'), 221, 139),
#  (('in', '2f', '2f-inner', '2f-right'), 235, 137),
#  (('in', '2f', '2f-left'), 995, 548),
#  (('in', '2f', '2f-left', '1f'), 373, 233),
#  (('in', '2f', '2f-left', '1f', '1f-right'), 216, 146),
#  (('in', '2f', '2f-left', '1f-left'), 266, 184),
#  (('in', '2f', '2f-left', '1f-right'), 380, 260),
#  (('in', '2f', '2f-left', '2f-inner'), 245, 131),
#  (('in', '2f', '2f-left', '2f-right'), 329, 183),
#  (('in', '2f', '2f-left', 'out'), 217, 119),
#  (('in', '2f', '2f-right'), 1032, 564),
#  (('in', '2f', '2f-right', '1f'), 367, 243),
#  (('in', '2f', '2f-right', '1f', '1f-right'), 206, 152),
#  (('in', '2f', '2f-right', '1f-inner'), 210, 146),
#  (('in', '2f', '2f-right', '1f-left'), 278, 195),
#  (('in', '2f', '2f-right', '1f-right'), 378, 270),
#  (('in', '2f', '2f-right', '2f-inner'), 205, 117),
#  (('in', '2f', '2f-right', '2f-left'), 303, 175),
#  (('in', '2f', '2f-right', 'out'), 225, 130),
#  (('in', '2f', '3f'), 418, 221),
#  (('in', '2f', 'in'), 250, 174),
#  (('in', '2f', 'in', '1f'), 208, 145),
#  (('in', '2f', 'out'), 676, 363),
#  (('in', '2f-inner'), 917, 505),
#  (('in', '2f-inner', '1f'), 332, 215),
#  (('in', '2f-inner', '1f', '1f-right'), 203, 138),
#  (('in', '2f-inner', '1f-left'), 265, 182),
#  (('in', '2f-inner', '1f-right'), 382, 257),
#  (('in', '2f-inner', '2f'), 280, 155),
#  (('in', '2f-inner', '2f-left'), 350, 206),
#  (('in', '2f-inner', '2f-right'), 350, 196),
#  (('in', '2f-inner', 'out'), 204, 114),
#  (('in', '2f-left'), 1197, 657),
#  (('in', '2f-left', '1f'), 450, 279),
#  (('in', '2f-left', '1f', '1f-right'), 246, 166),
#  (('in', '2f-left', '1f-inner'), 224, 156),
#  (('in', '2f-left', '1f-left'), 308, 212),
#  (('in', '2f-left', '1f-right'), 431, 295),
#  (('in', '2f-left', '2f'), 273, 156),
#  (('in', '2f-left', '2f-inner'), 313, 172),
#  (('in', '2f-left', '2f-right'), 429, 239),
#  (('in', '2f-left', 'out'), 252, 138),
#  (('in', '2f-right'), 1304, 700),
#  (('in', '2f-right', '1f'), 477, 303),
#  (('in', '2f-right', '1f', '1f-right'), 263, 185),
#  (('in', '2f-right', '1f-inner'), 249, 170),
#  (('in', '2f-right', '1f-left'), 326, 225),
#  (('in', '2f-right', '1f-right'), 462, 321),
#  (('in', '2f-right', '2f'), 359, 201),
#  (('in', '2f-right', '2f-inner'), 253, 141),
#  (('in', '2f-right', '2f-left'), 411, 237),
#  (('in', '2f-right', 'out'), 290, 163),
#  (('in', '3f'), 756, 418),
#  (('in', '3f', '1f'), 262, 172),
#  (('in', '3f', '1f-right'), 233, 161),
#  (('in', '3f', '2f'), 220, 127),
#  (('in', '3f', '2f-right'), 213, 111),
#  (('in', 'in'), 603, 425),
#  (('in', 'in', '1f'), 491, 347),
#  (('in', 'in', '1f', '1f-right'), 234, 164),
#  (('in', 'in', '1f-right'), 295, 211),
#  (('in', 'out'), 2139, 1144),
#  (('in', 'out', '1f'), 338, 231),
#  (('in', 'out', '1f-right'), 202, 140),
#  (('in', 'out', 'in'), 410, 283),
#  (('in', 'out', 'in', '1f'), 338, 231),
#  (('in', 'out', 'in', '1f-right'), 202, 140),
#  (('in', 'out', 'out'), 513, 321),
#  (('out',), 8885, 4442),
#  (('out', '1f'), 6507, 3357),
#  (('out', '1f', '1f'), 616, 431),
#  (('out', '1f', '1f', '1f-inner'), 201, 141),
#  (('out', '1f', '1f', '1f-left'), 225, 163),
#  (('out', '1f', '1f', '1f-right'), 341, 236),
#  (('out', '1f', '1f-inner'), 1827, 1005),
#  (('out', '1f', '1f-inner', '1f'), 207, 143),
#  (('out', '1f', '1f-inner', '1f-left'), 610, 372),
#  (('out', '1f', '1f-inner', '1f-left', '1f-right'), 229, 142),
#  (('out', '1f', '1f-inner', '1f-right'), 657, 390),
#  (('out', '1f', '1f-inner', '1f-right', '1f-left'), 203, 130),
#  (('out', '1f', '1f-inner', '2f'), 432, 265),
#  (('out', '1f', '1f-inner', '2f-right'), 211, 122),
#  (('out', '1f', '1f-inner', 'out'), 407, 210),
#  (('out', '1f', '1f-left'), 1823, 1069),
#  (('out', '1f', '1f-left', '1f-inner'), 729, 429),
#  (('out', '1f', '1f-left', '1f-inner', '1f-right'), 206, 132),
#  (('out', '1f', '1f-left', '1f-right'), 717, 423),
#  (('out', '1f', '1f-left', '1f-right', '1f-inner'), 217, 134),
#  (('out', '1f', '1f-left', '2f'), 453, 282),
#  (('out', '1f', '1f-left', '2f-right'), 218, 124),
#  (('out', '1f', '1f-left', 'out'), 405, 237),
#  (('out', '1f', '1f-right'), 2607, 1486),
#  (('out', '1f', '1f-right', '1f'), 300, 218),
#  (('out', '1f', '1f-right', '1f-inner'), 805, 477),
#  (('out', '1f', '1f-right', '1f-inner', '1f-left'), 259, 159),
#  (('out', '1f', '1f-right', '1f-inner', '2f'), 201, 127),
#  (('out', '1f', '1f-right', '1f-left'), 898, 556),
#  (('out', '1f', '1f-right', '1f-left', '1f-inner'), 321, 200),
#  (('out', '1f', '1f-right', '1f-left', '2f'), 206, 135),
#  (('out', '1f', '1f-right', '1f-left', 'out'), 202, 131),
#  (('out', '1f', '1f-right', '1f-right'), 285, 192),
#  (('out', '1f', '1f-right', '2f'), 681, 397),
#  (('out', '1f', '1f-right', '2f', '2f-inner'), 218, 124),
#  (('out', '1f', '1f-right', '2f', '2f-left'), 290, 165),
#  (('out', '1f', '1f-right', '2f', '2f-right'), 308, 174),
#  (('out', '1f', '1f-right', '2f-inner'), 304, 174),
#  (('out', '1f', '1f-right', '2f-left'), 336, 190),
#  (('out', '1f', '1f-right', '2f-right'), 372, 211),
#  (('out', '1f', '1f-right', '3f'), 205, 116),
#  (('out', '1f', '1f-right', 'out'), 566, 315),
#  (('out', '1f', '2f'), 1612, 883),
#  (('out', '1f', '2f', '1f'), 349, 251),
#  (('out', '1f', '2f', '1f', '1f-right'), 229, 169),
#  (('out', '1f', '2f', '1f-inner'), 339, 235),
#  (('out', '1f', '2f', '1f-left'), 398, 277),
#  (('out', '1f', '2f', '1f-right'), 506, 350),
#  (('out', '1f', '2f', '2f-inner'), 456, 261),
#  (('out', '1f', '2f', '2f-left'), 602, 338),
#  (('out', '1f', '2f', '2f-left', '1f-right'), 232, 161),
#  (('out', '1f', '2f', '2f-left', '2f-right'), 214, 118),
#  (('out', '1f', '2f', '2f-right'), 624, 333),
#  (('out', '1f', '2f', '2f-right', '1f-right'), 224, 156),
#  (('out', '1f', '2f', '2f-right', '2f-left'), 202, 114),
#  (('out', '1f', '2f', '3f'), 273, 149),
#  (('out', '1f', '2f', 'out'), 370, 206),
#  (('out', '1f', '2f-inner'), 666, 368),
#  (('out', '1f', '2f-inner', '1f-left'), 207, 140),
#  (('out', '1f', '2f-inner', '1f-right'), 272, 183),
#  (('out', '1f', '2f-inner', '2f-left'), 274, 160),
#  (('out', '1f', '2f-inner', '2f-right'), 276, 151),
#  (('out', '1f', '2f-left'), 744, 412),
#  (('out', '1f', '2f-left', '1f-left'), 220, 153),
#  (('out', '1f', '2f-left', '1f-right'), 278, 193),
#  (('out', '1f', '2f-left', '2f-inner'), 213, 121),
#  (('out', '1f', '2f-left', '2f-right'), 279, 154),
#  (('out', '1f', '2f-right'), 806, 437),
#  (('out', '1f', '2f-right', '1f-left'), 233, 162),
#  (('out', '1f', '2f-right', '1f-right'), 287, 203),
#  (('out', '1f', '2f-right', '2f-left'), 277, 162),
#  (('out', '1f', '3f'), 453, 248),
#  (('out', '1f', 'in'), 420, 293),
#  (('out', '1f', 'in', '1f'), 368, 260),
#  (('out', '1f', 'in', '1f-right'), 230, 159),
#  (('out', '1f', 'out'), 1541, 832),
#  (('out', '1f', 'out', '1f'), 265, 183),
#  (('out', '1f', 'out', 'in'), 300, 207),
#  (('out', '1f', 'out', 'in', '1f'), 265, 183),
#  (('out', '1f', 'out', 'out'), 356, 219),
#  (('out', '1f-inner'), 2000, 1095),
#  (('out', '1f-inner', '1f'), 391, 240),
#  (('out', '1f-inner', '1f', '1f-right'), 235, 148),
#  (('out', '1f-inner', '1f-left'), 683, 420),
#  (('out', '1f-inner', '1f-left', '1f-right'), 271, 167),
#  (('out', '1f-inner', '1f-right'), 754, 449),
#  (('out', '1f-inner', '1f-right', '1f-left'), 236, 156),
#  (('out', '1f-inner', '2f'), 478, 294),
#  (('out', '1f-inner', '2f-right'), 223, 129),
#  (('out', '1f-inner', 'out'), 451, 233),
#  (('out', '1f-left'), 2015, 1167),
#  (('out', '1f-left', '1f'), 400, 240),
#  (('out', '1f-left', '1f', '1f-right'), 284, 171),
#  (('out', '1f-left', '1f-inner'), 838, 485),
#  (('out', '1f-left', '1f-inner', '1f-right'), 249, 151),
#  (('out', '1f-left', '1f-right'), 872, 508),
#  (('out', '1f-left', '1f-right', '1f-inner'), 280, 171),
#  (('out', '1f-left', '1f-right', '2f'), 211, 126),
#  (('out', '1f-left', '2f'), 506, 311),
#  (('out', '1f-left', '2f-inner'), 200, 115),
#  (('out', '1f-left', '2f-left'), 221, 133),
#  (('out', '1f-left', '2f-right'), 247, 141),
#  (('out', '1f-left', 'out'), 448, 256),
#  (('out', '1f-right'), 3144, 1778),
#  (('out', '1f-right', '1f'), 884, 546),
#  (('out', '1f-right', '1f', '1f-inner'), 312, 193),
#  (('out', '1f-right', '1f', '1f-left'), 379, 247),
#  (('out', '1f-right', '1f', '1f-right'), 207, 146),
#  (('out', '1f-right', '1f', '2f'), 213, 129),
#  (('out', '1f-right', '1f-inner'), 1002, 589),
#  (('out', '1f-right', '1f-inner', '1f-left'), 332, 208),
#  (('out', '1f-right', '1f-inner', '2f'), 247, 155),
#  (('out', '1f-right', '1f-inner', 'out'), 238, 135),
#  (('out', '1f-right', '1f-left'), 1136, 700),
#  (('out', '1f-right', '1f-left', '1f-inner'), 414, 250),
#  (('out', '1f-right', '1f-left', '2f'), 265, 172),
#  (('out', '1f-right', '1f-left', 'out'), 254, 158),
#  (('out', '1f-right', '1f-right'), 336, 232),
#  (('out', '1f-right', '2f'), 836, 486),
#  (('out', '1f-right', '2f', '1f-left'), 221, 152),
#  (('out', '1f-right', '2f', '1f-right'), 204, 150),
#  (('out', '1f-right', '2f', '2f-inner'), 255, 151),
#  (('out', '1f-right', '2f', '2f-left'), 334, 193),
#  (('out', '1f-right', '2f', '2f-right'), 365, 198),
#  (('out', '1f-right', '2f-inner'), 357, 209),
#  (('out', '1f-right', '2f-left'), 395, 228),
#  (('out', '1f-right', '2f-right'), 445, 248),
#  (('out', '1f-right', '3f'), 251, 146),
#  (('out', '1f-right', 'in'), 204, 148),
#  (('out', '1f-right', 'out'), 665, 375),
#  (('out', '2f'), 3188, 1664),
#  (('out', '2f', '1f'), 1094, 666),
#  (('out', '2f', '1f', '1f-inner'), 279, 197),
#  (('out', '2f', '1f', '1f-left'), 360, 249),
#  (('out', '2f', '1f', '1f-right'), 553, 381),
#  (('out', '2f', '1f', '1f-right', '1f-left'), 208, 150),
#  (('out', '2f', '1f-inner'), 503, 345),
#  (('out', '2f', '1f-left'), 611, 414),
#  (('out', '2f', '1f-left', '1f-right'), 206, 138),
#  (('out', '2f', '1f-right'), 914, 609),
#  (('out', '2f', '1f-right', '1f'), 203, 135),
#  (('out', '2f', '1f-right', '1f-inner'), 233, 164),
#  (('out', '2f', '1f-right', '1f-left'), 335, 233),
#  (('out', '2f', '2f'), 219, 162),
#  (('out', '2f', '2f-inner'), 702, 394),
#  (('out', '2f', '2f-inner', '1f'), 262, 168),
#  (('out', '2f', '2f-inner', '1f-left'), 219, 145),
#  (('out', '2f', '2f-inner', '1f-right'), 316, 211),
#  (('out', '2f', '2f-inner', '2f-left'), 221, 139),
#  (('out', '2f', '2f-inner', '2f-right'), 235, 137),
#  (('out', '2f', '2f-left'), 995, 548),
#  (('out', '2f', '2f-left', '1f'), 373, 233),
#  (('out', '2f', '2f-left', '1f', '1f-right'), 216, 146),
#  (('out', '2f', '2f-left', '1f-left'), 266, 184),
#  (('out', '2f', '2f-left', '1f-right'), 380, 260),
#  (('out', '2f', '2f-left', '2f-inner'), 245, 131),
#  (('out', '2f', '2f-left', '2f-right'), 329, 183),
#  (('out', '2f', '2f-left', 'out'), 217, 119),
#  (('out', '2f', '2f-right'), 1032, 564),
#  (('out', '2f', '2f-right', '1f'), 367, 243),
#  (('out', '2f', '2f-right', '1f', '1f-right'), 206, 152),
#  (('out', '2f', '2f-right', '1f-inner'), 210, 146),
#  (('out', '2f', '2f-right', '1f-left'), 278, 195),
#  (('out', '2f', '2f-right', '1f-right'), 378, 270),
#  (('out', '2f', '2f-right', '2f-inner'), 205, 117),
#  (('out', '2f', '2f-right', '2f-left'), 303, 175),
#  (('out', '2f', '2f-right', 'out'), 225, 130),
#  (('out', '2f', '3f'), 418, 221),
#  (('out', '2f', 'in'), 250, 174),
#  (('out', '2f', 'in', '1f'), 208, 145),
#  (('out', '2f', 'out'), 676, 363),
#  (('out', '2f-inner'), 917, 505),
#  (('out', '2f-inner', '1f'), 332, 215),
#  (('out', '2f-inner', '1f', '1f-right'), 203, 138),
#  (('out', '2f-inner', '1f-left'), 265, 182),
#  (('out', '2f-inner', '1f-right'), 382, 257),
#  (('out', '2f-inner', '2f'), 280, 155),
#  (('out', '2f-inner', '2f-left'), 350, 206),
#  (('out', '2f-inner', '2f-right'), 350, 196),
#  (('out', '2f-inner', 'out'), 204, 114),
#  (('out', '2f-left'), 1197, 657),
#  (('out', '2f-left', '1f'), 450, 279),
#  (('out', '2f-left', '1f', '1f-right'), 246, 166),
#  (('out', '2f-left', '1f-inner'), 224, 156),
#  (('out', '2f-left', '1f-left'), 308, 212),
#  (('out', '2f-left', '1f-right'), 431, 295),
#  (('out', '2f-left', '2f'), 273, 156),
#  (('out', '2f-left', '2f-inner'), 313, 172),
#  (('out', '2f-left', '2f-right'), 429, 239),
#  (('out', '2f-left', 'out'), 252, 138),
#  (('out', '2f-right'), 1304, 700),
#  (('out', '2f-right', '1f'), 477, 303),
#  (('out', '2f-right', '1f', '1f-right'), 263, 185),
#  (('out', '2f-right', '1f-inner'), 249, 170),
#  (('out', '2f-right', '1f-left'), 326, 225),
#  (('out', '2f-right', '1f-right'), 462, 321),
#  (('out', '2f-right', '2f'), 359, 201),
#  (('out', '2f-right', '2f-inner'), 253, 141),
#  (('out', '2f-right', '2f-left'), 411, 237),
#  (('out', '2f-right', 'out'), 290, 163),
#  (('out', '3f'), 756, 418),
#  (('out', '3f', '1f'), 262, 172),
#  (('out', '3f', '1f-right'), 233, 161),
#  (('out', '3f', '2f'), 220, 127),
#  (('out', '3f', '2f-right'), 213, 111),
#  (('out', 'in'), 8882, 4439),
#  (('out', 'in', '1f'), 6507, 3357),
#  (('out', 'in', '1f', '1f'), 616, 431),
#  (('out', 'in', '1f', '1f', '1f-inner'), 201, 141),
#  (('out', 'in', '1f', '1f', '1f-left'), 225, 163),
#  (('out', 'in', '1f', '1f', '1f-right'), 341, 236),
#  (('out', 'in', '1f', '1f-inner'), 1827, 1005),
#  (('out', 'in', '1f', '1f-inner', '1f'), 207, 143),
#  (('out', 'in', '1f', '1f-inner', '1f-left'), 610, 372),
#  (('out', 'in', '1f', '1f-inner', '1f-left', '1f-right'), 229, 142),
#  (('out', 'in', '1f', '1f-inner', '1f-right'), 657, 390),
#  (('out', 'in', '1f', '1f-inner', '1f-right', '1f-left'), 203, 130),
#  (('out', 'in', '1f', '1f-inner', '2f'), 432, 265),
#  (('out', 'in', '1f', '1f-inner', '2f-right'), 211, 122),
#  (('out', 'in', '1f', '1f-inner', 'out'), 407, 210),
#  (('out', 'in', '1f', '1f-left'), 1823, 1069),
#  (('out', 'in', '1f', '1f-left', '1f-inner'), 729, 429),
#  (('out', 'in', '1f', '1f-left', '1f-inner', '1f-right'), 206, 132),
#  (('out', 'in', '1f', '1f-left', '1f-right'), 717, 423),
#  (('out', 'in', '1f', '1f-left', '1f-right', '1f-inner'), 217, 134),
#  (('out', 'in', '1f', '1f-left', '2f'), 453, 282),
#  (('out', 'in', '1f', '1f-left', '2f-right'), 218, 124),
#  (('out', 'in', '1f', '1f-left', 'out'), 405, 237),
#  (('out', 'in', '1f', '1f-right'), 2607, 1486),
#  (('out', 'in', '1f', '1f-right', '1f'), 300, 218),
#  (('out', 'in', '1f', '1f-right', '1f-inner'), 805, 477),
#  (('out', 'in', '1f', '1f-right', '1f-inner', '1f-left'), 259, 159),
#  (('out', 'in', '1f', '1f-right', '1f-inner', '2f'), 201, 127),
#  (('out', 'in', '1f', '1f-right', '1f-left'), 898, 556),
#  (('out', 'in', '1f', '1f-right', '1f-left', '1f-inner'), 321, 200),
#  (('out', 'in', '1f', '1f-right', '1f-left', '2f'), 206, 135),
#  (('out', 'in', '1f', '1f-right', '1f-left', 'out'), 202, 131),
#  (('out', 'in', '1f', '1f-right', '1f-right'), 285, 192),
#  (('out', 'in', '1f', '1f-right', '2f'), 681, 397),
#  (('out', 'in', '1f', '1f-right', '2f', '2f-inner'), 218, 124),
#  (('out', 'in', '1f', '1f-right', '2f', '2f-left'), 290, 165),
#  (('out', 'in', '1f', '1f-right', '2f', '2f-right'), 308, 174),
#  (('out', 'in', '1f', '1f-right', '2f-inner'), 304, 174),
#  (('out', 'in', '1f', '1f-right', '2f-left'), 336, 190),
#  (('out', 'in', '1f', '1f-right', '2f-right'), 372, 211),
#  (('out', 'in', '1f', '1f-right', '3f'), 205, 116),
#  (('out', 'in', '1f', '1f-right', 'out'), 566, 315),
#  (('out', 'in', '1f', '2f'), 1612, 883),
#  (('out', 'in', '1f', '2f', '1f'), 349, 251),
#  (('out', 'in', '1f', '2f', '1f', '1f-right'), 229, 169),
#  (('out', 'in', '1f', '2f', '1f-inner'), 339, 235),
#  (('out', 'in', '1f', '2f', '1f-left'), 398, 277),
#  (('out', 'in', '1f', '2f', '1f-right'), 506, 350),
#  (('out', 'in', '1f', '2f', '2f-inner'), 456, 261),
#  (('out', 'in', '1f', '2f', '2f-left'), 602, 338),
#  (('out', 'in', '1f', '2f', '2f-left', '1f-right'), 232, 161),
#  (('out', 'in', '1f', '2f', '2f-left', '2f-right'), 214, 118),
#  (('out', 'in', '1f', '2f', '2f-right'), 624, 333),
#  (('out', 'in', '1f', '2f', '2f-right', '1f-right'), 224, 156),
#  (('out', 'in', '1f', '2f', '2f-right', '2f-left'), 202, 114),
#  (('out', 'in', '1f', '2f', '3f'), 273, 149),
#  (('out', 'in', '1f', '2f', 'out'), 370, 206),
#  (('out', 'in', '1f', '2f-inner'), 666, 368),
#  (('out', 'in', '1f', '2f-inner', '1f-left'), 207, 140),
#  (('out', 'in', '1f', '2f-inner', '1f-right'), 272, 183),
#  (('out', 'in', '1f', '2f-inner', '2f-left'), 274, 160),
#  (('out', 'in', '1f', '2f-inner', '2f-right'), 276, 151),
#  (('out', 'in', '1f', '2f-left'), 744, 412),
#  (('out', 'in', '1f', '2f-left', '1f-left'), 220, 153),
#  (('out', 'in', '1f', '2f-left', '1f-right'), 278, 193),
#  (('out', 'in', '1f', '2f-left', '2f-inner'), 213, 121),
#  (('out', 'in', '1f', '2f-left', '2f-right'), 279, 154),
#  (('out', 'in', '1f', '2f-right'), 806, 437),
#  (('out', 'in', '1f', '2f-right', '1f-left'), 233, 162),
#  (('out', 'in', '1f', '2f-right', '1f-right'), 287, 203),
#  (('out', 'in', '1f', '2f-right', '2f-left'), 277, 162),
#  (('out', 'in', '1f', '3f'), 453, 248),
#  (('out', 'in', '1f', 'in'), 420, 293),
#  (('out', 'in', '1f', 'in', '1f'), 368, 260),
#  (('out', 'in', '1f', 'in', '1f-right'), 230, 159),
#  (('out', 'in', '1f', 'out'), 1541, 832),
#  (('out', 'in', '1f', 'out', '1f'), 265, 183),
#  (('out', 'in', '1f', 'out', 'in'), 300, 207),
#  (('out', 'in', '1f', 'out', 'in', '1f'), 265, 183),
#  (('out', 'in', '1f', 'out', 'out'), 356, 219),
#  (('out', 'in', '1f-inner'), 2000, 1095),
#  (('out', 'in', '1f-inner', '1f'), 391, 240),
#  (('out', 'in', '1f-inner', '1f', '1f-right'), 235, 148),
#  (('out', 'in', '1f-inner', '1f-left'), 683, 420),
#  (('out', 'in', '1f-inner', '1f-left', '1f-right'), 271, 167),
#  (('out', 'in', '1f-inner', '1f-right'), 754, 449),
#  (('out', 'in', '1f-inner', '1f-right', '1f-left'), 236, 156),
#  (('out', 'in', '1f-inner', '2f'), 478, 294),
#  (('out', 'in', '1f-inner', '2f-right'), 223, 129),
#  (('out', 'in', '1f-inner', 'out'), 451, 233),
#  (('out', 'in', '1f-left'), 2015, 1167),
#  (('out', 'in', '1f-left', '1f'), 400, 240),
#  (('out', 'in', '1f-left', '1f', '1f-right'), 284, 171),
#  (('out', 'in', '1f-left', '1f-inner'), 838, 485),
#  (('out', 'in', '1f-left', '1f-inner', '1f-right'), 249, 151),
#  (('out', 'in', '1f-left', '1f-right'), 872, 508),
#  (('out', 'in', '1f-left', '1f-right', '1f-inner'), 280, 171),
#  (('out', 'in', '1f-left', '1f-right', '2f'), 211, 126),
#  (('out', 'in', '1f-left', '2f'), 506, 311),
#  (('out', 'in', '1f-left', '2f-inner'), 200, 115),
#  (('out', 'in', '1f-left', '2f-left'), 221, 133),
#  (('out', 'in', '1f-left', '2f-right'), 247, 141),
#  (('out', 'in', '1f-left', 'out'), 448, 256),
#  (('out', 'in', '1f-right'), 3144, 1778),
#  (('out', 'in', '1f-right', '1f'), 884, 546),
#  (('out', 'in', '1f-right', '1f', '1f-inner'), 312, 193),
#  (('out', 'in', '1f-right', '1f', '1f-left'), 379, 247),
#  (('out', 'in', '1f-right', '1f', '1f-right'), 207, 146),
#  (('out', 'in', '1f-right', '1f', '2f'), 213, 129),
#  (('out', 'in', '1f-right', '1f-inner'), 1002, 589),
#  (('out', 'in', '1f-right', '1f-inner', '1f-left'), 332, 208),
#  (('out', 'in', '1f-right', '1f-inner', '2f'), 247, 155),
#  (('out', 'in', '1f-right', '1f-inner', 'out'), 238, 135),
#  (('out', 'in', '1f-right', '1f-left'), 1136, 700),
#  (('out', 'in', '1f-right', '1f-left', '1f-inner'), 414, 250),
#  (('out', 'in', '1f-right', '1f-left', '2f'), 265, 172),
#  (('out', 'in', '1f-right', '1f-left', 'out'), 254, 158),
#  (('out', 'in', '1f-right', '1f-right'), 336, 232),
#  (('out', 'in', '1f-right', '2f'), 836, 486),
#  (('out', 'in', '1f-right', '2f', '1f-left'), 221, 152),
#  (('out', 'in', '1f-right', '2f', '1f-right'), 204, 150),
#  (('out', 'in', '1f-right', '2f', '2f-inner'), 255, 151),
#  (('out', 'in', '1f-right', '2f', '2f-left'), 334, 193),
#  (('out', 'in', '1f-right', '2f', '2f-right'), 365, 198),
#  (('out', 'in', '1f-right', '2f-inner'), 357, 209),
#  (('out', 'in', '1f-right', '2f-left'), 395, 228),
#  (('out', 'in', '1f-right', '2f-right'), 445, 248),
#  (('out', 'in', '1f-right', '3f'), 251, 146),
#  (('out', 'in', '1f-right', 'in'), 204, 148),
#  (('out', 'in', '1f-right', 'out'), 665, 375),
#  (('out', 'in', '2f'), 3188, 1664),
#  (('out', 'in', '2f', '1f'), 1094, 666),
#  (('out', 'in', '2f', '1f', '1f-inner'), 279, 197),
#  (('out', 'in', '2f', '1f', '1f-left'), 360, 249),
#  (('out', 'in', '2f', '1f', '1f-right'), 553, 381),
#  (('out', 'in', '2f', '1f', '1f-right', '1f-left'), 208, 150),
#  (('out', 'in', '2f', '1f-inner'), 503, 345),
#  (('out', 'in', '2f', '1f-left'), 611, 414),
#  (('out', 'in', '2f', '1f-left', '1f-right'), 206, 138),
#  (('out', 'in', '2f', '1f-right'), 914, 609),
#  (('out', 'in', '2f', '1f-right', '1f'), 203, 135),
#  (('out', 'in', '2f', '1f-right', '1f-inner'), 233, 164),
#  (('out', 'in', '2f', '1f-right', '1f-left'), 335, 233),
#  (('out', 'in', '2f', '2f'), 219, 162),
#  (('out', 'in', '2f', '2f-inner'), 702, 394),
#  (('out', 'in', '2f', '2f-inner', '1f'), 262, 168),
#  (('out', 'in', '2f', '2f-inner', '1f-left'), 219, 145),
#  (('out', 'in', '2f', '2f-inner', '1f-right'), 316, 211),
#  (('out', 'in', '2f', '2f-inner', '2f-left'), 221, 139),
#  (('out', 'in', '2f', '2f-inner', '2f-right'), 235, 137),
#  (('out', 'in', '2f', '2f-left'), 995, 548),
#  (('out', 'in', '2f', '2f-left', '1f'), 373, 233),
#  (('out', 'in', '2f', '2f-left', '1f', '1f-right'), 216, 146),
#  (('out', 'in', '2f', '2f-left', '1f-left'), 266, 184),
#  (('out', 'in', '2f', '2f-left', '1f-right'), 380, 260),
#  (('out', 'in', '2f', '2f-left', '2f-inner'), 245, 131),
#  (('out', 'in', '2f', '2f-left', '2f-right'), 329, 183),
#  (('out', 'in', '2f', '2f-left', 'out'), 217, 119),
#  (('out', 'in', '2f', '2f-right'), 1032, 564),
#  (('out', 'in', '2f', '2f-right', '1f'), 367, 243),
#  (('out', 'in', '2f', '2f-right', '1f', '1f-right'), 206, 152),
#  (('out', 'in', '2f', '2f-right', '1f-inner'), 210, 146),
#  (('out', 'in', '2f', '2f-right', '1f-left'), 278, 195),
#  (('out', 'in', '2f', '2f-right', '1f-right'), 378, 270),
#  (('out', 'in', '2f', '2f-right', '2f-inner'), 205, 117),
#  (('out', 'in', '2f', '2f-right', '2f-left'), 303, 175),
#  (('out', 'in', '2f', '2f-right', 'out'), 225, 130),
#  (('out', 'in', '2f', '3f'), 418, 221),
#  (('out', 'in', '2f', 'in'), 250, 174),
#  (('out', 'in', '2f', 'in', '1f'), 208, 145),
#  (('out', 'in', '2f', 'out'), 676, 363),
#  (('out', 'in', '2f-inner'), 917, 505),
#  (('out', 'in', '2f-inner', '1f'), 332, 215),
#  (('out', 'in', '2f-inner', '1f', '1f-right'), 203, 138),
#  (('out', 'in', '2f-inner', '1f-left'), 265, 182),
#  (('out', 'in', '2f-inner', '1f-right'), 382, 257),
#  (('out', 'in', '2f-inner', '2f'), 280, 155),
#  (('out', 'in', '2f-inner', '2f-left'), 350, 206),
#  (('out', 'in', '2f-inner', '2f-right'), 350, 196),
#  (('out', 'in', '2f-inner', 'out'), 204, 114),
#  (('out', 'in', '2f-left'), 1197, 657),
#  (('out', 'in', '2f-left', '1f'), 450, 279),
#  (('out', 'in', '2f-left', '1f', '1f-right'), 246, 166),
#  (('out', 'in', '2f-left', '1f-inner'), 224, 156),
#  (('out', 'in', '2f-left', '1f-left'), 308, 212),
#  (('out', 'in', '2f-left', '1f-right'), 431, 295),
#  (('out', 'in', '2f-left', '2f'), 273, 156),
#  (('out', 'in', '2f-left', '2f-inner'), 313, 172),
#  (('out', 'in', '2f-left', '2f-right'), 429, 239),
#  (('out', 'in', '2f-left', 'out'), 252, 138),
#  (('out', 'in', '2f-right'), 1304, 700),
#  (('out', 'in', '2f-right', '1f'), 477, 303),
#  (('out', 'in', '2f-right', '1f', '1f-right'), 263, 185),
#  (('out', 'in', '2f-right', '1f-inner'), 249, 170),
#  (('out', 'in', '2f-right', '1f-left'), 326, 225),
#  (('out', 'in', '2f-right', '1f-right'), 462, 321),
#  (('out', 'in', '2f-right', '2f'), 359, 201),
#  (('out', 'in', '2f-right', '2f-inner'), 253, 141),
#  (('out', 'in', '2f-right', '2f-left'), 411, 237),
#  (('out', 'in', '2f-right', 'out'), 290, 163),
#  (('out', 'in', '3f'), 756, 418),
#  (('out', 'in', '3f', '1f'), 262, 172),
#  (('out', 'in', '3f', '1f-right'), 233, 161),
#  (('out', 'in', '3f', '2f'), 220, 127),
#  (('out', 'in', '3f', '2f-right'), 213, 111),
#  (('out', 'in', 'in'), 603, 425),
#  (('out', 'in', 'in', '1f'), 491, 347),
#  (('out', 'in', 'in', '1f', '1f-right'), 234, 164),
#  (('out', 'in', 'in', '1f-right'), 295, 211),
#  (('out', 'in', 'out'), 2136, 1141),
#  (('out', 'in', 'out', '1f'), 338, 231),
#  (('out', 'in', 'out', '1f-right'), 202, 140),
#  (('out', 'in', 'out', 'in'), 410, 283),
#  (('out', 'in', 'out', 'in', '1f'), 338, 231),
#  (('out', 'in', 'out', 'in', '1f-right'), 202, 140),
#  (('out', 'in', 'out', 'out'), 511, 319),
#  (('out', 'out'), 3301, 1698),
#  (('out', 'out', '1f'), 1390, 771),
#  (('out', 'out', '1f', '1f-inner'), 348, 194),
#  (('out', 'out', '1f', '1f-left'), 325, 207),
#  (('out', 'out', '1f', '1f-right'), 499, 298),
#  (('out', 'out', '1f', '2f'), 305, 174),
#  (('out', 'out', '1f', 'out'), 332, 205),
#  (('out', 'out', '1f-inner'), 384, 215),
#  (('out', 'out', '1f-left'), 370, 229),
#  (('out', 'out', '1f-right'), 603, 358),
#  (('out', 'out', '2f'), 578, 309),
#  (('out', 'out', '2f-right'), 229, 126),
#  (('out', 'out', 'in'), 1937, 1048),
#  (('out', 'out', 'in', '1f'), 1390, 771),
#  (('out', 'out', 'in', '1f', '1f-inner'), 348, 194),
#  (('out', 'out', 'in', '1f', '1f-left'), 325, 207),
#  (('out', 'out', 'in', '1f', '1f-right'), 499, 298),
#  (('out', 'out', 'in', '1f', '2f'), 305, 174),
#  (('out', 'out', 'in', '1f', 'out'), 332, 205),
#  (('out', 'out', 'in', '1f-inner'), 384, 215),
#  (('out', 'out', 'in', '1f-left'), 370, 229),
#  (('out', 'out', 'in', '1f-right'), 603, 358),
#  (('out', 'out', 'in', '2f'), 578, 309),
#  (('out', 'out', 'in', '2f-right'), 229, 126),
#  (('out', 'out', 'in', 'out'), 482, 300),
#  (('out', 'out', 'out'), 994, 594),
#  (('out', 'out', 'out', '1f'), 302, 204),
#  (('out', 'out', 'out', 'in'), 442, 301),
#  (('out', 'out', 'out', 'in', '1f'), 302, 204),
#  (('out', 'out', 'out', 'out'), 365, 259)}

# %%
def entropy(data, target_attr):
 
    val_freq = {}
    data_entropy = 0.0
 
    # Calculate the frequency of each of the values in the target attr
    for record in data:
        if (val_freq.has_key(record[target_attr])):
            val_freq[record[target_attr]] += 1.0
        else:
            val_freq[record[target_attr]]  = 1.0
 
    # Calculate the entropy of the data for the target attribute
    for freq in val_freq.values():
        data_entropy += (-freq/len(data)) * math.log(freq/len(data), 2) 
 
    return data_entropy


x = np.random.rand(3, 10)
p = x/x.sum(axis=1, keepdims=True)
print(p)
print(p.shape)
print(p.sum(axis=1))

print(entr(p).sum(axis=1))
print(entr(p).sum(axis=1)/np.log(2))
print((-p*np.log2(p)).sum(axis=1))

# %%
yyy = trajs_combined_balanced.ix['16767_25e9517c47319ab64486403f94348dd6']

# %%
def asdf(yyy, i):
    return yyy['logs'][i], yyy['traj'][i]

# %%
asdf(yyy, 2)
# Out:
# (3145074, '2f')

# %%
yyy['logs'][2]
# Out:
# 3145074

# %%
yyy['traj'][2]
# Out:
# '2f'

# %% [markdown]
# -----------

# %%
### Leave long enough trajs
tatt2 = trajs_combined_balanced.loc(len(trajs_combined_balanced['traj']) > 8)
dfff = trajs_combined_balanced

# %%
mask = dfff['traj'].str.len() > 5
dfff2 = dfff.loc[mask]

# %%
dfff2.shape
# Out:
# (3231, 37)

# %%
dfff2.traj
# Out:
# 16706_3352c133a2ee0a29ed3351ab69dae032            [out, in, 3f, 2f-right, 2f, 1f, 1f-right]
# 16760_b210865acfd2674ae0017b11271afc33                 [out, in, 2f, 1f, 2f-left, 2f-inner]
# 16724_8eb18e0cbf9c29ea1e5ed4f98cb05171    [out, in, 1f, 1f-right, 2f, 3f, out, in, 1f-le...
# 16833_c751fe946b3c00c90874339929e99f06           [out, in, 1f, 1f-inner, 1f-right, 1f-left]
# 16935_a176960c74009d94369ede0614a5288f            [out, in, 2f, 2f-inner, 2f-left, 1f, out]
# 16732_a6a7fce63f5da450cccee8a0099d58e2                [out, in, 1f, 1f-right, 1f-left, out]
# 16831_3e5edaf2d72ac48a405c280c54eebdee           [out, in, 1f-right, 1f, 1f-left, 1f-inner]
# 16991_ebe19542cfead37db10244c163fbf76c    [out, out, out, in, 1f, 1f-inner, 2f, 2f-right...
# 16714_f59239d966989d77610087d5e9b9b802    [out, in, 1f, 1f-right, 1f-left, 2f-right, 2f,...
# 16927_dedf509af2003d829b2c3dd8e718bae7                     [out, in, 2f, 2f-inner, 1f, out]
# 16889_2dae56b75aed7823db01f5d6fe878fa5           [out, in, 1f-right, 1f, 1f-left, 1f-inner]
# 16948_e128d5f74c7f54c190ba0985b8dda8a8    [out, out, in, 1f, 1f-right, 2f, 2f-left, 2f-r...
# 16727_b62d3475c9b7fa7e96980130a0ead94e                    [out, out, in, 1f, out, out, out]
# 16992_642aaf178a9f28324c20fc14da4d2c41        [out, in, 2f, 2f-left, 1f, 1f-right, 1f-left]
# 16686_6b6bf250d2e67702f137b2fe8d225f2c    [out, in, 2f, 2f-inner, 1f, 2f-right, 3f, out,...
# 16920_828104c3089d9207ad4a44488c68406b    [out, in, 1f, 1f-inner, 1f-left, 1f-right, out...
# 16921_520645deb1a192656921716d2058d8b0    [out, in, 2f-right, 2f, 2f-left, 2f-inner, 1f,...
# 16740_2ed3896f9d40453b7ffe51223166f7aa                [out, out, in, 1f, 1f-right, 1f-left]
# 16932_9412db70409db792d9c9268e7fe58156    [out, in, 2f, 2f-left, 2f-right, 1f-right, 1f,...
# 16821_565e19723ab94e73addfb5d28b7a335d                [out, in, 2f, 2f-inner, 1f, out, out]
# 16772_3ef8d53508886eddc9e308349d4bfffd    [out, in, 1f, 1f-right, 1f-inner, 1f-left, 1f-...
# 16746_bda7c415ce437dd4821272151fa74050           [out, in, 1f-right, 1f, 1f-inner, 1f-left]
# 17015_61e492cf16cc2993d5dc1414c3ed534b    [out, in, 1f, 2f, 3f, out, in, 1f, 1f-right, 3...
# 16900_adbbf742d88eb88cf0762e18168e3f32                 [out, in, 1f, 1f-inner, out, in, 1f]
# 17015_a711570c6fb2c6037622fcbdbffe2ca0    [out, out, in, 1f-right, 1f, 2f, 2f-inner, 3f,...
# 16741_60ed078e273a8bb43fb746c408b78e3a                     [out, in, 2f, 2f-right, 1f, out]
# 16851_a60385d205abb15f4e926ea60683f831           [out, in, 1f-inner, 1f, 1f-right, 1f-left]
# 16683_6445372e25c7c933c4cff0fd5d2e1db8                 [out, in, 2f, 2f-left, 2f-inner, 1f]
# 16787_cf300c2390206a39b9a4d538a7ea54ec                      [out, in, 1f, 2f-right, 2f, 3f]
# 16840_94bfa4040a8900edce038cdc732e4adf                           [out, in, 2f, out, in, 2f]
#                                                                 ...
# 16989_215a19faedd274852ec7aacf1c24ddf0    [out, in, 1f, 1f-right, 1f-left, out, in, 1f-r...
# 16826_c9c1c7a59c29c831c811a7854ade701a        [out, in, 2f, 2f-right, in, 2f-right, 2f, 1f]
# 16834_8ecd22ce7a6cf6003ea65d684020dadb                 [out, in, 1f, 2f-left, 2f, 2f-right]
# 17016_8bd9d731f7f54af1448c387296bcbf8e    [out, in, 1f, out, out, out, out, in, 1f, out,...
# 16768_94896776f3a0c2225a453b90d8f4e534                      [out, in, 2f-inner, 2f, 1f, 1f]
# 16771_4cd21eceb27928bc7bc25e0c30f095f8    [out, in, 1f, 3f, 2f-inner, 2f, 2f-left, 2f-ri...
# 16887_349b48a5eb696f1d66d4131eb1ffbdad    [out, in, 1f, 1f-inner, 2f, 2f-right, 3f, 1f, ...
# 16753_206f44e1f51756bb201b6c9481dff656      [out, in, 1f, 1f-right, 1f-left, 1f-inner, out]
# 16993_44e4de36fd6ed5d8211b6e9b7c672835    [out, in, 2f-left, 2f, 2f-right, 1f, 1f-inner,...
# 16946_b709a2f40287ea61c25235007aa3cae6    [out, in, 1f, 1f-inner, 2f-inner, 2f, 2f-right...
# 16678_d097dfe9057c765b4eb65f2af19bc118    [out, in, 1f-inner, 1f, 1f-left, 2f-left, 2f, ...
# 16761_f0b0a46a1fed8bafddf471a58910558b       [out, in, 1f-right, 1f, 1f-left, 2f, 1f-inner]
# 16766_1ea8f32fded4dc577e77c2da48f97d16    [out, in, 1f-right, 1f, 1f-left, 1f-inner, 2f,...
# 16859_77536649bf0ba497dc4e3f167230abf5             [out, in, 1f, 2f, 2f-left, 1f-right, 1f]
# 16890_d258dfaa409566ebd21b5668eca43a82                     [out, out, in, 1f, 2f, 1f-right]
# 16841_749f962249e927bad4d0e5d2b74ca619    [out, out, out, in, 2f-left, 2f, 2f-right, 2f-...
# 16905_ccae76c88a74e406ae039ef8b62af2bc    [out, in, 1f, 1f-left, 1f-inner, 1f-right, out...
# 16717_6dfb321de77e19b0a4834a691bb793b2               [out, in, 1f, 1f-inner, 1f-right, out]
# 16887_21efa9b0e13a0d64e80749661c1d8986    [out, in, 1f-right, 1f, 1f-left, 1f-inner, 2f,...
# 16723_9276f24dfa557946c7e3fb7b3556527f       [out, in, 1f, 1f-left, 2f, 1f-inner, 1f-right]
# 16773_334080b4178d42d45f3c5f893c9c038a       [out, in, 1f, 1f-left, 1f-inner, 1f-right, 2f]
# 16759_307a2ce4ff96bf9c8c99c2409eb202a7    [out, in, 1f, 2f-left, 2f, 3f, 2f-inner, 1f, 1...
# 16794_a0ca5b04cf5e0e3508a73884fb6ac96e                      [out, in, 2f, 2f-right, 3f, 1f]
# 16769_db64620755b34d91cc03ac5122c3a5b5           [out, in, 1f, 1f-right, 1f-inner, 1f-left]
# 16816_67f4d764d911e7b8c1fc1afdf374dd28                    [out, out, out, in, 1f, out, out]
# 16890_68d59e794448dd680e938b011310cac4           [out, in, 1f, 1f-left, 1f-inner, 1f-right]
# 17005_bfdc954eaac74d58c55dbed2c5470cd9    [out, in, 1f-right, 1f, 1f-inner, 2f-left, 2f,...
# 16781_9e43b15d0c56409322f15776e970ce0e                     [out, out, in, 1f, 2f, 2f-right]
# 16777_217ca89dc99254e9d835ee5e168e8c77                       [out, in, 3f, 2f-left, 2f, 1f]
# 16929_b62d90196eb3344755ba6cef21ce1b6c    [out, in, 1f, 2f, 2f-left, 2f-right, 2f-inner,...
# Name: traj, dtype: object

# %% [markdown]
# -----------

# %%
type(dfff['traj'][0])
# Out:
# list

# %%
dfff['tt'] = 1

# %%
import random
def createRandomTrajs():
    rand = random.randrange(10) + 10
    listt = []
    foo = ['1f', '2f', '3f', '1f-left', '1f-inner', '1f-right', '2f-inner', '2f-left', '2f-right']
    listt.append('out')
    listt.append('in')
    for i in range(rand-2):
        listt.append(random.choice(foo))
    return listt

# %%
np.array([createRandomTrajs()])
# Out:
# array([['out', 'in', '3f', '2f-inner', '3f', '1f-inner', '1f-left',
#         '2f-right', '2f-left', '1f-right', '1f', '1f-inner']],
#       dtype='<U8')

# %%
listt = []
listt2 = []
for i in range(50000):
    listt.append(createRandomTrajs())
    listt2.append(random.choice([0, 1]))

# %%
d = {'traj': listt, 'r_i': listt2}
dfyo = pd.DataFrame(data=d, columns=['traj', 'r_i'])

# %%
dfyo.head(5000)
# Out:
#                                                    traj  r_i
# 0     [out, in, 2f-inner, 2f-left, 1f, 2f, 1f-inner,...    0
# 1     [out, in, 1f, 1f, 1f, 2f-inner, 2f-right, 1f-i...    1
# 2     [out, in, 2f-right, 1f, 1f-right, 2f-inner, 3f...    1
# 3     [out, in, 3f, 1f-left, 1f-inner, 1f-inner, 1f-...    1
# 4     [out, in, 1f-inner, 2f-right, 2f, 2f-right, 1f...    1
# 5     [out, in, 2f-right, 2f-inner, 2f, 3f, 1f-inner...    0
# 6     [out, in, 2f-left, 2f, 1f-left, 1f-left, 1f-in...    1
# 7     [out, in, 1f-inner, 2f, 1f-right, 2f-inner, 1f...    1
# 8     [out, in, 2f, 2f, 2f, 1f, 2f-right, 2f-left, 2...    0
# 9     [out, in, 1f-right, 2f-inner, 1f-right, 1f-inn...    1
# 10    [out, in, 2f, 1f-inner, 1f-left, 3f, 2f-inner,...    1
# 11    [out, in, 2f-left, 3f, 2f-right, 1f-right, 2f-...    0
# 12    [out, in, 3f, 1f, 2f-inner, 2f, 2f, 1f, 3f, 2f...    1
# 13    [out, in, 1f-inner, 2f-inner, 2f-right, 2f-inn...    0
# 14    [out, in, 1f-left, 2f-right, 2f, 1f-right, 1f-...    0
# 15    [out, in, 2f-inner, 2f-inner, 2f-right, 1f-lef...    0
# 16    [out, in, 3f, 1f-inner, 2f-right, 1f-left, 2f-...    1
# 17    [out, in, 1f, 1f-left, 1f-inner, 1f-left, 2f-r...    1
# 18    [out, in, 2f, 3f, 1f, 1f-left, 1f, 3f, 2f-left...    0
# 19    [out, in, 1f-left, 1f-left, 1f-right, 1f-inner...    0
# 20    [out, in, 1f-inner, 1f-inner, 2f-right, 1f, 2f...    0
# 21    [out, in, 2f-left, 1f-left, 1f-left, 1f-right,...    1
# 22    [out, in, 2f-inner, 2f-left, 2f-right, 1f-righ...    1
# 23    [out, in, 3f, 1f-right, 2f-right, 2f-inner, 2f...    1
# 24    [out, in, 2f-left, 2f-right, 1f-right, 1f-left...    1
# 25    [out, in, 1f, 1f-right, 2f-right, 1f-inner, 1f...    1
# 26    [out, in, 1f-right, 2f, 2f-inner, 1f, 1f-right...    1
# 27    [out, in, 1f-right, 2f-inner, 1f-left, 1f, 1f-...    0
# 28    [out, in, 1f-left, 1f-left, 2f-inner, 3f, 1f-i...    1
# 29    [out, in, 3f, 1f-right, 1f-inner, 3f, 2f-right...    1
# ...                                                 ...  ...
# 4970  [out, in, 2f-left, 3f, 2f-left, 3f, 2f-inner, ...    1
# 4971  [out, in, 2f-right, 1f-right, 2f, 2f-inner, 1f...    1
# 4972  [out, in, 2f, 1f-right, 1f-left, 1f-left, 2f-l...    1
# 4973  [out, in, 1f, 1f-right, 2f, 2f-right, 2f-inner...    1
# 4974  [out, in, 2f-inner, 3f, 1f, 1f-right, 1f-inner...    0
# 4975  [out, in, 1f-inner, 2f-left, 1f-left, 2f-right...    0
# 4976  [out, in, 2f-left, 1f-right, 1f, 2f, 1f-inner,...    1
# 4977  [out, in, 1f, 2f-inner, 1f-right, 2f-left, 1f-...    1
# 4978  [out, in, 1f-right, 2f-inner, 1f-right, 1f-rig...    0
# 4979  [out, in, 3f, 1f-right, 2f, 2f, 2f-right, 3f, ...    0
# 4980  [out, in, 1f-right, 1f, 1f, 2f-inner, 1f-inner...    1
# 4981  [out, in, 3f, 1f-left, 1f-left, 1f-left, 1f, 2...    1
# 4982  [out, in, 1f-inner, 3f, 2f-right, 2f-right, 2f...    0
# 4983  [out, in, 1f-left, 1f-left, 1f-inner, 3f, 2f-r...    1
# 4984  [out, in, 1f-inner, 2f-left, 2f-left, 2f-inner...    0
# 4985  [out, in, 2f-inner, 2f-left, 3f, 1f, 2f-left, ...    1
# 4986  [out, in, 1f-right, 2f-right, 1f-inner, 1f-inn...    0
# 4987  [out, in, 1f-inner, 2f-inner, 2f-left, 3f, 2f-...    0
# 4988  [out, in, 1f, 1f-right, 1f-inner, 1f-inner, 3f...    0
# 4989  [out, in, 2f, 1f-left, 1f, 2f-left, 1f-right, ...    0
# 4990  [out, in, 2f-left, 1f-right, 2f-left, 1f-inner...    1
# 4991  [out, in, 2f-inner, 1f, 2f, 1f, 2f-left, 2f-in...    1
# 4992  [out, in, 3f, 2f, 1f, 1f-left, 2f-inner, 1f, 2...    0
# 4993  [out, in, 1f-inner, 1f-right, 2f-inner, 3f, 1f...    1
# 4994  [out, in, 2f-inner, 2f-inner, 2f-right, 2f-inn...    1
# 4995  [out, in, 2f, 1f-left, 3f, 2f-right, 1f-right,...    0
# 4996  [out, in, 1f, 1f-left, 3f, 1f, 3f, 2f-right, 2...    0
# 4997  [out, in, 1f-left, 1f, 2f, 1f-left, 1f-inner, ...    0
# 4998  [out, in, 1f, 2f, 2f-left, 1f-left, 1f-left, 3...    0
# 4999  [out, in, 2f-right, 1f-inner, 1f, 3f, 3f, 2f-l...    0
#
# [5000 rows x 2 columns]

# %%
dfff['tt'] = createRandomTrajs()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-e19cbea9e7e3> in <module>()
# ----> 1 dfff['tt'] = createRandomTrajs()
#
# /Users/sundong/anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2355         else:
#    2356             # set column
# -> 2357             self._set_item(key, value)
#    2358
#    2359     def _setitem_slice(self, key, value):
#
# /Users/sundong/anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2421
#    2422         self._ensure_valid_index(value)
# -> 2423         value = self._sanitize_column(key, value)
#    2424         NDFrame._set_item(self, key, value)
#    2425
#
# /Users/sundong/anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value)
#    2576
#    2577             # turn me into an ndarray
# -> 2578             value = _sanitize_index(value, self.index, copy=False)
#    2579             if not isinstance(value, (np.ndarray, Index)):
#    2580                 if isinstance(value, list) and len(value) > 0:
#
# /Users/sundong/anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/series.py in _sanitize_index(data, index, copy)
#    2768
#    2769     if len(data) != len(index):
# -> 2770         raise ValueError('Length of values does not match length of ' 'index')
#    2771
#    2772     if isinstance(data, PeriodIndex):
#
# ValueError: Length of values does not match length of index

# %%
length = 15
fakedata1 = [i for i in range(random.randrange(length)+10)]

# %%
len(fakedata1)
# Out:
# 19

# %%
prob_revisit = (len(fakedata1)-10)/(length)
prob_revisit
# Out:
# 0.6

# %%
s = 0
for i in range(10000):
    s += np.random.choice([0, 1], p=[1-prob_revisit, prob_revisit])
print (s)
# Out:
# 5958
